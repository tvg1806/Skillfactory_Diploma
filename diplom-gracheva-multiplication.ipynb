# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/diploma/data.csv

# %%
# импорт библиотек

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import sys
import zipfile
import PIL
from PIL import ImageOps, ImageFilter
import re
import ast
from datetime import time, date, datetime
import random

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-paper')


from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score, roc_curve, roc_auc_score
from sklearn import metrics
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import VotingRegressor
from tqdm.notebook import tqdm
from catboost import CatBoostRegressor, Pool, cv

# keras
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.losses import MeanAbsolutePercentageError

#from transformers import AutoTokenizer, TFAutoModelForSequenceClassification, DataCollatorWithPadding

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns', 550) # больше колонок

os.environ['PYTHONHASHSEED']=str(42)

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
ITERATIONS = 200

# %%
DIR_DATA  = '../input/diploma/'

# %%
data_d = pd.read_csv(DIR_DATA+'data.csv')

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377185 entries, 0 to 377184
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        337267 non-null  object
#  1   private pool  4181 non-null    object
#  2   propertyType  342452 non-null  object
#  3   street        377183 non-null  object
#  4   baths         270847 non-null  object
#  5   homeFacts     377185 non-null  object
#  6   fireplace     103115 non-null  object
#  7   city          377151 non-null  object
#  8   schools       377185 non-null  object
#  9   sqft          336608 non-null  object
#  10  zipcode       377185 non-null  object
#  11  beds          285903 non-null  object
#  12  state         377185 non-null  object
#  13  stories       226470 non-null  object
#  14  mls-id        24942 non-null   object
#  15  PrivatePool   40311 non-null   object
#  16  MlsId         310305 non-null  object
#  17  target        374704 non-null  object
# dtypes: object(18)
# memory usage: 51.8+ MB

# %% [markdown]
# # Анализ целевой переменной.

# %% [markdown]
# # Вспомогательная функция извлечения числа из записи доллара.

# %%
def dollar_clean(string):
    i=0
    string_interm=re.findall('[0-9]+', string)
    
    if string_interm==[]:

        return np.NaN
    else:
        dollar_res=''
        while i<=(len(string_interm)-1):
            dollar_res=dollar_res + string_interm[i]
            i=i+1
        return float(dollar_res)

# %%
data_d.target = data_d.target.apply(lambda x: dollar_clean(str(x)))

# %%
data_d['target'].isna().unique()
# Out:
# array([False,  True])

# %%
data_d.loc[data_d['target'].isna() == True]
# Out:
#                            status private pool        propertyType  \
# 61                            NaN          NaN       Single Family
# 94      Pre-foreclosure / auction          NaN           Townhouse
# 121                     / auction          NaN       Single Family
# 169                           NaN          NaN       Single Family
# 174     Pre-foreclosure / auction          NaN       Single Family
# ...                           ...          ...                 ...
# 376495              recently sold          NaN  single-family home
# 376528                foreclosure          NaN           apartment
# 376577                 Foreclosed          NaN       Single Family
# 376937                        NaN          NaN                 NaN
# 377120                        NaN          NaN                 NaN
#
#                              street         baths  \
# 61              7353 Boysenberry Ct           2.0
# 94                 20663 Fm 2154 Rd  Bathrooms: 4
# 121                 3719 Suffolk St             2
# 169              8201 Waterford Ave           2.0
# 174               17508 Puritas Ave  Bathrooms: 2
# ...                             ...           ...
# 376495            7433 Creekland Dr       2 Baths
# 376528            5652 S Justine St       2 Baths
# 376577  1851 W Landstreet Rd # 3233           NaN
# 376937             8501 NW 53rd Ter           NaN
# 377120            75 Sophie May Ln            NaN
#
#                                                 homeFacts fireplace  \
# 61      {'atAGlanceFacts': [{'factValue': '1983', 'fac...       Yes
# 94      {'atAGlanceFacts': [{'factValue': '2016', 'fac...       Yes
# 121     {'atAGlanceFacts': [{'factValue': '1972', 'fac...       Yes
# 169     {'atAGlanceFacts': [{'factValue': '1985', 'fac...       NaN
# 174     {'atAGlanceFacts': [{'factValue': '2006', 'fac...       NaN
# ...                                                   ...       ...
# 376495  {'atAGlanceFacts': [{'factValue': '2003', 'fac...       NaN
# 376528  {'atAGlanceFacts': [{'factValue': '2009', 'fac...       NaN
# 376577  {'atAGlanceFacts': [{'factValue': '1973', 'fac...       NaN
# 376937  {'atAGlanceFacts': [{'factValue': None, 'factL...       NaN
# 377120  {'atAGlanceFacts': [{'factValue': '', 'factLab...       NaN
#
#                    city                                            schools  \
# 61         Jacksonville  [{'rating': ['7/10', '2/10', '4/10'], 'data': ...
# 94      College Station  [{'rating': ['NA', '2/10', 'NA'], 'data': {'Di...
# 121              Durham  [{'rating': ['2/10', '5/10', '4/10'], 'data': ...
# 169             Tamarac  [{'rating': ['4/10', '5/10', '5/10'], 'data': ...
# 174           Cleveland  [{'rating': ['2/10', '2/10'], 'data': {'Distan...
# ...                 ...                                                ...
# 376495             Reno  [{'rating': ['None/10', '5/10', '3/10'], 'data...
# 376528          Chicago  [{'rating': ['1/10', '1/10', '2/10'], 'data': ...
# 376577          Orlando  [{'rating': ['4/10', '2/10', '5/10'], 'data': ...
# 376937            Doral  [{'rating': ['10/10', '8/10'], 'data': {'Dista...
# 377120     Norridgewock  [{'rating': ['3', 'NR', '5', 'NR', '2'], 'data...
#
#                                            sqft zipcode        beds state  \
# 61                                   1,446 sqft   32244           3    FL
# 94      Total interior livable area: 4,179 sqft   77845        4 bd    TX
# 121                                       2,327   27707           3    NC
# 169                                  1,280 sqft   33321           2    FL
# 174     Total interior livable area: 1,209 sqft   44135        2 bd    OH
# ...                                         ...     ...         ...   ...
# 376495                               1,082 sqft   89506      2 Beds    NV
# 376528                               2,351 sqft   60636      6 Beds    IL
# 376577    Total interior livable area: 620 sqft   32809       -- bd    FL
# 376937                                      NaN   33166  1.74 acres    FL
# 377120                                      NaN    4957         NaN    ME
#
#        stories mls-id PrivatePool MlsId  target
# 61           1    NaN         NaN   NaN     NaN
# 94         2.0    NaN         NaN   NaN     NaN
# 121        0.0    NaN         NaN   NaN     NaN
# 169        1.0    NaN         NaN   NaN     NaN
# 174        NaN    NaN         NaN   NaN     NaN
# ...        ...    ...         ...   ...     ...
# 376495       1    NaN         NaN   NaN     NaN
# 376528     NaN    NaN         NaN   NaN     NaN
# 376577     NaN    NaN         NaN   NaN     NaN
# 376937     NaN    NaN         NaN   NaN     NaN
# 377120     NaN    NaN         NaN   NaN     NaN
#
# [2481 rows x 18 columns]

# %%
data_d.dropna(axis=0,subset=['target'],inplace=True)

# %%
data_d['target'].isna().unique()
# Out:
# array([False])

# %%
sns.distplot(data_d['target'])
# Out:
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %% [markdown]
# # Удаление выбросов в целевой переменной.

# %%
data_d.loc[data_d['target'].median()]
# Out:
# status                                                     Active
# private pool                                                  NaN
# propertyType                        Condo/Townhome/Row Home/Co-Op
# street                              1080 Wisconsin Ave NW Apt 304
# baths                                                         1.5
# homeFacts       {'atAGlanceFacts': [{'factValue': '1981', 'fac...
# fireplace                                                     NaN
# city                                                   Washington
# schools         [{'rating': ['8', '8', '8', '8', '9', '9', 'NR...
# sqft                                                          946
# zipcode                                                     20007
# beds                                                            1
# state                                                          DC
# stories                                                        3+
# mls-id                                                        NaN
# PrivatePool                                                   NaN
# MlsId                                                  DCDC440008
# target                                                   549500.0
# Name: 320000, dtype: object

# %%
data_d['target'].mean()
# Out:
# 644757.5030263888

# %%
data_d.loc[data_d['target']>data_d['target'].mean()]
# Out:
#           status private pool        propertyType                    street  \
# 2       for sale          NaN  single-family home         2005 Westridge Rd
# 3       for sale          NaN  single-family home       4311 Livingston Ave
# 10      for sale          NaN                coop  14205 Roosevelt Ave #512
# 15           New          NaN             2 Story              930 52nd St
# 17        Active          NaN           Townhouse            24 W 126th St
# ...          ...          ...                 ...                       ...
# 377168  for sale          NaN  single-family home          24080 Tuscany Ct
# 377174  for sale          NaN  single-family home         1107 E Euclid Ave
# 377179  For sale          NaN               Condo     2238 11th St NW APT 2
# 377180       NaN          NaN       Single Family         20800 NE 23rd Ave
# 377181  for sale          NaN               condo  3530 N Lake Shore Dr #4B
#
#           baths                                          homeFacts fireplace  \
# 2       2 Baths  {'atAGlanceFacts': [{'factValue': '1961', 'fac...       yes
# 3       8 Baths  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 10      2 Baths  {'atAGlanceFacts': [{'factValue': '1965', 'fac...       NaN
# 15          NaN  {'atAGlanceFacts': [{'factValue': '1905', 'fac...       NaN
# 17          NaN  {'atAGlanceFacts': [{'factValue': '1899', 'fac...       NaN
# ...         ...                                                ...       ...
# 377168  5 Baths  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 377174      NaN  {'atAGlanceFacts': [{'factValue': '1938', 'fac...       NaN
# 377179        3  {'atAGlanceFacts': [{'factValue': '2010', 'fac...       NaN
# 377180      6.0  {'atAGlanceFacts': [{'factValue': '1990', 'fac...       NaN
# 377181  3 Baths  {'atAGlanceFacts': [{'factValue': '1924', 'fac...       NaN
#
#                   city                                            schools  \
# 2          Los Angeles  [{'rating': ['8/10', '4/10', '8/10'], 'data': ...
# 3               Dallas  [{'rating': ['9/10', '9/10', '10/10', '9/10'],...
# 10            Flushing  [{'rating': ['2/10', '8/10', '10/10'], 'data':...
# 15            Brooklyn  [{'rating': ['8', '8', '3'], 'data': {'Distanc...
# 17            New York  [{'rating': ['2', '5', '1', '2'], 'data': {'Di...
# ...                ...                                                ...
# 377168  Bonita Springs  [{'rating': ['3/10', '8/10', '4/10', '5/10', '...
# 377174     San Antonio  [{'rating': ['4/10', '5/10', '3/10'], 'data': ...
# 377179      Washington  [{'rating': ['3/10', '3/10'], 'data': {'Distan...
# 377180           Miami  [{'rating': ['10/10', '5/10'], 'data': {'Dista...
# 377181         Chicago  [{'rating': ['1/10', '5/10', '7/10'], 'data': ...
#
#               sqft zipcode    beds state stories mls-id PrivatePool  \
# 2       3,000 sqft   90049  3 Beds    CA     1.0    NaN         yes
# 3       6,457 sqft   75205  5 Beds    TX     3.0    NaN         NaN
# 10      1,300 sqft   11354  3 Beds    NY     NaN    NaN         NaN
# 15             NaN   11219     NaN    NY     NaN    NaN         NaN
# 17           3,325   10027     NaN    NY     NaN    NaN         NaN
# ...            ...     ...     ...   ...     ...    ...         ...
# 377168  5,992 sqft   34134  4 Beds    FL     NaN    NaN         yes
# 377174    950 sqft   78212  2 Beds    TX     1.0    NaN         yes
# 377179       1,417   20001       2    DC     3.0    NaN         NaN
# 377180       4,017   33180       5    FL     0.0    NaN         Yes
# 377181  2,000 sqft   60657  3 Beds    IL     9.0    NaN         NaN
#
#              MlsId     target
# 2       FR19221027  2895000.0
# 3         14191809  2395000.0
# 10         3087630   669000.0
# 15         3182740  1650000.0
# 17         4975368  2650000.0
# ...            ...        ...
# 377168   219077435  2495000.0
# 377174     1391618   799500.0
# 377179  DCDC444306   799000.0
# 377180   A10702700  1249000.0
# 377181    10374233   674999.0
#
# [82814 rows x 18 columns]

# %%
data_d.loc[data_d['target']>500000]
# Out:
#           status private pool        propertyType                    street  \
# 2       for sale          NaN  single-family home         2005 Westridge Rd
# 3       for sale          NaN  single-family home       4311 Livingston Ave
# 10      for sale          NaN                coop  14205 Roosevelt Ave #512
# 12      for sale          NaN  single-family home          16373 NW 16th St
# 15           New          NaN             2 Story              930 52nd St
# ...          ...          ...                 ...                       ...
# 377174  for sale          NaN  single-family home         1107 E Euclid Ave
# 377179  For sale          NaN               Condo     2238 11th St NW APT 2
# 377180       NaN          NaN       Single Family         20800 NE 23rd Ave
# 377181  for sale          NaN               condo  3530 N Lake Shore Dr #4B
# 377182  for sale          NaN  single-family home         15509 Linden Blvd
#
#           baths                                          homeFacts fireplace  \
# 2       2 Baths  {'atAGlanceFacts': [{'factValue': '1961', 'fac...       yes
# 3       8 Baths  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 10      2 Baths  {'atAGlanceFacts': [{'factValue': '1965', 'fac...       NaN
# 12      3 Baths  {'atAGlanceFacts': [{'factValue': '1996', 'fac...       NaN
# 15          NaN  {'atAGlanceFacts': [{'factValue': '1905', 'fac...       NaN
# ...         ...                                                ...       ...
# 377174      NaN  {'atAGlanceFacts': [{'factValue': '1938', 'fac...       NaN
# 377179        3  {'atAGlanceFacts': [{'factValue': '2010', 'fac...       NaN
# 377180      6.0  {'atAGlanceFacts': [{'factValue': '1990', 'fac...       NaN
# 377181  3 Baths  {'atAGlanceFacts': [{'factValue': '1924', 'fac...       NaN
# 377182  3 Baths  {'atAGlanceFacts': [{'factValue': '1950', 'fac...       NaN
#
#                   city                                            schools  \
# 2          Los Angeles  [{'rating': ['8/10', '4/10', '8/10'], 'data': ...
# 3               Dallas  [{'rating': ['9/10', '9/10', '10/10', '9/10'],...
# 10            Flushing  [{'rating': ['2/10', '8/10', '10/10'], 'data':...
# 12      Pembroke Pines  [{'rating': ['8/10', '7/10', '7/10'], 'data': ...
# 15            Brooklyn  [{'rating': ['8', '8', '3'], 'data': {'Distanc...
# ...                ...                                                ...
# 377174     San Antonio  [{'rating': ['4/10', '5/10', '3/10'], 'data': ...
# 377179      Washington  [{'rating': ['3/10', '3/10'], 'data': {'Distan...
# 377180           Miami  [{'rating': ['10/10', '5/10'], 'data': {'Dista...
# 377181         Chicago  [{'rating': ['1/10', '5/10', '7/10'], 'data': ...
# 377182         Jamaica  [{'rating': ['5/10', '4/10'], 'data': {'Distan...
#
#               sqft zipcode    beds state stories mls-id PrivatePool  \
# 2       3,000 sqft   90049  3 Beds    CA     1.0    NaN         yes
# 3       6,457 sqft   75205  5 Beds    TX     3.0    NaN         NaN
# 10      1,300 sqft   11354  3 Beds    NY     NaN    NaN         NaN
# 12      2,839 sqft   33028  4 Beds    FL     1.0    NaN         yes
# 15             NaN   11219     NaN    NY     NaN    NaN         NaN
# ...            ...     ...     ...   ...     ...    ...         ...
# 377174    950 sqft   78212  2 Beds    TX     1.0    NaN         yes
# 377179       1,417   20001       2    DC     3.0    NaN         NaN
# 377180       4,017   33180       5    FL     0.0    NaN         Yes
# 377181  2,000 sqft   60657  3 Beds    IL     9.0    NaN         NaN
# 377182  1,152 sqft   11434  3 Beds    NY       2    NaN         NaN
#
#              MlsId     target
# 2       FR19221027  2895000.0
# 3         14191809  2395000.0
# 10         3087630   669000.0
# 12       A10767242   525000.0
# 15         3182740  1650000.0
# ...            ...        ...
# 377174     1391618   799500.0
# 377179  DCDC444306   799000.0
# 377180   A10702700  1249000.0
# 377181    10374233   674999.0
# 377182         NaN   528000.0
#
# [110207 rows x 18 columns]

# %%
data_d = data_d[(data_d['target'] < 550000)]

# %%
sns.distplot(data_d['target'])
# Out:
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %%
plt.violinplot(data_d['target'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f62c7222dd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f62c7255590>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f62c71d0a50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f62c71d0a90>}

# %%
data_d['target'].isna().unique()
# Out:
# array([False])

# %%
data_d.loc[data_d['target']==0]
# Out:
# Empty DataFrame
# Columns: [status, private pool, propertyType, street, baths, homeFacts, fireplace, city, schools, sqft, zipcode, beds, state, stories, mls-id, PrivatePool, MlsId, target]
# Index: []

# %%
data_d.loc[data_d['target'].min()]
# Out:
# status                                                   for sale
# private pool                                                  NaN
# propertyType                                   single-family home
# street                                          12911 E Heroy Ave
# baths                                                     3 Baths
# homeFacts       {'atAGlanceFacts': [{'factValue': '2019', 'fac...
# fireplace                                                     NaN
# city                                               Spokane Valley
# schools         [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# sqft                                                   1,947 sqft
# zipcode                                                     99216
# beds                                                       3 Beds
# state                                                          WA
# stories                                                       2.0
# mls-id                                                        NaN
# PrivatePool                                                   NaN
# MlsId                                                   201916904
# target                                                   310000.0
# Name: 1, dtype: object

# %%
#data_d.target = np.log(data_d.target[data_d.target > 0])

# %%
#data_d['target'].isna().unique()

# %% [markdown]
# # Обработка признака homeFacts.

# %%
def facts_extraction(slovar):
    if slovar.find('atAGlanceFacts')>-1:
        slovar1 = eval(slovar)
       # print(type(slovar1))
        #print(slovar1)
        slovar2=slovar1.get('atAGlanceFacts')
       # print(type(slovar2))
       # print(slovar2)
        
        lst = ['']
        for i in slovar2:
            
            lst.append(i.get('factValue'))
        lst_res=lst[1:]
        return lst_res
            
    else: return np.NaN

# %%
data_d.homeFacts = data_d.homeFacts.apply(lambda x: facts_extraction(x))
t = data_d['homeFacts']
t_lst = t.tolist()
columns = ['Year built','Remodeled year','Heating','Cooling','Parking','lotsize','price_sqft']
t1 = pd.DataFrame(t_lst, columns = columns)
data_d = data_d.join(t1)

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274467 entries, 0 to 377184
# Data columns (total 25 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          245007 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250827 non-null  object
#  3   street          274466 non-null  object
#  4   baths           192550 non-null  object
#  5   homeFacts       274467 non-null  object
#  6   fireplace       66993 non-null   object
#  7   city            274447 non-null  object
#  8   schools         274467 non-null  object
#  9   sqft            244803 non-null  object
#  10  zipcode         274467 non-null  object
#  11  beds            204895 non-null  object
#  12  state           274467 non-null  object
#  13  stories         167742 non-null  object
#  14  mls-id          19144 non-null   object
#  15  PrivatePool     22559 non-null   object
#  16  MlsId           224520 non-null  object
#  17  target          274467 non-null  float64
#  18  Year built      197552 non-null  object
#  19  Remodeled year  186648 non-null  object
#  20  Heating         197614 non-null  object
#  21  Cooling         197614 non-null  object
#  22  Parking         197614 non-null  object
#  23  lotsize         184643 non-null  object
#  24  price_sqft      167356 non-null  object
# dtypes: float64(1), object(24)
# memory usage: 62.5+ MB

# %% [markdown]
# # Разбор признака школы.

# %%
data_d.schools = data_d.schools.apply(lambda x: eval(x[1:-1]))
t = data_d['schools']
t_lst = t.tolist()
t5_lst = []
for i in t_lst:
    i1 = dict([('rating', i.get('rating')), ('Distance', (i.get('data')).get('Distance')), ('Grades', (i.get('data')).get('Grades')),('name',i.get('name'))])
    t5_lst.append(i1)

df_lst = pd.DataFrame(t5_lst,dtype=str)
data_d = data_d.join(df_lst)

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274467 entries, 0 to 377184
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          245007 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250827 non-null  object
#  3   street          274466 non-null  object
#  4   baths           192550 non-null  object
#  5   homeFacts       274467 non-null  object
#  6   fireplace       66993 non-null   object
#  7   city            274447 non-null  object
#  8   schools         274467 non-null  object
#  9   sqft            244803 non-null  object
#  10  zipcode         274467 non-null  object
#  11  beds            204895 non-null  object
#  12  state           274467 non-null  object
#  13  stories         167742 non-null  object
#  14  mls-id          19144 non-null   object
#  15  PrivatePool     22559 non-null   object
#  16  MlsId           224520 non-null  object
#  17  target          274467 non-null  float64
#  18  Year built      197552 non-null  object
#  19  Remodeled year  186648 non-null  object
#  20  Heating         197614 non-null  object
#  21  Cooling         197614 non-null  object
#  22  Parking         197614 non-null  object
#  23  lotsize         184643 non-null  object
#  24  price_sqft      167356 non-null  object
#  25  rating          199601 non-null  object
#  26  Distance        199601 non-null  object
#  27  Grades          199601 non-null  object
#  28  name            199601 non-null  object
# dtypes: float64(1), object(28)
# memory usage: 70.9+ MB

# %% [markdown]
# # Площадь

# %% [markdown]
# Вспомогательная функция для получения численного значения площади. Если значение некорректно, возвращает NaN.

# %%
def extract_num_recurr_sqft(stroka,first_digit,len_s,i):
    if i == len_s and stroka[i].isdigit():
        return (float(first_digit + str(stroka[i])))
    elif i < len_s and (stroka[i].isdigit() or stroka[i] == '.'):
        return extract_num_recurr_sqft(stroka, (first_digit + str(stroka[i])), len_s, i+1)
    elif i < len_s and stroka[i] == ',':
        return extract_num_recurr_sqft(stroka, first_digit, len_s, i+1)
    else: return(float(first_digit))
                        
def extract_num_sqft(stroka,len_s,i):
  
    if i == len_s and not stroka[i].isdigit():
        return np.NaN
    elif i == len_s and stroka[i].isdigit():
        return float(stroka[i])
    elif i < len_s and stroka[i].isdigit():
        return extract_num_recurr_sqft(stroka,str(stroka[i]),len_s,i+1)
    else: return extract_num_sqft(stroka,len_s,i+1)

def main_extract_num_sqft(stroka):   
    len_s=len(stroka)-1
    
    return extract_num_sqft(stroka,len_s,0)

# %%
data_d.sqft = data_d.sqft.apply(lambda x: main_extract_num_sqft(str(x)))

# %% [markdown]
# Вместо нулевых значений подставляю нан для упрощения последующей замены.

# %%
data_d.sqft = data_d.sqft.apply(lambda x: np.NaN if x==0.0 else x)

# %%
data_d.loc[data_d['sqft'].isna() == True]
# Out:
#           status private pool        propertyType                 street  \
# 4       for sale          NaN            lot/land         1524 Kiscoe St
# 7         Active          NaN                 NaN        6094 Mingle Dr
# 40        Active          NaN                 NaN      1104 Rotonda Cir
# 48        Active          NaN                 NaN   18b Sitton-Mills Pl
# 49        Active          NaN                Land       23443 N 65th Ave
# ...          ...          ...                 ...                    ...
# 377141    Active          NaN                 NaN            Mantova Ct
# 377146  for sale          NaN  single-family home  206/208 N Randolph St
# 377154    Active          NaN                 NaN      2104 Russell Ave
# 377161    Active          NaN                Land     Homestead Dr Lot 1
# 377183       NaN          NaN                 NaN        7810 Pereida St
#
#        baths                                     homeFacts fireplace  \
# 4        NaN                 [, , , , , 10,019 sqft, None]       NaN
# 7        NaN  [1976, , , , , 8,750 Sq. Ft., $57 / Sq. Ft.]       NaN
# 40       NaN                           [, , , , , —, None]       NaN
# 48       NaN                           [, , , , , —, None]       NaN
# 49       NaN                       [, , , , , 50530, None]       NaN
# ...      ...                                           ...       ...
# 377141   NaN                           [, , , , , —, None]       NaN
# 377146   NaN               [1910, , , , , 5488 sqft, None]       NaN
# 377154   NaN               [, , , , , 6,970 Sq. Ft., None]       NaN
# 377161   NaN                           [, , , , , 1, None]       NaN
# 377183   NaN    [None, None, None, None, None, None, None]       NaN
#
#                    city                                            schools  \
# 4              Palm Bay  {'rating': ['4/10', '5/10', '5/10'], 'data': {...
# 7               Memphis  {'rating': ['4', '2', '2'], 'data': {'Distance...
# 40         ROTONDA WEST  {'rating': ['6', '6', '7'], 'data': {'Distance...
# 48      Signal Mountain  {'rating': ['8', 'NR', '7', '4'], 'data': {'Di...
# 49             Glendale  {'rating': ['8', '9', '7', '8', '9', '7', 'NR'...
# ...                 ...                                                ...
# 377141          ORLANDO  {'rating': ['7', '6', 'NR', 'NR', '7'], 'data'...
# 377146     Indianapolis  {'rating': ['1/10'], 'data': {'Distance': ['0....
# 377154        Charlotte  {'rating': ['2', '3', '3'], 'data': {'Distance...
# 377161       Columbiana  {'rating': ['8', '9', '8', 'NR'], 'data': {'Di...
# 377183          Houston  {'rating': ['NA', 'NA', 'NA'], 'data': {'Dista...
#
#         sqft zipcode        beds state stories mls-id PrivatePool     MlsId  \
# 4        NaN   32908         NaN    FL     NaN    NaN         NaN    861745
# 7        NaN   38115         NaN    TN     NaN    NaN         NaN  10063506
# 40       NaN   33947         NaN    FL     NaN    NaN         NaN  D6107075
# 48       NaN   37377         NaN    TN     NaN    NaN         NaN   1310212
# 49       NaN   85310         NaN    AZ     NaN    NaN         NaN   5876037
# ...      ...     ...         ...   ...     ...    ...         ...       ...
# 377141   NaN   32836         NaN    FL     NaN    NaN         NaN  O5763033
# 377146   NaN   46201         NaN    IN     NaN    NaN         NaN  21686741
# 377154   NaN   28216         NaN    NC     NaN    NaN         NaN   3571015
# 377161   NaN   44408         NaN    OH     NaN    NaN         NaN   3382834
# 377183   NaN   77028  8,479 sqft    TX     NaN    NaN         NaN       NaN
#
#           target Year built Remodeled year              Heating      Cooling  \
# 4         5000.0       2006           2006  Electric, Heat Pump  Central Air
# 7        68000.0       2019           None                  Gas      Central
# 40       54000.0       1974                            Electric
# 48      125000.0       1918                           Baseboard
# 49      275000.0       1960           1993    Central, Electric  Central Air
# ...          ...        ...            ...                  ...          ...
# 377141  400000.0        NaN            NaN                  NaN          NaN
# 377146   50000.0        NaN            NaN                  NaN          NaN
# 377154   99990.0        NaN            NaN                  NaN          NaN
# 377161   45000.0        NaN            NaN                  NaN          NaN
# 377183   34500.0        NaN            NaN                  NaN          NaN
#
#                 Parking         lotsize      price_sqft  \
# 4                         4,996 Sq. Ft.  $120 / Sq. Ft.
# 7       Attached Garage      2,056 sqft            $162
# 40                            1.7 acres       $344/sqft
# 48           Off Street      7,680 sqft       $617/sqft
# 49                       10,200 Sq. Ft.  $190 / Sq. Ft.
# ...                 ...             ...             ...
# 377141              NaN             NaN             NaN
# 377146              NaN             NaN             NaN
# 377154              NaN             NaN             NaN
# 377161              NaN             NaN             NaN
# 377183              NaN             NaN             NaN
#
#                           rating                                  Distance  \
# 4          ['3', '3', '1', 'NR']  ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
# 7       ['4/10', '3/10', '2/10']            ['0.7 mi', '0.6 mi', '1.9 mi']
# 40      ['8/10', '6/10', '8/10']            ['0.93mi', '0.59mi', '0.41mi']
# 48      ['6/10', '3/10', '4/10']             ['0.33mi', '0.7mi', '0.18mi']
# 49               ['4', '7', '7']            ['1.4 mi', '2.6 mi', '4.8 mi']
# ...                          ...                                       ...
# 377141                       NaN                                       NaN
# 377146                       NaN                                       NaN
# 377154                       NaN                                       NaN
# 377161                       NaN                                       NaN
# 377183                       NaN                                       NaN
#
#                                                    Grades  \
# 4       ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 7                                 ['PK-5', '5-8', '9-12']
# 40                                ['9-12', '6-8', 'PK-5']
# 48                                ['6-8', 'PK-5', '9-12']
# 49                ['Preschool to 5', '6 to 8', '9 to 12']
# ...                                                   ...
# 377141                                                NaN
# 377146                                                NaN
# 377154                                                NaN
# 377161                                                NaN
# 377183                                                NaN
#
#                                                      name
# 4       ['Palmetto Elementary School', 'Haines City Se...
# 7       ['Edgewood Elementary School', 'Landrum Middle...
# 40      ['Dunwoody High School', 'Peachtree Middle Sch...
# 48      ['Denny Middle School', 'Roxhill Elementary Sc...
# 49      ['Peace River Elementary School', 'Port Charlo...
# ...                                                   ...
# 377141                                                NaN
# 377146                                                NaN
# 377154                                                NaN
# 377161                                                NaN
# 377183                                                NaN
#
# [40837 rows x 29 columns]

# %%
data_d[['sqft']] = data_d[['sqft']].fillna(method='ffill')

# %%
data_d['sqft'].isna().sum()
# Out:
# 0

# %%
data_d.loc[data_d['sqft'].min()]
# Out:
# status                                                     for sale
# private pool                                                    NaN
# propertyType                                     single-family home
# street                                            12911 E Heroy Ave
# baths                                                       3 Baths
# homeFacts                      [2019, , , , , 5828 sqft, $159/sqft]
# fireplace                                                       NaN
# city                                                 Spokane Valley
# schools           {'rating': ['4/10', 'None/10', '4/10'], 'data'...
# sqft                                                         1947.0
# zipcode                                                       99216
# beds                                                         3 Beds
# state                                                            WA
# stories                                                         2.0
# mls-id                                                          NaN
# PrivatePool                                                     NaN
# MlsId                                                     201916904
# target                                                     310000.0
# Year built                                                     2019
# Remodeled year
# Heating
# Cooling
# Parking
# lotsize                                                   5828 sqft
# price_sqft                                                $159/sqft
# rating                                  ['4/10', 'None/10', '4/10']
# Distance                             ['1.65mi', '1.32mi', '1.01mi']
# Grades                                      ['9-12', '3-8', 'PK-8']
# name              ['East Valley High School&Extension', 'Eastval...
# Name: 1, dtype: object

# %%
sns.distplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='Density'>

# %%
data_d.loc[data_d['sqft'].median()]
# Out:
# status                                                     for sale
# private pool                                                    NaN
# propertyType                                                  condo
# street                                        2924 Collins Ave #503
# baths                                                       2 Baths
# homeFacts            [1980, 1980, Electric, Central, , , $487/sqft]
# fireplace                                                       NaN
# city                                                    Miami Beach
# schools           {'rating': ['5/10', '10/10', '4/10', '10/10', ...
# sqft                                                         1077.0
# zipcode                                                       33140
# beds                                                         2 Beds
# state                                                            FL
# stories                                                         NaN
# mls-id                                                          NaN
# PrivatePool                                                     NaN
# MlsId                                                     A10786403
# target                                                     525000.0
# Year built                                                     2004
# Remodeled year                                                 2004
# Heating                                                       Other
# Cooling                                                     Central
# Parking                                                     1 space
# lotsize                                                        None
# price_sqft                                                     $324
# rating                                             ['3/10', '4/10']
# Distance                                       ['0.6 mi', '2.8 mi']
# Grades                                             ['PK-8', '9-12']
# name              ['Gregory-Lincoln Ed Center', 'Reagan High Sch...
# Name: 1655, dtype: object

# %%
data_d['sqft_big'] = data_d['sqft'].apply(lambda x: 1 if x > 2300 else 0)

# %%
data_d.sqft = data_d.sqft.apply(lambda x: 2301 if x>2300 else x)

# %% [markdown]
# # Визуализация признака площадь

# %%
sns.distplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='Density'>

# %%
x = data_d['sqft']
y = data_d['target']
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Цена', fontsize = 15)
plt.title('Зависимость цены от площади', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от площади')

# %%
sns.boxplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft'>

# %% [markdown]
# # Спальни - приведение к численному виду.

# %%
data_d.loc[data_d['beds'] == '# Bedrooms 1st Floor']
# Out:
#           status private pool propertyType               street baths  \
# 364340  A Active          NaN         Land  4500 Harris Hill Rd   NaN
#
#                             homeFacts fireplace      city  \
# 364340  [1922, , , , , 1079000, None]       NaN  Falconer
#
#                                                   schools    sqft zipcode  \
# 364340  {'rating': ['5', '5', 'NR', 'NR', 'NR'], 'data...  1596.0   14733
#
#                         beds state stories mls-id PrivatePool     MlsId  \
# 364340  # Bedrooms 1st Floor    NY     NaN    NaN         NaN  R1171774
#
#          target Year built Remodeled year Heating Cooling Parking lotsize  \
# 364340  79000.0        NaN            NaN     NaN     NaN     NaN     NaN
#
#        price_sqft rating Distance Grades name  sqft_big
# 364340        NaN    NaN      NaN    NaN  NaN         0

# %%
#data_d = data_d.drop(data_d['beds'] == '# Bedrooms 1st Floor')

# %% [markdown]
# Вспомогательная функция stirng_part со вложенной string_part_extract для выделения символьной части.

# %%
def string_part_extract(string, len_s, i, res_str):
    if i<len_s:
      
        if string[i].isdigit(): return string_part_extract(string, len_s, i+1, res_str)
        else:
    
            return string_part_extract(string, len_s, i+1, res_str+string[i])
    elif i==len_s:
    
        if string[i].isdigit(): 
           
            return res_str
        
        else:
       
            return (res_str+string[i])
    
    
    
    
def stirng_part(string):
    len_s = len(str(string))-1
    pus = ""
    return string_part_extract(str(string), len_s, 0, pus)

# %% [markdown]
# Вспомогательная функция, проверяет определенные слова в описании признака.

# %%
def subsrting_beds(source_string):
    list_of_strings = ['Bd','Bedrooms','Beds','Bed','bd','beds','bed','bedrooms']
    for substring in list_of_strings:
        if substring in source_string:
            return False
    return True

# %% [markdown]
# Предварительная обработка признака для систематизации словесных комментариев. (Для того, чтобы значимые величины не попали в выбросы.)

# %%
#data_d = data_d.drop(np.where(data_d['beds'] == '# Bedrooms 1st Floor'))
data_d.beds = data_d.beds.apply(lambda x: 1 if subsrting_beds(stirng_part(x)) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if 'Bath' in str(x) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if x == '1-2 Beds' or x == '-- bd' else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if x == '1-2 Beds' or x == '-- bd' else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('sqft')>-1) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('acres')>-1) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('# Bedrooms 1st Floor')>-1) else x)
data_d['beds'].unique()                        
data_d['beds'].value_counts()
# Out:
# 1                                                                         156446
# 3 Beds                                                                     42508
# 4 Beds                                                                     24565
# 2 Beds                                                                     20274
# 3 bd                                                                       10939
# 4 bd                                                                        6034
# 5 Beds                                                                      4770
# 2 bd                                                                        4573
# 5 bd                                                                        1303
# 6 Beds                                                                      1123
# 1 bd                                                                         969
# 6 bd                                                                         253
# 7 Beds                                                                       235
# 8 Beds                                                                       159
# 9 Beds                                                                        73
# 64 Beds                                                                       44
# 8 bd                                                                          44
# 7 bd                                                                          39
# 10 Beds                                                                       37
# 9 bd                                                                          15
# 12 Beds                                                                       13
# 11 Beds                                                                       13
# 10 bd                                                                          8
# 16 Beds                                                                        6
# 12 bd                                                                          5
# 14 Beds                                                                        3
# 11 bd                                                                          2
# 18 Beds                                                                        2
# 13 Beds                                                                        1
# 20 Beds                                                                        1
# 28 Beds                                                                        1
# 14 bd                                                                          1
# 3 or More Bedrooms                                                             1
# 24 bd                                                                          1
# 15 Beds                                                                        1
# 13 bd                                                                          1
# 3 or More Bedrooms, Dining Room, Living Room, Range/Oven, Refrigerator         1
# 17 Beds                                                                        1
# 44 Beds                                                                        1
# 24 Beds                                                                        1
# Name: beds, dtype: int64

# %%
data_d.loc[data_d['beds'] == '# Bedrooms 1st Floor']
# Out:
# Empty DataFrame
# Columns: [status, private pool, propertyType, street, baths, homeFacts, fireplace, city, schools, sqft, zipcode, beds, state, stories, mls-id, PrivatePool, MlsId, target, Year built, Remodeled year, Heating, Cooling, Parking, lotsize, price_sqft, rating, Distance, Grades, name, sqft_big]
# Index: []

# %% [markdown]
# Вспомогательная функция для выбора числового значения признака спальни.

# %%
def otbor(stroka,i):
    if i == len(stroka): return(int(stroka))
    elif stroka[i] == ' ':
            return (int(stroka[:i]))
    else: return otbor(stroka,i+1)

# %%
data_d.beds = data_d.beds.apply(lambda x: otbor(str(x),0))

# %%
data_d['beds'].unique()
# Out:
# array([ 1,  3,  2,  4,  5,  8,  6,  7, 10, 64, 24,  9, 11, 16, 18, 12, 44,
#        17, 14, 13, 15, 28, 20])

# %%
data_d['beds'].isna().sum()
# Out:
# 0

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274467 entries, 0 to 377184
# Data columns (total 30 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          245007 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250827 non-null  object
#  3   street          274466 non-null  object
#  4   baths           192550 non-null  object
#  5   homeFacts       274467 non-null  object
#  6   fireplace       66993 non-null   object
#  7   city            274447 non-null  object
#  8   schools         274467 non-null  object
#  9   sqft            274467 non-null  float64
#  10  zipcode         274467 non-null  object
#  11  beds            274467 non-null  int64
#  12  state           274467 non-null  object
#  13  stories         167742 non-null  object
#  14  mls-id          19144 non-null   object
#  15  PrivatePool     22559 non-null   object
#  16  MlsId           224520 non-null  object
#  17  target          274467 non-null  float64
#  18  Year built      197552 non-null  object
#  19  Remodeled year  186648 non-null  object
#  20  Heating         197614 non-null  object
#  21  Cooling         197614 non-null  object
#  22  Parking         197614 non-null  object
#  23  lotsize         184643 non-null  object
#  24  price_sqft      167356 non-null  object
#  25  rating          199601 non-null  object
#  26  Distance        199601 non-null  object
#  27  Grades          199601 non-null  object
#  28  name            199601 non-null  object
#  29  sqft_big        274467 non-null  int64
# dtypes: float64(2), int64(2), object(26)
# memory usage: 73.0+ MB

# %%
data_d.loc[data_d['beds']==10]
# Out:
#                  status private pool        propertyType  \
# 5835        foreclosure          NaN        multi-family
# 17965          for sale          NaN        multi-family
# 20786          for sale          NaN        multi-family
# 22631          for sale          NaN        multi-family
# 43069          for sale          NaN  single-family home
# 47322          for sale          NaN        multi-family
# 65194          For sale          NaN        Multi Family
# 69582          for sale          NaN        multi-family
# 75157       foreclosure          NaN        multi-family
# 86894   Pre-foreclosure          NaN               Condo
# 101099         for sale          NaN        multi-family
# 108328         for sale          NaN        multi-family
# 112304         for sale          NaN        multi-family
# 124687         for sale          NaN            lot/land
# 145781         for sale          NaN        multi-family
# 156139         for sale          NaN        multi-family
# 164986      foreclosure          NaN  single-family home
# 170295         for sale          NaN        multi-family
# 176747         for sale          NaN  single-family home
# 177457         For sale          NaN        Multi Family
# 186910         for sale          NaN        multi-family
# 188811      foreclosure          NaN        multi-family
# 198340         for sale          NaN        multi-family
# 212075         for sale          NaN        multi-family
# 223895         for sale          NaN        multi-family
# 238402         for sale          NaN        multi-family
# 239883         For sale          NaN        Multi Family
# 250910      foreclosure          NaN        multi-family
# 255881         for sale          NaN        multi-family
# 262232         for sale          NaN        multi-family
# 266931         for sale          NaN        multi-family
# 271225         For sale          NaN        Multi Family
# 275277         for sale          NaN        multi-family
# 277563         for sale          NaN  single-family home
# 284102         For sale          NaN        Multi Family
# 285830         For sale          NaN        Multi Family
# 301679         for sale          NaN        multi-family
# 310332      foreclosure          NaN        multi-family
# 313294      foreclosure          NaN  single-family home
# 329198         for sale          NaN        multi-family
# 346254         For sale          NaN        Multi Family
# 352608         for sale          NaN  single-family home
# 375309         for sale          NaN        multi-family
# 376081         for sale          NaN        multi-family
# 376203         for sale          NaN        multi-family
#
#                          street         baths  \
# 5835      4128 W Wilcox St #1-4       8 Baths
# 17965            192 Ontario St       8 Baths
# 20786                80 3rd Ave       5 Baths
# 22631     6333 S California Ave       4 Baths
# 43069               2700 Ash St       5 Baths
# 47322          146 Beethoven St           NaN
# 65194         5419 Woodcrest Rd  Bathrooms: 7
# 69582     Address Not Disclosed       5 Baths
# 75157     6201 S California Ave       5 Baths
# 86894             93 Fairfax Rd  Bathrooms: 5
# 101099    4710 Springfield Blvd       4 Baths
# 108328       3821 W Fillmore St       4 Baths
# 112304        88 Montgomery Ave       3 Baths
# 124687          2307 Jackson St           NaN
# 145781      4314 S Berkeley Ave       7 Baths
# 156139       1619 S Harding Ave       3 Baths
# 164986           5930 S King Dr       4 Baths
# 170295           950 Burton Ave       5 Baths
# 176747             990 Dana Ave       6 Baths
# 177457           739 Genesee St  Bathrooms: 4
# 186910           1533 W 51st St       4 Baths
# 188811         6511 S Peoria St       4 Baths
# 198340        5419 Woodcrest Rd       7 Baths
# 212075    7811 S Winchester Ave       4 Baths
# 223895         7233 S Peoria St           NaN
# 238402         7656 S Morgan St       4 Baths
# 239883            535 E 26th St      -- baths
# 250910         4128 W Wilcox St       7 Baths
# 255881            17 Edwards St       4 Baths
# 262232         30 Stuyvesant St       3 Baths
# 266931  3344 W Shields Ave #101           NaN
# 271225             1345 65th Dr  Bathrooms: 8
# 275277       10739 S Wabash Ave       4 Baths
# 277563  525-27 Fayette Blvd #27       7 Baths
# 284102       309 311 William St  Bathrooms: 6
# 285830           120 Orchard St  Bathrooms: 6
# 301679   3839 W Washington Blvd       6 Baths
# 310332        9215 S Drexel Ave       3 Baths
# 313294       7046 S Normal Blvd       4 Baths
# 329198     3287 Washington Blvd       4 Baths
# 346254            17 Edwards St  Bathrooms: 4
# 352608           8524 Wingo Way       7 Baths
# 375309       2129 N Latrobe Ave       4 Baths
# 376081      8559 S Escanaba Ave       4 Baths
# 376203     3166 E Derbyshire Rd       4 Baths
#
#                                                 homeFacts fireplace  \
# 5835                  [2011, , , , , 3025 sqft, $37/sqft]       NaN
# 17965   [1965, , Baseboard, None, , 4,355 sqft, $127/s...       NaN
# 20786   [1880, , Baseboard, None, Attached Garage, 8,3...       NaN
# 22631   [1927, , Forced Air, Central, Detached Garage,...       NaN
# 43069                 [1925, , , , , 3001 sqft, $46/sqft]       NaN
# 47322                 [1970, , , , , 4791 sqft, $56/sqft]       NaN
# 65194          [1950, , Wall, Wall, , 0.5 acres lot, $87]       NaN
# 69582   [1960, , Gas, , Detached Garage, 3,720 sqft, N...       NaN
# 75157   [1924, , Forced Air, , Detached Garage, 3,780 ...       NaN
# 86894                 [1800, 1980, Other, , 2 spaces, , ]       NaN
# 101099  [1929, 1960, Forced Air, Central, Wall, , 4,72...       NaN
# 108328     [1915, , Forced Air, , None, 3,125 sqft, None]       NaN
# 112304               [1940, , Other, , , 2378 sqft, None]       NaN
# 124687  [1925, , Other, Central, Detached Garage, 6,25...       NaN
# 145781        [1895, , Forced Air, , 2, 2,976 sqft, None]       NaN
# 156139                [1905, , Gas, , 3, 4356 sqft, None]       NaN
# 164986               [1894, , , , , 7,565 sqft, $51/sqft]       NaN
# 170295  [1900, , Forced Air, Central, Detached Garage,...       NaN
# 176747  [1909, , Forced Air, Central, Detached Garage,...       yes
# 177457             [1920, , Gas, , , 3,959 sqft lot, $47]       NaN
# 186910            [1897, , Gas, , None, 3,024 sqft, None]       NaN
# 188811           [1905, , , , None, 4,687 sqft, $14/sqft]       NaN
# 198340       [1950, , Wall, Wall, , 0.50 acres, $87/sqft]       yes
# 212075    [1929, , , , Detached Garage, 3,750 sqft, None]       NaN
# 223895      [1920, , Other, , On Street, 3049 sqft, None]       NaN
# 238402  [1915, , Forced Air, , Detached Garage, 3,472 ...       NaN
# 239883  [1900, , Forced air, Central, , 5,662 sqft lot...       NaN
# 250910        [2010, , Forced Air, , 3, 3,025 sqft, None]       NaN
# 255881  [1960, , Forced Air, None, Off Street, , $74/s...       NaN
# 262232  [1950, , Forced Air, , Detached Garage, 7840 s...       NaN
# 266931  [1988, 1988, Forced Air, Central, Carport, 8,4...       yes
# 271225  [1964, 1964, Forced air, , 8 spaces, 0.28 acre...       NaN
# 275277  [1925, , Forced Air, , None, 4,059 sqft, $76/s...       NaN
# 277563      [1950, , Forced Air, , , 7365 sqft, $60/sqft]       yes
# 284102       [, , Electric, Gas, , , 6,534 sqft lot, $40]       NaN
# 285830                [1988, , , , , 0.33 acres lot, $75]       NaN
# 301679     [1892, , Other, , None, 4,000 sqft, $140/sqft]       NaN
# 310332  [1899, , Forced Air, Central, None, 4,650 sqft...       NaN
# 313294                [1910, , , , , 3920 sqft, $44/sqft]       NaN
# 329198  [1920, 1962, Forced Air, Central, Detached Gar...       yes
# 346254  [1910, , Forced air, , Off street, -- sqft lot...       NaN
# 352608  [1932, , Forced Air, Central, , 0.78 acres, $3...       NaN
# 375309    [1910, , Forced Air, , Detached Garage, , None]       NaN
# 376081               [1915, , Gas, , 2, 3,000 sqft, None]       NaN
# 376203  [1925, 1962, Forced Air, None, Detached Garage...       yes
#
#                      city                                            schools  \
# 5835              Chicago  {'rating': ['1/10', '5/10', '4/10'], 'data': {...
# 17965              Albany  {'rating': ['3/10', '3/10', '2/10'], 'data': {...
# 20786              Albany  {'rating': ['3/10', '3/10', '1/10'], 'data': {...
# 22631             Chicago  {'rating': ['1/10', '1/10', '2/10'], 'data': {...
# 43069        Philadelphia  {'rating': ['3/10', '1/10'], 'data': {'Distanc...
# 47322          Binghamton  {'rating': ['3/10', '4/10', '3/10'], 'data': {...
# 65194        Jacksonville  {'rating': ['1/10', '3/10', '4/10'], 'data': {...
# 69582             Chicago  {'rating': ['2/10', '3/10', '1/10'], 'data': {...
# 75157             Chicago  {'rating': ['1/10', '1/10', '2/10'], 'data': {...
# 86894           Worcester  {'rating': ['2/10', '4/10', '4/10'], 'data': {...
# 101099       Jacksonville  {'rating': ['4/10', '2/10', '3/10'], 'data': {...
# 108328            Chicago  {'rating': ['2/10', '1/10', '3/10'], 'data': {...
# 112304      Richmond Hill  {'rating': ['None/10', '7/10', '3/10', '6/10']...
# 124687            Houston  {'rating': ['6/10', '3/10'], 'data': {'Distanc...
# 145781            Chicago  {'rating': ['1/10', '6/10', '6/10', '2/10'], '...
# 156139            Chicago  {'rating': ['5/10', '1/10', '2/10'], 'data': {...
# 164986            Chicago  {'rating': ['1/10', '1/10', '6/10'], 'data': {...
# 170295         Cincinnati  {'rating': ['4/10', '2/10', '1/10', '1/10', '2...
# 176747         Cincinnati  {'rating': ['4/10', '2/10', '1/10', '1/10', '2...
# 177457          Rochester  {'rating': ['3/10', '2/10', '1/10'], 'data': {...
# 186910            Chicago  {'rating': ['1/10', '3/10', '4/10'], 'data': {...
# 188811            Chicago  {'rating': ['2/10', '1/10', '6/10'], 'data': {...
# 198340       Jacksonville  {'rating': ['1/10', '3/10', '4/10'], 'data': {...
# 212075            Chicago  {'rating': ['2/10', '6/10'], 'data': {'Distanc...
# 223895            Chicago  {'rating': ['1/10', '4/10', '1/10'], 'data': {...
# 238402            Chicago  {'rating': ['1/10', '4/10', '1/10'], 'data': {...
# 239883               Erie  {'rating': ['3/10', '3/10', '1/10'], 'data': {...
# 250910            Chicago  {'rating': ['1/10', '5/10', '4/10'], 'data': {...
# 255881         Binghamton  {'rating': ['3/10', '3/10', '3/10'], 'data': {...
# 262232         Binghamton  {'rating': ['2/10', '3/10', '2/10'], 'data': {...
# 266931             Fresno  {'rating': ['4/10', '3/10', '2/10'], 'data': {...
# 271225            Lubbock  {'rating': ['4/10', '2/10', '3/10'], 'data': {...
# 275277            Chicago  {'rating': ['1/10', '4/10', '1/10'], 'data': {...
# 277563           Syracuse  {'rating': ['4/10', '3/10'], 'data': {'Distanc...
# 284102           Scranton  {'rating': ['4/10', '4/10', '2/10'], 'data': {...
# 285830        Springfield  {'rating': ['3/10', 'NA', '1/10'], 'data': {'D...
# 301679            Chicago  {'rating': ['1/10', '2/10', '1/10'], 'data': {...
# 310332            Chicago  {'rating': ['7/10', '6/10', '5/10'], 'data': {...
# 313294            Chicago  {'rating': ['3/10', '1/10'], 'data': {'Distanc...
# 329198  Cleveland Heights  {'rating': ['4/10', '2/10', '4/10'], 'data': {...
# 346254         Binghamton  {'rating': ['3/10', '3/10'], 'data': {'Distanc...
# 352608            El Paso  {'rating': ['7/10', '5/10', '3/10'], 'data': {...
# 375309            Chicago  {'rating': ['1/10', '1/10', '5/10'], 'data': {...
# 376081            Chicago  {'rating': ['2/10', '1/10'], 'data': {'Distanc...
# 376203  Cleveland Heights  {'rating': ['4/10', '2/10', '4/10'], 'data': {...
#
#           sqft zipcode  beds state stories     mls-id PrivatePool       MlsId  \
# 5835    2301.0   60624    10    IL     NaN        NaN         NaN    10420955
# 17965   2301.0   12203    10    NY     NaN        NaN         NaN   201934408
# 20786   2301.0   12202    10    NY     NaN        NaN         NaN   201935177
# 22631   2301.0   60629    10    IL     NaN        NaN         NaN    10499159
# 43069   2301.0   19137    10    PA     3.0        NaN         NaN  PAPH853562
# 47322   2301.0   13905    10    NY     NaN        NaN         NaN      218528
# 65194   2301.0   32205    10    FL     1.0    1026741         NaN         NaN
# 69582   2301.0   60649    10    IL     NaN        NaN         NaN    10595167
# 75157   2301.0   60629    10    IL     NaN        NaN         NaN    10492455
# 86894   2301.0    1610    10    MA     3.0        NaN         NaN         NaN
# 101099  2301.0   32206    10    FL     1.0        NaN         NaN     1021516
# 108328  2301.0   60624    10    IL     NaN        NaN         NaN    10541868
# 112304  1740.0   11418    10    NY     NaN        NaN         NaN     3090721
# 124687  2301.0   77004    10    TX     2.0        NaN         NaN    45367527
# 145781  2301.0   60653    10    IL     NaN        NaN         NaN    10527143
# 156139  2301.0   60623    10    IL     NaN        NaN         NaN    10418896
# 164986  2301.0   60637    10    IL     NaN        NaN         NaN         NaN
# 170295  2301.0   45229    10    OH     2.0        NaN         NaN     1629011
# 176747  2301.0   45229    10    OH     2.0        NaN         NaN     1638709
# 177457  2301.0   14611    10    NY     2.0   R1236181         NaN         NaN
# 186910  2301.0   60609    10    IL     NaN        NaN         NaN    10462471
# 188811  2301.0   60621    10    IL     NaN        NaN         NaN    10572569
# 198340  2301.0   32205    10    FL       1        NaN         NaN     1026741
# 212075  2301.0   60620    10    IL     NaN        NaN         NaN    10529112
# 223895  1734.0   60621    10    IL     NaN        NaN         NaN    10424161
# 238402  2301.0   60620    10    IL     NaN        NaN         NaN    10594173
# 239883  2301.0   16504    10    PA     2.0     148196         NaN         NaN
# 250910  2301.0   60624    10    IL     NaN        NaN         NaN    10420955
# 255881  2301.0   13905    10    NY     NaN        NaN         NaN      220040
# 262232  2301.0   13901    10    NY     NaN        NaN         NaN      222854
# 266931  2301.0   93722    10    CA     NaN        NaN         yes      534850
# 271225  2301.0   79412    10    TX     2.0  201909614         NaN         NaN
# 275277  2301.0   60628    10    IL     NaN        NaN         NaN    10513180
# 277563  2301.0   13224    10    NY       2        NaN         NaN    S1187078
# 284102  2301.0   18508    10    PA     3.0    19-5064         NaN         NaN
# 285830  2301.0    1107    10    MA     NaN   72579413         NaN         NaN
# 301679  1500.0   60624    10    IL     NaN        NaN         NaN    10570106
# 310332  2301.0   60619    10    IL     NaN        NaN         NaN    10393773
# 313294  2301.0   60621    10    IL     NaN        NaN         NaN         NaN
# 329198  2301.0   44118    10    OH     2.0        NaN         NaN     4120043
# 346254  2301.0   13905    10    NY     NaN     220040         NaN         NaN
# 352608  2301.0   79907    10    TX     NaN        NaN         NaN      817342
# 375309  1603.0   60639    10    IL     NaN        NaN         NaN    10548543
# 376081  2301.0   60617    10    IL     NaN        NaN         NaN    10539126
# 376203  2301.0   44118    10    OH     2.0        NaN         NaN     4156317
#
#           target Year built Remodeled year                Heating  \
# 5835    179900.0       1968           1968             Forced Air
# 17965   445000.0       1955
# 20786   175000.0       1900                            Forced air
# 22631   269000.0       1910           1910              Baseboard
# 43069   529000.0       2016
# 47322   349000.0       1997           1997             Forced air
# 65194   449900.0       2019           None          Electric, Gas
# 69582   324995.0       1997                            Forced air
# 75157   217900.0
# 86894   244134.0
# 101099  148700.0       1973           1974             Forced Air
# 108328  265000.0                                              Gas
# 112304  400000.0       1956           2019             Forced air
# 124687  499900.0
# 145781  350000.0                                       Forced air
# 156139  299000.0       1979           1987   Central, Natural Gas
# 164986  281989.0       2003                 , Gas Hot Air/Furnace
# 170295  247500.0       1990                               Central
# 176747  239900.0       2007           2007             Forced air
# 177457  279900.0
# 186910  125000.0       1970                              Electric
# 188811   65000.0       1958                            Forced air
# 198340  449900.0
# 212075  210000.0       2003           2003       Central Electric
# 223895  175000.0       1986           1986           Window Units
# 238402  383000.0       2017                                 Other
# 239883   67500.0
# 250910  151000.0       1900           1970        Forced Air, Gas
# 255881  200000.0       1985
# 262232  160000.0       2005           2005                  Other
# 266931  375000.0       1973           1973            Central Air
# 271225  225000.0       1959                      Natural Gas Heat
# 275277  189000.0        NaN            NaN                    NaN
# 277563  205000.0        NaN            NaN                    NaN
# 284102  199000.0        NaN            NaN                    NaN
# 285830  299000.0        NaN            NaN                    NaN
# 301679  210000.0        NaN            NaN                    NaN
# 310332  145500.0        NaN            NaN                    NaN
# 313294  175000.0        NaN            NaN                    NaN
# 329198  249900.0        NaN            NaN                    NaN
# 346254  200000.0        NaN            NaN                    NaN
# 352608  190000.0        NaN            NaN                    NaN
# 375309  349000.0        NaN            NaN                    NaN
# 376081  267500.0        NaN            NaN                    NaN
# 376203  185000.0        NaN            NaN                    NaN
#
#                                  Cooling  \
# 5835
# 17965                            Central
# 20786
# 22631                               Wall
# 43069
# 47322                            Central
# 65194                            Central
# 69582                            Central
# 75157
# 86894
# 101099                           Central
# 108328
# 112304                           Central
# 124687
# 145781                           Central
# 156139                       Central Air
# 164986  Central Air, Gas Hot Air/Furnace
# 170295                       Central Air
# 176747                           Central
# 177457
# 186910
# 188811                           Central
# 198340
# 212075                       Central Gas
# 223895                       Window Unit
# 238402                           Central
# 239883
# 250910                           Central
# 255881                  Central Electric
# 262232                           Central
# 266931                       Has Cooling
# 271225                   Central Heating
# 275277                               NaN
# 277563                               NaN
# 284102                               NaN
# 285830                               NaN
# 301679                               NaN
# 310332                               NaN
# 313294                               NaN
# 329198                               NaN
# 346254                               NaN
# 352608                               NaN
# 375309                               NaN
# 376081                               NaN
# 376203                               NaN
#
#                                              Parking         lotsize  \
# 5835                        Carport, Attached Garage
# 17965                                Detached Garage      4,375 sqft
# 20786   Off street, Attached Garage, Detached Garage  5,662 sqft lot
# 22631                                Attached Garage      2,800 sqft
# 43069                                                     9,217 sqft
# 47322                                      On street  7,671 sqft lot
# 65194                                Attached Garage      5,384 sqft
# 69582                                                    -- sqft lot
# 75157                                                  9,999 Sq. Ft.
# 86894                                                         218671
# 101099                                    Off Street        721 sqft
# 108328                                                    0.65 acres
# 112304                                       1 space      7,997 sqft
# 124687                                                         46609
# 145781                               Attached Garage      5,192 sqft
# 156139                                                             —
# 164986     Attached Garage, Driveway, Garage - 2 Car           10890
# 170295                                                          9999
# 176747                               Attached Garage            None
# 177457                                                 7,150 Sq. Ft.
# 186910                                          None      0.76 acres
# 188811                                       Carport      9,644 sqft
# 198340                                                          None
# 212075                                                 5,693 Sq. Ft.
# 223895                                                 3,657 Sq. Ft.
# 238402                               Attached Garage      3,027 sqft
# 239883                                                   10,454 sqft
# 250910                                                 4,500 Sq. Ft.
# 255881                                             1            None
# 262232                               Attached Garage      8,205 sqft
# 266931                                                             —
# 271225                                                 6,195 Sq. Ft.
# 275277                                           NaN             NaN
# 277563                                           NaN             NaN
# 284102                                           NaN             NaN
# 285830                                           NaN             NaN
# 301679                                           NaN             NaN
# 310332                                           NaN             NaN
# 313294                                           NaN             NaN
# 329198                                           NaN             NaN
# 346254                                           NaN             NaN
# 352608                                           NaN             NaN
# 375309                                           NaN             NaN
# 376081                                           NaN             NaN
# 376203                                           NaN             NaN
#
#             price_sqft                                        rating  \
# 5835         $247/sqft  ['4/10', '8/10', '10/10', '2/10', 'None/10']
# 17965        $277/sqft                      ['1/10', '9/10', '8/10']
# 20786              $57                      ['3/10', '1/10', '4/10']
# 22631        $478/sqft                                      ['3/10']
# 43069        $121/sqft                      ['6/10', '7/10', '6/10']
# 47322             $132                      ['9/10', '3/10', '7/10']
# 65194              $98                      ['3/10', '5/10', '2/10']
# 69582             $120                      ['3/10', '4/10', '2/10']
# 75157             None                               ['5', '4', '6']
# 86894             None                                    ['7', '6']
# 101099       $281/sqft                      ['6/10', '2/10', '4/10']
# 108328            None                                      ['4/10']
# 112304            $205                                      ['5/10']
# 124687            None          ['4', '6', '6', '8', '4', '2', 'NR']
# 145781            $223                      ['4/10', '7/10', '7/10']
# 156139  $107 / Sq. Ft.                               ['4', '3', '4']
# 164986             $93   ['4', '2', '2', '3', '3', 'NR', 'NR', 'NR']
# 170295            $113    ['5', '7', '6', '6', '2', '5', 'NR', 'NR']
# 176747            $380                             ['10/10', '4/10']
# 177457            None                               ['9', '6', '7']
# 186910       $199/sqft                              ['6/10', '4/10']
# 188811             $75                      ['4/10', '3/10', '3/10']
# 198340            $126    ['8', '9', '4', '8', '8', '5', 'NR', 'NR']
# 212075  $103 / Sq. Ft.                     ['4', '4', '6', '1', '5']
# 223895  $184 / Sq. Ft.                          ['7', '3', '4', '4']
# 238402       $166/sqft                      ['3/10', '3/10', '2/10']
# 239883            None                      ['4/10', '4/10', '3/10']
# 250910  $104 / Sq. Ft.                               ['5', '6', '6']
# 255881            $184   ['7', '7', '1', '10', '2', '9', 'NR', 'NR']
# 262232       $132/sqft                      ['7/10', '3/10', '5/10']
# 266931            None                   ['6', '10', 'NR', '3', '6']
# 271225   $83 / Sq. Ft.                   ['2', 'NR', 'NR', '4', '1']
# 275277             NaN                                           NaN
# 277563             NaN                                           NaN
# 284102             NaN                                           NaN
# 285830             NaN                                           NaN
# 301679             NaN                                           NaN
# 310332             NaN                                           NaN
# 313294             NaN                                           NaN
# 329198             NaN                                           NaN
# 346254             NaN                                           NaN
# 352608             NaN                                           NaN
# 375309             NaN                                           NaN
# 376081             NaN                                           NaN
# 376203             NaN                                           NaN
#
#                                                  Distance  \
# 5835    ['2.5mi', '0.38mi', '21.6mi', '1.75mi', '16.94...
# 17965                     ['15.06mi', '0.51mi', '2.12mi']
# 20786                        ['0.1 mi', '1.3 mi', '1 mi']
# 22631                                          ['0.06mi']
# 43069                      ['0.83mi', '1.04mi', '1.16mi']
# 47322                      ['2.4 mi', '2.8 mi', '2.9 mi']
# 65194                        ['2 mi', '5.2 mi', '2.7 mi']
# 69582                      ['5.4 mi', '6.8 mi', '6.2 mi']
# 75157                      ['4.6 mi', '2.2 mi', '2.6 mi']
# 86894                                ['5.2 mi', '5.0 mi']
# 101099                     ['0.76mi', '2.02mi', '2.45mi']
# 108328                                         ['8.96mi']
# 112304                                         ['0.6 mi']
# 124687  ['1.6 mi', '0.8 mi', '2.6 mi', '2.2 mi', '4.8 ...
# 145781                     ['0.5 mi', '1.1 mi', '1.4 mi']
# 156139                     ['1.1 mi', '1.2 mi', '1.7 mi']
# 164986  ['1.6 mi', '4.1 mi', '4.1 mi', '1.5 mi', '3.3 ...
# 170295  ['0.6 mi', '1.6 mi', '5.4 mi', '1.8 mi', '3.6 ...
# 176747                              ['19.7 mi', '2.7 mi']
# 177457                     ['2.0 mi', '4.6 mi', '5.4 mi']
# 186910                               ['0.29mi', '1.18mi']
# 188811                     ['1.9 mi', '0.3 mi', '0.3 mi']
# 198340  ['0.8 mi', '3.2 mi', '1.1 mi', '1.2 mi', '3.4 ...
# 212075  ['1.7 mi', '5.6 mi', '2.7 mi', '1.7 mi', '5.9 ...
# 223895           ['1.0 mi', '0.9 mi', '1.2 mi', '0.9 mi']
# 238402                     ['1.56mi', '0.38mi', '3.68mi']
# 239883                     ['4.15mi', '1.11mi', '1.28mi']
# 250910                     ['0.4 mi', '0.6 mi', '2.4 mi']
# 255881  ['0.6 mi', '1.4 mi', '2.0 mi', '0.7 mi', '0.9 ...
# 262232                     ['1.44mi', '1.28mi', '1.94mi']
# 266931  ['1.3 mi', '30.4 mi', '25.2 mi', '1.5 mi', '1....
# 271225  ['0.2 mi', '0.5 mi', '0.7 mi', '0.8 mi', '1.8 ...
# 275277                                                NaN
# 277563                                                NaN
# 284102                                                NaN
# 285830                                                NaN
# 301679                                                NaN
# 310332                                                NaN
# 313294                                                NaN
# 329198                                                NaN
# 346254                                                NaN
# 352608                                                NaN
# 375309                                                NaN
# 376081                                                NaN
# 376203                                                NaN
#
#                                                    Grades  \
# 5835               ['6-8', 'PK-5', 'PK-8', '9-12', 'K-9']
# 17965                             ['9-12', 'K-8', '7-12']
# 20786                             ['PK-4', '5-8', '9-12']
# 22631                                            ['PK-8']
# 43069                             ['9-12', '6-8', 'PK-5']
# 47322                             ['PK-8', '6-8', '9-12']
# 65194                             ['PK-5', '6-8', '9-12']
# 69582                              ['K-3', '6-8', '9-12']
# 75157             ['Preschool to 5', '6 to 8', '9 to 12']
# 86894                                     ['K–6', '7–12']
# 101099                            ['PK-5', '9-12', '6-8']
# 108328                                           ['9-12']
# 112304                                          ['PK-12']
# 124687  ['PK–5', '6–8', '9–12', 'PK–5', '6–12', '9–12'...
# 145781                             ['K-5', '6-8', '9-12']
# 156139            ['Preschool to 5', '6 to 8', '9 to 12']
# 164986  ['PK–5', '6–8', '9–12', 'K–7', '6–8', '2–2', '...
# 170295  ['PK–5', '6–8', '9–12', 'PK–5', 'PK–12', '6–12...
# 176747                                   ['PK-8', '9-12']
# 177457            ['Preschool to 5', '6 to 8', '9 to 12']
# 186910                                   ['PK-8', '9-12']
# 188811                            ['PK-5', '6-8', '9-12']
# 198340  ['PK–5', '6–8', '9–12', 'PK–5', '6–8', '9–12',...
# 212075  ['Preschool to 5', '6 to 8', '6 to 8', '9 to 1...
# 223895          ['1 to 3', '5 to 6', '7 to 8', '9 to 12']
# 238402                            ['5-8', 'PK-5', '9-12']
# 239883                            ['9-12', '7-8', 'PK-6']
# 250910                    ['K to 5', '6 to 8', '9 to 12']
# 255881  ['PK–5', '6–8', '9–12', 'PK–7', 'PK–12', '9–12...
# 262232                            ['9-12', 'PK-5', '6-8']
# 266931  ['Preschool to 8', 'Preschool to 8', 'K to 9',...
# 271225  ['Preschool to 7', '5 to 12', '3 to 8', 'Presc...
# 275277                                                NaN
# 277563                                                NaN
# 284102                                                NaN
# 285830                                                NaN
# 301679                                                NaN
# 310332                                                NaN
# 313294                                                NaN
# 329198                                                NaN
# 346254                                                NaN
# 352608                                                NaN
# 375309                                                NaN
# 376081                                                NaN
# 376203                                                NaN
#
#                                                      name  sqft_big
# 5835    ['Shenandoah Middle School', 'Southside Elemen...         1
# 17965   ['Hope College Prep High School', 'Edgebrook E...         1
# 20786   ['Lincoln Primary Center', 'Marshall Intermedi...         1
# 22631                               ['Ps Ms 42 R Vernam']         1
# 43069   ['Northwest High School', 'Gene Pike Middle Sc...         1
# 47322   ['Windy Ridge K-8', 'Chain Of Lakes Middle Sch...         1
# 65194   ['Hoyland Elementary School', 'Dueitt Middle S...         1
# 69582   ['Avalon Elementary School', 'Woodward Park Mi...         1
# 75157   ['Liberty Elementary School', 'Murdock Middle ...         1
# 86894   ['Saranac Elementary School', 'Saranac Jr/Sr H...         1
# 101099  ['Mcnab Elementary School', 'Northeast High Sc...         1
# 108328                         ['Southridge High School']         1
# 112304                          ['Northeast High School']         0
# 124687  ['Soddy Elementary School', 'Soddy Daisy Middl...         1
# 145781  ['Orchard Elementary School', 'Daniel J. Savag...         1
# 156139  ['Marjorie Kinnan Rawlings Elementary School',...         1
# 164986  ['University Meadows Elementary School', 'Jame...         1
# 170295  ['Kingsway Elementary School', 'Port Charlotte...         1
# 176747  ['Air Base Elementary School', 'Miami Senior H...         1
# 177457  ['Leon Springs Elementary School', 'Rawlinson ...         1
# 186910    ['Goudy Elementary School', 'Senn High School']         1
# 188811  ['John Snively Elementary School', 'Denison Mi...         1
# 198340  ['Charles Borchers Elementary School', 'Trautm...         1
# 212075  ['Carolee Booker Elementary School', 'Rickey C...         1
# 223895  ['Anderson Academy', 'Houston Academy', 'Drew ...         0
# 238402  ['Landrum Middle School', 'Housman Elementary ...         1
# 239883  ['Heritage High School', 'Southwest Middle Sch...         1
# 250910  ['Cedar Heights Elementary School', 'General S...         1
# 255881  ['School at St. George Place', 'Grady Middle S...         1
# 262232  ['A. Crawford Mosley High School', 'Hiland Par...         1
# 266931  ['David Lawrence Jr. K-8 Center', 'Air Base El...         1
# 271225  ['Foster Elementary School', 'Seidel Learning ...         1
# 275277                                                NaN         1
# 277563                                                NaN         1
# 284102                                                NaN         1
# 285830                                                NaN         1
# 301679                                                NaN         0
# 310332                                                NaN         1
# 313294                                                NaN         1
# 329198                                                NaN         1
# 346254                                                NaN         1
# 352608                                                NaN         1
# 375309                                                NaN         0
# 376081                                                NaN         1
# 376203                                                NaN         1

# %%
#data_d.loc[[data_d['beds'] == 10 & data_d['target']<150000]]

# %%
#data_d = data_d.drop(data_d[[data_d['beds'] == 10] & data_d[data_d['target']<150000]].index)

# %%
#data_d.loc[data_d['beds']==10]

# %% [markdown]
# # Визуализация и обработка признака спальни (beds).

# %%
data_d['beds_big']= data_d['beds'].apply(lambda x: 1 if x>7 else 0)

# %%
data_d.beds = data_d.beds.apply(lambda x: 11 if x>10 else x)

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274467 entries, 0 to 377184
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          245007 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250827 non-null  object
#  3   street          274466 non-null  object
#  4   baths           192550 non-null  object
#  5   homeFacts       274467 non-null  object
#  6   fireplace       66993 non-null   object
#  7   city            274447 non-null  object
#  8   schools         274467 non-null  object
#  9   sqft            274467 non-null  float64
#  10  zipcode         274467 non-null  object
#  11  beds            274467 non-null  int64
#  12  state           274467 non-null  object
#  13  stories         167742 non-null  object
#  14  mls-id          19144 non-null   object
#  15  PrivatePool     22559 non-null   object
#  16  MlsId           224520 non-null  object
#  17  target          274467 non-null  float64
#  18  Year built      197552 non-null  object
#  19  Remodeled year  186648 non-null  object
#  20  Heating         197614 non-null  object
#  21  Cooling         197614 non-null  object
#  22  Parking         197614 non-null  object
#  23  lotsize         184643 non-null  object
#  24  price_sqft      167356 non-null  object
#  25  rating          199601 non-null  object
#  26  Distance        199601 non-null  object
#  27  Grades          199601 non-null  object
#  28  name            199601 non-null  object
#  29  sqft_big        274467 non-null  int64
#  30  beds_big        274467 non-null  int64
# dtypes: float64(2), int64(3), object(26)
# memory usage: 75.1+ MB

# %%
data_d['beds'].isna().sum()
# Out:
# 0

# %%
sns.distplot(data_d['beds'])
# Out:
# <AxesSubplot:xlabel='beds', ylabel='Density'>

# %%
y = data_d['target']

# %%
x = data_d['beds']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Количество комнат', fontsize = 15)
plt.ylabel('Цена', fontsize = 15)
plt.title('Зависимость цены от количества комнат', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от количества комнат')

# %%
sns.boxplot(data_d['beds'])
# Out:
# <AxesSubplot:xlabel='beds'>

# %% [markdown]
# # Ванны - приведение к численному виду.

# %% [markdown]
# Вспомогательная функция извлекает численное значение из текста. Если значение некорректно, выдает 1. Применила здесь, а также для обработки этажей.)

# %%
def extract_num_recurr(stroka,first_digit,len_s,i):
    if i == len_s and stroka[i].isdigit():
        return (float(first_digit + str(stroka[i])))
    elif i < len_s and (stroka[i].isdigit() or stroka[i] == '.'):
        return extract_num_recurr(stroka, (first_digit + str(stroka[i])), len_s, i+1)
    
    else: return(float(first_digit))
                        
def extract_num(stroka,len_s,i):
  
    if i == len_s and not stroka[i].isdigit():
        return 1
    elif i == len_s and stroka[i].isdigit():
        return float(stroka[i])
    elif i < len_s and stroka[i].isdigit():
        return extract_num_recurr(stroka,str(stroka[i]),len_s,i+1)
    else: return extract_num(stroka,len_s,i+1)

def main_extract_num(stroka):   
    len_s=len(stroka)-1
    
    return extract_num(stroka,len_s,0)

# %%
data_d.baths = data_d.baths.apply(lambda x: round(main_extract_num(str(x)),1))

# %%
data_d['baths'].unique()
# Out:
# array([3.50e+00, 3.00e+00, 1.00e+00, 2.00e+00, 4.00e+00, 2.10e+00,
#        2.50e+00, 4.50e+00, 5.50e+00, 1.50e+00, 0.00e+00, 7.50e+02,
#        5.00e+00, 6.00e+00, 7.00e+00, 8.00e+00, 1.90e+01, 1.80e+00,
#        1.30e+01, 1.10e+00, 1.20e+01, 2.41e+02, 6.50e+00, 1.40e+01,
#        2.20e+01, 2.20e+00, 1.80e+01, 1.00e+01, 2.80e+00, 1.60e+01,
#        1.10e+01, 1.50e+01, 3.80e+00, 3.20e+00, 9.00e+00, 1.20e+00,
#        2.00e+01, 2.50e+01, 5.00e-01, 8.50e+00, 3.10e+00, 3.00e+01,
#        8.00e-01, 1.70e+01, 4.10e+00, 2.80e+01])

# %%
data_d['baths'].isna().sum()
# Out:
# 0

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274467 entries, 0 to 377184
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          245007 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250827 non-null  object
#  3   street          274466 non-null  object
#  4   baths           274467 non-null  float64
#  5   homeFacts       274467 non-null  object
#  6   fireplace       66993 non-null   object
#  7   city            274447 non-null  object
#  8   schools         274467 non-null  object
#  9   sqft            274467 non-null  float64
#  10  zipcode         274467 non-null  object
#  11  beds            274467 non-null  int64
#  12  state           274467 non-null  object
#  13  stories         167742 non-null  object
#  14  mls-id          19144 non-null   object
#  15  PrivatePool     22559 non-null   object
#  16  MlsId           224520 non-null  object
#  17  target          274467 non-null  float64
#  18  Year built      197552 non-null  object
#  19  Remodeled year  186648 non-null  object
#  20  Heating         197614 non-null  object
#  21  Cooling         197614 non-null  object
#  22  Parking         197614 non-null  object
#  23  lotsize         184643 non-null  object
#  24  price_sqft      167356 non-null  object
#  25  rating          199601 non-null  object
#  26  Distance        199601 non-null  object
#  27  Grades          199601 non-null  object
#  28  name            199601 non-null  object
#  29  sqft_big        274467 non-null  int64
#  30  beds_big        274467 non-null  int64
# dtypes: float64(3), int64(3), object(25)
# memory usage: 75.1+ MB

# %% [markdown]
# # Визуализация и обработка признака ванны (baths).

# %%
sns.distplot(data_d['baths'])
# Out:
# <AxesSubplot:xlabel='baths', ylabel='Density'>

# %%
data_d.loc[data_d['baths']>10]
# Out:
#           status private pool                         propertyType  \
# 1109      Active          NaN  Attached or 1/2 Duplex, Traditional
# 3594      Active          NaN                                  NaN
# 6031    for sale          NaN                   single-family home
# 6467    for sale          NaN                   single-family home
# 7693      Active          NaN                       Condo/Townhome
# ...          ...          ...                                  ...
# 366559    Active          NaN                                  NaN
# 372603    Active          NaN                                  NaN
# 375634    Active          NaN  Condo/Townhome, Contemporary/Modern
# 376012    Active          NaN  Condo/Townhome, Other (See Remarks)
# 376147    Active          NaN              Condo/Townhome, Hi-Rise
#
#                                street  baths  \
# 1109                3624 Douglas Ave   750.0
# 3594             601 W 11th Ave #409   750.0
# 6031                 3206 Briscoe Trl   19.0
# 6467                  15044 120th Ave   13.0
# 7693      3314 Douglas Ave Unit 202D   750.0
# ...                               ...    ...
# 366559               1374 N Yates St   750.0
# 372603  601 Pennsylvania Ave NW #212   750.0
# 375634  3225 Turtle Creek Blvd #1646   750.0
# 376012            2262 Alterbrook Ln   750.0
# 376147   3225 Turtle Creek Blvd #528   750.0
#
#                                                 homeFacts fireplace  \
# 1109    [1993, 1993, , Central A/C (Electric), Central...         1
# 3594    [1981, , Forced Air, Natural Gas, Central Air,...       NaN
# 6031    [2007, , Forced Air, Central, Attached Garage,...       yes
# 6467                [2008, , , , , 2,247 sqft, $452/sqft]       NaN
# 7693    [1984, , , Central A/C (Gas), Central Heat (Ga...         3
# ...                                                   ...       ...
# 366559  [2019, , Forced Air, Natural Gas, Central Air,...       NaN
# 372603                  [1991, , , , , —, $561 / Sq. Ft.]       NaN
# 375634  [1998, 1998, , Central A/C (Electric), Central...       NaN
# 376012  [2019, , , Central A/C (Electric), Central Hea...       NaN
# 376147  [1998, 1998, , Central A/C (Electric), Central...       NaN
#
#                city                                            schools  \
# 1109         Dallas  {'rating': ['5', '5', '2', '10'], 'data': {'Di...
# 3594         DENVER  {'rating': ['5', 'NR', '5', '2'], 'data': {'Di...
# 6031    San Antonio  {'rating': ['7/10', '7/10'], 'data': {'Distanc...
# 6467        Jamaica  {'rating': ['5/10', '3/10'], 'data': {'Distanc...
# 7693         Dallas  {'rating': ['4', '3', '2', '10'], 'data': {'Di...
# ...             ...                                                ...
# 366559       DENVER  {'rating': ['2', '2', '2'], 'data': {'Distance...
# 372603   Washington  {'rating': ['8', '8', '3', '5'], 'data': {'Dis...
# 375634       Dallas  {'rating': ['5', '5', '2', '10'], 'data': {'Di...
# 376012       Dallas  {'rating': ['4', '3', '2', '10'], 'data': {'Di...
# 376147       Dallas  {'rating': ['5', '5', '2', '10'], 'data': {'Di...
#
#           sqft zipcode  beds state stories mls-id PrivatePool       MlsId  \
# 1109    1758.0   75219     1    TX     NaN    NaN         NaN    14240509
# 3594     873.0   80204     1    CO     NaN    NaN         NaN     7106586
# 6031    2301.0   78253     5    TX     2.0    NaN         yes     1429315
# 6467    1162.0   11434     3    NY       2    NaN         NaN      9JLBZQ
# 7693    1336.0   75219     1    TX       3    NaN         NaN    14237911
# ...        ...     ...   ...   ...     ...    ...         ...         ...
# 366559  1181.0   80204     1    CO     NaN    NaN         NaN     1592091
# 372603   801.0   20004     1    DC     NaN    NaN         NaN  DCDC444552
# 375634   832.0   75219     1    TX     NaN    NaN         NaN    14215205
# 376012  2102.0   75219     1    TX     NaN    NaN         NaN    14204976
# 376147   837.0   75219     1    TX      22    NaN         NaN    14222399
#
#           target Year built Remodeled year     Heating  Cooling  \
# 1109    499000.0       None           None        None     None
# 3594    348900.0       2006           2006  Forced Air  Central
# 6031    369000.0       1976           1977  Forced Air  Central
# 6467    525000.0       1950                 Forced Air  Central
# 7693    285000.0       2017
# ...          ...        ...            ...         ...      ...
# 366559  449900.0        NaN            NaN         NaN      NaN
# 372603  449000.0        NaN            NaN         NaN      NaN
# 375634  219500.0        NaN            NaN         NaN      NaN
# 376012  464900.0        NaN            NaN         NaN      NaN
# 376147  240000.0        NaN            NaN         NaN      NaN
#
#                 Parking     lotsize price_sqft  \
# 1109               None        None       None
# 3594    Attached Garage  4,420 sqft  $165/sqft
# 6031                                 $155/sqft
# 6467         Off Street  7,170 sqft  $109/sqft
# 7693                     7,492 sqft  $190/sqft
# ...                 ...         ...        ...
# 366559              NaN         NaN        NaN
# 372603              NaN         NaN        NaN
# 375634              NaN         NaN        NaN
# 376012              NaN         NaN        NaN
# 376147              NaN         NaN        NaN
#
#                                                    rating  \
# 1109                               ['NA', '9/10', '8/10']
# 3594    ['3/10', '8/10', '4/10', '5/10', '6/10', '5/10...
# 6031                             ['6/10', '3/10', '6/10']
# 6467    ['4/10', '4/10', '2/10', '6/10', 'None/10', '3...
# 7693                             ['3/10', '3/10', '5/10']
# ...                                                   ...
# 366559                                                NaN
# 372603                                                NaN
# 375634                                                NaN
# 376012                                                NaN
# 376147                                                NaN
#
#                                                  Distance  \
# 1109                       ['2.2 mi', '3.8 mi', '5.1 mi']
# 3594    ['13.73mi', '10.69mi', '17.81mi', '13.02mi', '...
# 6031                       ['0.93mi', '0.13mi', '1.71mi']
# 6467    ['0.92mi', '0.82mi', '0.3mi', '1.17mi', '0.73m...
# 7693                       ['4.23mi', '1.21mi', '0.95mi']
# ...                                                   ...
# 366559                                                NaN
# 372603                                                NaN
# 375634                                                NaN
# 376012                                                NaN
# 376147                                                NaN
#
#                                                    Grades  \
# 1109                              ['PK-5', '6-8', '9-12']
# 3594    ['9-12', 'PK-5', 'PK-5', '6-8', '6-8', 'PK-5',...
# 6031                              ['6-8', 'PK-8', '9-12']
# 6467            ['5', '9-12', 'PK-4', '7-8', '9-12', '6']
# 7693                              ['9-12', '6-8', 'PK-5']
# ...                                                   ...
# 366559                                                NaN
# 372603                                                NaN
# 375634                                                NaN
# 376012                                                NaN
# 376147                                                NaN
#
#                                                      name  sqft_big  beds_big
# 1109    ['Ellison Elementary School', 'Garcia Middle S...         0         0
# 3594    ['South Fort Myers High School', 'Rayma C. Pag...         0         0
# 6031    ['Coral Springs Middle School', 'Coral Springs...         1         0
# 6467    ['Dan Powell Intermediate School', 'Everman Hi...         0         0
# 7693    ['Prairie View High School', 'Otho E Stuart Mi...         0         0
# ...                                                   ...       ...       ...
# 366559                                                NaN         0         0
# 372603                                                NaN         0         0
# 375634                                                NaN         0         0
# 376012                                                NaN         0         0
# 376147                                                NaN         0         0
#
# [179 rows x 31 columns]

# %%
data_d = data_d[data_d['baths']<10]

# %%
sns.distplot(data_d['baths'])
# Out:
# <AxesSubplot:xlabel='baths', ylabel='Density'>

# %%
x = data_d['baths']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Оборудование ванн', fontsize = 15)
plt.title('Зависимость цены от оборудования ванн', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от оборудования ванн')

# %% [markdown]
#  # Камин

# %% [markdown]
# Вспомогательная функция для приведения признака числа каминов к численному виду.

# %%
def fireplaces_def(stroka):
    if stroka == 'yes': return 1
    elif stroka == 'Yes': return 1
    elif stroka == '1': return 1
    elif stroka == '2': return 2
    else: return 0

# %%
data_d.fireplace = data_d.fireplace.apply(lambda x: fireplaces_def(str(x)))

# %%
data_d['fireplace'].unique()
# Out:
# array([0, 1, 2])

# %%
data_d['fireplace'].isna().sum()
# Out:
# 0

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274282 entries, 0 to 377184
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   status          244823 non-null  object
#  1   private pool    2712 non-null    object
#  2   propertyType    250666 non-null  object
#  3   street          274281 non-null  object
#  4   baths           274282 non-null  float64
#  5   homeFacts       274282 non-null  object
#  6   fireplace       274282 non-null  int64
#  7   city            274262 non-null  object
#  8   schools         274282 non-null  object
#  9   sqft            274282 non-null  float64
#  10  zipcode         274282 non-null  object
#  11  beds            274282 non-null  int64
#  12  state           274282 non-null  object
#  13  stories         167675 non-null  object
#  14  mls-id          19140 non-null   object
#  15  PrivatePool     22557 non-null   object
#  16  MlsId           224341 non-null  object
#  17  target          274282 non-null  float64
#  18  Year built      197418 non-null  object
#  19  Remodeled year  186522 non-null  object
#  20  Heating         197480 non-null  object
#  21  Cooling         197480 non-null  object
#  22  Parking         197480 non-null  object
#  23  lotsize         184517 non-null  object
#  24  price_sqft      167237 non-null  object
#  25  rating          199466 non-null  object
#  26  Distance        199466 non-null  object
#  27  Grades          199466 non-null  object
#  28  name            199466 non-null  object
#  29  sqft_big        274282 non-null  int64
#  30  beds_big        274282 non-null  int64
# dtypes: float64(3), int64(4), object(24)
# memory usage: 67.0+ MB

# %%
x = data_d['fireplace']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Камин', fontsize = 15)
plt.title('Зависимость цены от наличия камина', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от наличия камина')

# %% [markdown]
# # Бассейн. Анализ.

# %%
data_d['private pool'].value_counts()
# Out:
# Yes    2712
# Name: private pool, dtype: int64

# %%
data_d.loc[data_d['private pool'] == 'Yes']
# Out:
#                            status private pool           propertyType  \
# 205                      For sale          Yes          Single Family
# 321                      For sale          Yes          Single Family
# 355                      For sale          Yes  Mobile / Manufactured
# 425     Pre-foreclosure / auction          Yes          Single Family
# 447                      For sale          Yes          Single Family
# ...                           ...          ...                    ...
# 376298            Pre-foreclosure          Yes          Single Family
# 376340                   For sale          Yes                  Condo
# 376582                   For sale          Yes          Single Family
# 376686                   For sale          Yes          Single Family
# 376694                   For sale          Yes                  Condo
#
#                              street  baths  \
# 205                  1403 Betton Rd    2.0
# 321              3296 Ledgewood Cir    3.0
# 355            2250 N Broadway # 42    2.0
# 425                7632 Hillside Dr    2.0
# 447       5370 Christie Ann Pl # 17    2.0
# ...                             ...    ...
# 376298            15369 Daybreak Ln    3.0
# 376340  200 River Vista Dr UNIT 436    2.0
# 376582           3235 Landover Blvd    2.0
# 376686          2609 S Marigold Ave    3.0
# 376694    5980 Shore Blvd S APT 312    3.0
#
#                                                 homeFacts  fireplace  \
# 205     [1958, 1980, Heat pump, Central, 1 space, 0.45...          1
# 321     [2017, , Forced air, Central, 2 spaces, 3,484 ...          0
# 355     [1976, , Forced air, Central, 2 spaces, -- sqf...          0
# 425     [1964, 1964, Forced air, Central, , 8,624 sqft, ]          1
# 447     [1992, 1992, Forced air, Central, Attached Gar...          0
# ...                                                   ...        ...
# 376298  [1990, 2007, Other, Central, 3 spaces, 6,011 s...          1
# 376340  [2010, , Forced air, Central, Attached Garage,...          0
# 376582  [2005, 2005, Other, Central, 1 space, 10,741 s...          0
# 376686  [1979, 1979, Forced air, Central, 2 spaces, 7,...          0
# 376694  [1972, 1981, Forced air, Central, 1 space, -- ...          0
#
#                 city                                            schools  \
# 205      Tallahassee  {'rating': ['4/10', '5/10', '7/10'], 'data': {...
# 321        Riverside  {'rating': ['4/10', '4/10', '6/10'], 'data': {...
# 355        Escondido  {'rating': ['4/10', '4/10', '6/10'], 'data': {...
# 425     Jacksonville  {'rating': ['5/10', '2/10', '4/10'], 'data': {...
# 447         Sarasota  {'rating': ['10/10', '9/10', '6/10'], 'data': ...
# ...              ...                                                ...
# 376298       Fontana  {'rating': ['4/10', '3/10', '4/10'], 'data': {...
# 376340       Atlanta  {'rating': ['9/10', '6/10', '6/10'], 'data': {...
# 376582   Spring Hill  {'rating': ['4/10', '6/10'], 'data': {'Distanc...
# 376686       Ontario  {'rating': ['7/10', '6/10', '5/10'], 'data': {...
# 376694      Gulfport  {'rating': ['2/10', '2/10', '4/10'], 'data': {...
#
#           sqft zipcode  beds state stories      mls-id PrivatePool MlsId  \
# 205     2301.0   32308     3    FL     NaN      302221         NaN   NaN
# 321     2135.0   92503     3    CA     2.0  IV19242188         NaN   NaN
# 355     1536.0   92026     2    CA     0.0   190034991         NaN   NaN
# 425     1245.0   32221     3    FL     1.0         NaN         NaN   NaN
# 447     1936.0   34233     3    FL     1.0    O5821850         NaN   NaN
# ...        ...     ...   ...   ...     ...         ...         ...   ...
# 376298  2225.0   92337     5    CA     2.0         NaN         NaN   NaN
# 376340  1299.0   30339     2    GA     1.0     8690633         NaN   NaN
# 376582  2256.0   34609     4    FL     1.0     2204520         NaN   NaN
# 376686  1726.0   91761     3    CA     2.0  IV19252050         NaN   NaN
# 376694  2210.0   33707     2    FL     9.0    U8064383         NaN   NaN
#
#           target Year built Remodeled year           Heating          Cooling  \
# 205     385000.0       1973           1973  Central Electric      Central Gas
# 321     525000.0       1955
# 355     119000.0                                  Forced Air          Central
# 425     128103.0       1959                            Other          Central
# 447     258000.0       1986                    Electric Heat  Central Heating
# ...          ...        ...            ...               ...              ...
# 376298  399094.0        NaN            NaN               NaN              NaN
# 376340  295000.0        NaN            NaN               NaN              NaN
# 376582  225000.0        NaN            NaN               NaN              NaN
# 376686  479000.0        NaN            NaN               NaN              NaN
# 376694  435000.0        NaN            NaN               NaN              NaN
#
#                 Parking        lotsize      price_sqft  \
# 205                      7,480 Sq. Ft.  $110 / Sq. Ft.
# 321                      8,190 Sq. Ft.   $81 / Sq. Ft.
# 355     Attached Garage     5.00 acres       $142/sqft
# 425             Carport     0.27 acres       $104/sqft
# 447                      3,024 Sq. Ft.  $118 / Sq. Ft.
# ...                 ...            ...             ...
# 376298              NaN            NaN             NaN
# 376340              NaN            NaN             NaN
# 376582              NaN            NaN             NaN
# 376686              NaN            NaN             NaN
# 376694              NaN            NaN             NaN
#
#                           rating                        Distance  \
# 205              ['8', '7', '7']  ['1.9 mi', '1.7 mi', '1.2 mi']
# 321              ['2', '3', '3']  ['0.5 mi', '1.1 mi', '0.3 mi']
# 355     ['8/10', '9/10', '5/10']  ['5.01mi', '5.07mi', '0.23mi']
# 425             ['3/10', '5/10']            ['3.64mi', '3.64mi']
# 447             ['8', '10', '8']  ['1.2 mi', '2.8 mi', '1.3 mi']
# ...                          ...                             ...
# 376298                       NaN                             NaN
# 376340                       NaN                             NaN
# 376582                       NaN                             NaN
# 376686                       NaN                             NaN
# 376694                       NaN                             NaN
#
#                                          Grades  \
# 205     ['Preschool to 5', '6 to 8', '9 to 12']
# 321             ['K to 5', '6 to 8', '9 to 12']
# 355                     ['6-8', '9-12', 'PK-5']
# 425                              ['1-5', '6-8']
# 447     ['Preschool to 5', '6 to 8', '9 to 12']
# ...                                         ...
# 376298                                      NaN
# 376340                                      NaN
# 376582                                      NaN
# 376686                                      NaN
# 376694                                      NaN
#
#                                                      name  sqft_big  beds_big
# 205     ['Ray Daily Elementary School', 'West Briar Mi...         1         0
# 321     ['Willow Oaks Elementary School', 'Colonial Mi...         0         0
# 355     ['Rossview Middle School', 'Rossview High Scho...         0         0
# 425     ['Bramlette Elementary School', 'Judson Middle...         0         0
# 447     ['Stone Oak Elementary School', 'Bush Middle S...         0         0
# ...                                                   ...       ...       ...
# 376298                                                NaN         0         0
# 376340                                                NaN         0         0
# 376582                                                NaN         0         0
# 376686                                                NaN         0         0
# 376694                                                NaN         0         0
#
# [2712 rows x 31 columns]

# %% [markdown]
# Вывод: число домов с бассейнами незначительно (4181 из 377185), разброс цен для домов с бассейнами большой, явного влияния на цену нет. Можно не рассматривать.

# %% [markdown]
#  # propertyType

# %%
data_d['propertyType'].value_counts(normalize=True)
# Out:
# single-family home                                             0.272630
# Single Family                                                  0.180140
# Single Family Home                                             0.098087
# lot/land                                                       0.070871
# condo                                                          0.066419
#                                                                  ...
# Penthouse, Low Rise                                            0.000004
# Traditional, Loft with Bedrooms                                0.000004
# Condo/Townhome, French, Split Level                            0.000004
# Traditional, Colonial, Federal                                 0.000004
# Bilevel, Converted Dwelling, Loft with Bedrooms, Condo/Unit    0.000004
# Name: propertyType, Length: 884, dtype: float64

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: str(x))

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: 'sfh' if x in ['single-family home','Single Family','Single Family Home'] else x)

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: x.lower())

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: 'mlf' if (x.find('multi')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'ctmp' if (x.find('contempor')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'loft' if (x.find('loft')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'twnh' if (x.find('townhouse')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'condo' if (x.find('condo')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'sn_dtch' if (x.find('single detached')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'eng' if (x.find('english')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'other' if x not in ['mlf','ctmp','loft','twnh','condo','sn_dtch','eng'] else x)

# %%
data_d['propertyType'].value_counts()
# Out:
# other      214443
# condo       34421
# twnh        14316
# mlf          5946
# ctmp         2836
# sn_dtch      2261
# loft           32
# eng            27
# Name: propertyType, dtype: int64

# %% [markdown]
# Преобразование к численному виду.

# %%
data_d['propertyType'] = data_d['propertyType'].astype('category')
data_d['propertyType_cat'] = data_d['propertyType'].cat.codes
data_d['propertyType_cat'] = data_d['propertyType_cat'].astype('category')

# %%
data_d['propertyType_cat'].isna().sum()
# Out:
# 0

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274282 entries, 0 to 377184
# Data columns (total 32 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   status            244823 non-null  object
#  1   private pool      2712 non-null    object
#  2   propertyType      274282 non-null  category
#  3   street            274281 non-null  object
#  4   baths             274282 non-null  float64
#  5   homeFacts         274282 non-null  object
#  6   fireplace         274282 non-null  int64
#  7   city              274262 non-null  object
#  8   schools           274282 non-null  object
#  9   sqft              274282 non-null  float64
#  10  zipcode           274282 non-null  object
#  11  beds              274282 non-null  int64
#  12  state             274282 non-null  object
#  13  stories           167675 non-null  object
#  14  mls-id            19140 non-null   object
#  15  PrivatePool       22557 non-null   object
#  16  MlsId             224341 non-null  object
#  17  target            274282 non-null  float64
#  18  Year built        197418 non-null  object
#  19  Remodeled year    186522 non-null  object
#  20  Heating           197480 non-null  object
#  21  Cooling           197480 non-null  object
#  22  Parking           197480 non-null  object
#  23  lotsize           184517 non-null  object
#  24  price_sqft        167237 non-null  object
#  25  rating            199466 non-null  object
#  26  Distance          199466 non-null  object
#  27  Grades            199466 non-null  object
#  28  name              199466 non-null  object
#  29  sqft_big          274282 non-null  int64
#  30  beds_big          274282 non-null  int64
#  31  propertyType_cat  274282 non-null  category
# dtypes: category(2), float64(3), int64(4), object(23)
# memory usage: 65.4+ MB

# %%
x = data_d['propertyType_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Тим собственности', fontsize = 15)
plt.title('Зависимость цены от типа собственности', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от типа собственности')

# %% [markdown]
# # Город

# %%
data_d.city.fillna('others',inplace=True)

# %%
data_d['city'].isna().sum()
# Out:
# 0

# %%
t = data_d['city'].value_counts()

# %%
t_df = pd.DataFrame(t)

# %%
t_df.loc[t_df['city']==np.NaN]
# Out:
# Empty DataFrame
# Columns: [city]
# Index: []

# %%
t_df['city'].isna().sum()
# Out:
# 0

# %%
dict_t = t_df.to_dict()

# %%
dict_city = dict_t.get('city')

# %%
data_d['city'].isna().sum()
# Out:
# 0

# %% [markdown]
# Вспомогательная функция присваивает значение others, если число вхождений данного города невелико. (Здесь меньше 500.)

# %%
def other_cities(x1,d):
    if x1==np.NaN:
        return ('others')
    elif d.get(x1)==np.NaN:
        return('others')
    elif d.get(x1)<500: return ('others')
    else: return(x1)

# %%
data_d.city = data_d.city.apply(lambda x: other_cities(x,dict_city))

# %%
data_d.loc[data_d['city']=='others']
# Out:
#           status private pool propertyType                   street  baths  \
# 0         Active          NaN        other           240 Heather Ln    3.5
# 1       for sale          NaN        other        12911 E Heroy Ave    3.0
# 6         Active          NaN        other         552 Casanova Ct     1.0
# 8         Active          NaN        other            11182 Owl Ave    2.0
# 12      for sale          NaN        other         16373 NW 16th St    3.0
# ...          ...          ...          ...                      ...    ...
# 377140  for sale          NaN        other        6383 Cathedral Dr    1.0
# 377147    Active          NaN        other  1022 Lyndon Station Dr     1.0
# 377161    Active          NaN        other       Homestead Dr Lot 1    1.0
# 377173  for sale          NaN        other      19743 N Sagamore Rd    3.0
# 377182  for sale          NaN        other        15509 Linden Blvd    3.0
#
#                                                 homeFacts  fireplace    city  \
# 0        [2019, , Central A/C, Heat Pump, , , None, $144]          0  others
# 1                    [2019, , , , , 5828 sqft, $159/sqft]          0  others
# 6       [2006, 2006, Electric, Heat Pump, Central Air,...          0  others
# 8            [1970, , Forced Air, Central, , 124582, $68]          0  others
# 12      [1996, 1997, Forced Air, Central, Carport, Att...          0  others
# ...                                                   ...        ...     ...
# 377140                       [, , , , , 3.34 acres, None]          0  others
# 377147  [2020, , , Central Air, Gas (Hot Air), Multi-Z...          0  others
# 377161                                [, , , , , 1, None]          0  others
# 377173  [1950, 2010, Forced Air, Central, Detached Gar...          1  others
# 377182    [1950, 1950, Other, , 2, 1,600 sqft, $458/sqft]          0  others
#
#                                                   schools    sqft zipcode  \
# 0       {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2301.0   28387
# 1       {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0   99216
# 6       {'rating': ['3', '3', '1', 'NR'], 'data': {'Di...  1507.0   34759
# 8       {'rating': ['2', '2', '4', '7', '4', 'NR'], 'd...  2301.0   50401
# 12      {'rating': ['8/10', '7/10', '7/10'], 'data': {...  2301.0   33028
# ...                                                   ...     ...     ...
# 377140  {'rating': ['5/10', '5/10', '7/10'], 'data': {...  2301.0   28601
# 377147  {'rating': ['8', '4', '7'], 'data': {'Distance...  2058.0   28134
# 377161  {'rating': ['8', '9', '8', 'NR'], 'data': {'Di...  1323.0   44408
# 377173  {'rating': ['6/10', '5/10', '6/10'], 'data': {...  2301.0   44126
# 377182  {'rating': ['5/10', '4/10'], 'data': {'Distanc...  1152.0   11434
#
#         beds state stories mls-id PrivatePool      MlsId    target Year built  \
# 0          1    NC     NaN    NaN         NaN     611019  418000.0       2019
# 1          3    WA     2.0    NaN         NaN  201916904  310000.0       2019
# 6          1    FL     One    NaN         NaN   S5026943  181500.0       1970
# 8          1    IA     NaN    NaN         NaN     190988  244900.0       2015
# 12         4    FL     1.0    NaN         yes  A10767242  525000.0       2008
# ...      ...   ...     ...    ...         ...        ...       ...        ...
# 377140     1    NC     NaN    NaN         NaN    3525591   41000.0        NaN
# 377147     1    NC     NaN    NaN         NaN    3576461  342969.0        NaN
# 377161     1    OH     NaN    NaN         NaN    3382834   45000.0        NaN
# 377173     5    OH     2.0    NaN         NaN    4126112  384900.0        NaN
# 377182     3    NY       2    NaN         NaN        NaN  528000.0        NaN
#
#        Remodeled year                 Heating      Cooling Parking  \
# 0                      Central A/C, Heat Pump
# 1
# 6                                  Forced Air      Central
# 8                2015        Central Electric  Central Gas
# 12               2009
# ...               ...                     ...          ...     ...
# 377140            NaN                     NaN          NaN     NaN
# 377147            NaN                     NaN          NaN     NaN
# 377161            NaN                     NaN          NaN     NaN
# 377173            NaN                     NaN          NaN     NaN
# 377182            NaN                     NaN          NaN     NaN
#
#               lotsize      price_sqft  \
# 0                None            $144
# 1           5828 sqft       $159/sqft
# 6              124582             $68
# 8       5,715 Sq. Ft.   $83 / Sq. Ft.
# 12      5,304 Sq. Ft.  $152 / Sq. Ft.
# ...               ...             ...
# 377140            NaN             NaN
# 377147            NaN             NaN
# 377161            NaN             NaN
# 377173            NaN             NaN
# 377182            NaN             NaN
#
#                                              rating  \
# 0       ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1                       ['4/10', 'None/10', '4/10']
# 6                   ['2', '2', '4', '7', '4', 'NR']
# 8                         ['6', '3', '6', '1', '5']
# 12                           ['4', 'NR', '3', 'NR']
# ...                                             ...
# 377140                                          NaN
# 377147                                          NaN
# 377161                                          NaN
# 377173                                          NaN
# 377182                                          NaN
#
#                                                  Distance  \
# 0       ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                          ['1.65mi', '1.32mi', '1.01mi']
# 6       ['5.6 mi', '5.6 mi', '6.8 mi', '6.5 mi', '6.8 ...
# 8       ['0.4 mi', '0.4 mi', '3.0 mi', '3.2 mi', '7.4 ...
# 12               ['0.5 mi', '0.7 mi', '0.5 mi', '1.1 mi']
# ...                                                   ...
# 377140                                                NaN
# 377147                                                NaN
# 377161                                                NaN
# 377173                                                NaN
# 377182                                                NaN
#
#                                                    Grades  \
# 0       ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                                 ['9-12', '3-8', 'PK-8']
# 6          ['PK–4', '5–6', '9–12', 'PK–4', '7–8', '9–12']
# 8       ['Preschool to 5', '6 to 8', '6 to 8', '9 to 1...
# 12      ['Preschool to 5', 'Preschool to 8', '6 to 12'...
# ...                                                   ...
# 377140                                                NaN
# 377147                                                NaN
# 377161                                                NaN
# 377173                                                NaN
# 377182                                                NaN
#
#                                                      name  sqft_big  beds_big  \
# 0       ['Southern Pines Elementary School', 'Southern...         1         0
# 1       ['East Valley High School&Extension', 'Eastval...         0         0
# 6       ['Roosevelt Elementary School', 'Lincoln Inter...         0         0
# 8       ['Pat Reynolds Elementary School', 'Edwin M We...         1         0
# 12      ['Dillard Elementary School', 'Mount Olivet Se...         1         0
# ...                                                   ...       ...       ...
# 377140                                                NaN         1         0
# 377147                                                NaN         0         0
# 377161                                                NaN         0         0
# 377173                                                NaN         1         0
# 377182                                                NaN         0         0
#
#        propertyType_cat
# 0                     5
# 1                     5
# 6                     5
# 8                     5
# 12                    5
# ...                 ...
# 377140                5
# 377147                5
# 377161                5
# 377173                5
# 377182                5
#
# [73054 rows x 32 columns]

# %%
#from sklearn.preprocessing import OneHotEncoder
#ohe = OneHotEncoder(sparse=False)

# %%
#ohe_ftrs = ohe.fit_transform(data_d['city'].values.reshape(-1,1))

# %%
#tmp = pd.DataFrame(ohe_ftrs, columns = ['city=' + str(i) for i in range(ohe_ftrs.shape[1])])
#data_d = pd.concat([data_d, tmp], axis=1)

# %%
#data_d['city=97'].isna().sum()

# %%
data_d['city'] = data_d['city'].astype('category')
data_d['city_cat'] = data_d['city'].cat.codes
data_d['city_cat'] = data_d['city_cat'].astype('category')

# %%
sns.distplot(data_d['city_cat'])
# Out:
# <AxesSubplot:xlabel='city_cat', ylabel='Density'>

# %%
data_d['city_cat'].isna().sum()
# Out:
# 0

# %%
x = data_d['city_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Город', fontsize = 15)
plt.title('Зависимость цены от города', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от города')

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274282 entries, 0 to 377184
# Data columns (total 33 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   status            244823 non-null  object
#  1   private pool      2712 non-null    object
#  2   propertyType      274282 non-null  category
#  3   street            274281 non-null  object
#  4   baths             274282 non-null  float64
#  5   homeFacts         274282 non-null  object
#  6   fireplace         274282 non-null  int64
#  7   city              274282 non-null  category
#  8   schools           274282 non-null  object
#  9   sqft              274282 non-null  float64
#  10  zipcode           274282 non-null  object
#  11  beds              274282 non-null  int64
#  12  state             274282 non-null  object
#  13  stories           167675 non-null  object
#  14  mls-id            19140 non-null   object
#  15  PrivatePool       22557 non-null   object
#  16  MlsId             224341 non-null  object
#  17  target            274282 non-null  float64
#  18  Year built        197418 non-null  object
#  19  Remodeled year    186522 non-null  object
#  20  Heating           197480 non-null  object
#  21  Cooling           197480 non-null  object
#  22  Parking           197480 non-null  object
#  23  lotsize           184517 non-null  object
#  24  price_sqft        167237 non-null  object
#  25  rating            199466 non-null  object
#  26  Distance          199466 non-null  object
#  27  Grades            199466 non-null  object
#  28  name              199466 non-null  object
#  29  sqft_big          274282 non-null  int64
#  30  beds_big          274282 non-null  int64
#  31  propertyType_cat  274282 non-null  category
#  32  city_cat          274282 non-null  category
# dtypes: category(4), float64(3), int64(4), object(22)
# memory usage: 63.8+ MB

# %% [markdown]
# # Штат

# %%
data_d['state'] = data_d['state'].astype('category')
data_d['state_cat'] = data_d['state'].cat.codes
data_d['state_cat'] = data_d['state_cat'].astype('category')

# %%
data_d['state_cat'].isna().sum()
# Out:
# 0

# %%
x = data_d['state_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Штат', fontsize = 15)
plt.title('Зависимость цены от штата', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от штата')

# %% [markdown]
# # Улица

# %%
data_d['street'].nunique()
# Out:
# 245863

# %% [markdown]
# Уникальных значений улиц слишком много. Признак удалила.

# %% [markdown]
#  # Stories (надеюсь, это этажи)

# %%
data_d.stories = data_d.stories.apply(lambda x: main_extract_num(str(x)))

# %%
data_d['stories'].isna().sum()
# Out:
# 0

# %%
sns.distplot(data_d['stories'])
# Out:
# <AxesSubplot:xlabel='stories', ylabel='Density'>

# %%
data_d.loc[data_d['stories']>17]
# Out:
#           status private pool propertyType                      street  baths  \
# 612     for sale          NaN        condo         600 NE 36th St #519    2.0
# 1170    for sale          NaN        other      2550 Olinville Ave #2A    1.0
# 1276    for sale          NaN        other           357 E 57th St #9G    1.0
# 2109    for sale          NaN        condo     600 S Dearborn St #1401    2.0
# 3586    for sale          NaN        condo          2201 3rd Ave #1905    1.0
# ...          ...          ...          ...                         ...    ...
# 363402    Active          NaN        condo         2600 2nd Ave #1409     1.0
# 364480  for sale          NaN        other           200 E 36th St #5H    1.0
# 369361  for sale          NaN        other  6636 Yellowstone Blvd #24A    1.0
# 370600  for sale          NaN        other          245 E 54th St #14J    1.0
# 375325       NaN          NaN        condo       55 SE 6th St APT 3610    2.0
#
#                                                 homeFacts  fireplace  \
# 612     [1973, 2005, Forced Air, Central, Attached Gar...          0
# 1170      [1999, , Oil, Central, , 2.24 acres, $263/sqft]          0
# 1276                [1958, , , , , 8,183 sqft, $998/sqft]          0
# 2109    [1910, 2015, Heat Pump, Evaporative, Off Stree...          0
# 3586    [1979, 1990, Baseboard, None, Attached Garage,...          1
# ...                                                   ...        ...
# 363402  [1993, , Central, Central Air Conditioning, Fo...          0
# 364480                [1955, , , , , 9,250 sqft, $4/sqft]          0
# 369361               [1964, , , , , 0.9 acres, $387/sqft]          0
# 370600  [1977, , , , Attached Garage, 0.52 acres, $898...          0
# 375325  [2008, 2008, Forced air, Central, 1 space, Non...          0
#
#             city                                            schools    sqft  \
# 612        Miami  {'rating': ['2/10', '4/10', '10/10', '2/10', '...   757.0
# 1170       Bronx  {'rating': ['5/10', '7/10', '3/10'], 'data': {...   950.0
# 1276    New York  {'rating': ['9/10', '8/10', '3/10', '8/10', '1...   500.0
# 2109     Chicago  {'rating': ['6/10', '7/10'], 'data': {'Distanc...  1200.0
# 3586     Seattle  {'rating': ['7/10', '2/10'], 'data': {'Distanc...   557.0
# ...          ...                                                ...     ...
# 363402   Seattle  {'rating': ['2', '6'], 'data': {'Distance': ['...   729.0
# 364480  New York  {'rating': ['9/10', '8/10', '3/10', '8/10', '9...  2301.0
# 369361    others  {'rating': ['5/10', '8/10', '7/10'], 'data': {...   850.0
# 370600  New York  {'rating': ['9/10', '8/10', '3/10', '8/10', '1...   500.0
# 375325     Miami  {'rating': ['10/10', '2/10'], 'data': {'Distan...  1200.0
#
#        zipcode  beds state  stories mls-id PrivatePool      MlsId    target  \
# 612      33137     1    FL     22.0    NaN         NaN  A10584822  245000.0
# 1170     10467     2    NY     18.0    NaN         NaN    5104665  250000.0
# 1276     10022     1    NY     21.0    NaN         NaN        NaN  499000.0
# 2109     60605     2    IL     22.0    NaN         NaN   10574512  379990.0
# 3586     98121     1    WA     27.0    NaN         yes    1498832  459950.0
# ...        ...   ...   ...      ...    ...         ...        ...       ...
# 363402   98121     1    WA     25.0    NaN         NaN    1494038  535000.0
# 364480   10016     1    NY     19.0    NaN         NaN        NaN  525000.0
# 369361   11375     1    NY     28.0    NaN         yes        NaN  329000.0
# 370600   10022     1    NY     29.0    NaN         NaN    8679885  449000.0
# 375325   33131     1    FL     43.0    NaN         NaN  A10730974  499000.0
#
#        Year built Remodeled year     Heating   Cooling   Parking     lotsize  \
# 612          2019
# 1170         2017                    Central  Electric                     —
# 1276         1920           1952  Forced air      None      None  3,388 sqft
# 2109
# 3586         1971           1971  Forced air   Central  6 spaces  0.74 acres
# ...           ...            ...         ...       ...       ...         ...
# 363402        NaN            NaN         NaN       NaN       NaN         NaN
# 364480        NaN            NaN         NaN       NaN       NaN         NaN
# 369361        NaN            NaN         NaN       NaN       NaN         NaN
# 370600        NaN            NaN         NaN       NaN       NaN         NaN
# 375325        NaN            NaN         NaN       NaN       NaN         NaN
#
#             price_sqft                          rating  \
# 612          $205/sqft        ['3/10', '3/10', '5/10']
# 1170    $291 / Sq. Ft.  ['2', '1', '3', '8', '1', '1']
# 1276               $68                ['2/10', '2/10']
# 2109         $136/sqft       ['8/10', '6/10', '10/10']
# 3586              None        ['9/10', '6/10', '4/10']
# ...                ...                             ...
# 363402             NaN                             NaN
# 364480             NaN                             NaN
# 369361             NaN                             NaN
# 370600             NaN                             NaN
# 375325             NaN                             NaN
#
#                                                  Distance  \
# 612                        ['2.46mi', '0.78mi', '0.96mi']
# 1170    ['2.7 mi', '4.1 mi', '1.2 mi', '6.5 mi', '1.4 ...
# 1276                                ['10.2 mi', '9.8 mi']
# 2109                        ['2.6mi', '3.32mi', '0.48mi']
# 3586                         ['1 mi', '1.9 mi', '0.6 mi']
# ...                                                   ...
# 363402                                                NaN
# 364480                                                NaN
# 369361                                                NaN
# 370600                                                NaN
# 375325                                                NaN
#
#                                                    Grades  \
# 612                               ['9-12', '6-8', 'PK-5']
# 1170    ['Preschool to 4', 'Preschool to 4', '5 to 8',...
# 1276                                     ['PK-9', '5-12']
# 2109                              ['6-8', '9-12', 'PK-5']
# 3586                              ['PK-5', '6-8', '9-12']
# ...                                                   ...
# 363402                                                NaN
# 364480                                                NaN
# 369361                                                NaN
# 370600                                                NaN
# 375325                                                NaN
#
#                                                      name  sqft_big  beds_big  \
# 612     ['Prairie View High School', 'Otho E Stuart Mi...         0         0
# 1170    ['Cotton Elementary School', 'Caldwell Enhance...         0         0
# 1276    ['Adlai Stevenson School', 'Collinwood High Sc...         0         0
# 2109    ['Hopewell Middle School', 'Stony Point High S...         0         0
# 3586    ['Kendale Elementary School', 'Glades Middle S...         0         0
# ...                                                   ...       ...       ...
# 363402                                                NaN         0         0
# 364480                                                NaN         1         0
# 369361                                                NaN         0         0
# 370600                                                NaN         0         0
# 375325                                                NaN         0         0
#
#        propertyType_cat city_cat state_cat
# 612                   0       52         7
# 1170                  5        5        24
# 1276                  5       58        24
# 2109                  0       11        11
# 3586                  0       86        37
# ...                 ...      ...       ...
# 363402                0       86        37
# 364480                5       58        24
# 369361                5      102        24
# 370600                5       58        24
# 375325                0       52         7
#
# [243 rows x 34 columns]

# %%
data_d = data_d[data_d['stories']<17]

# %%
x = data_d['stories']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Этаж', fontsize = 15)
plt.title('Зависимость цены от этажа', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от этажа')

# %% [markdown]
#  # Status

# %%
data_d['status'].value_counts()
# Out:
# for sale                113218
# Active                   76591
# For sale                 30301
# foreclosure               5150
# Pending                   4054
#                          ...
# Contingent   No Show         1
# Pending Sale                 1
# Coming soon: Nov 30.         1
# Coming soon: Dec 16.         1
# Accepting backups            1
# Name: status, Length: 149, dtype: int64

# %%
data_d.status = data_d.status.apply(lambda x: 'for_sale' if x in ['for sale','For sale'] else x)

# %%
data_d.status = data_d.status.apply(lambda x: str(x))

# %%
data_d.status = data_d.status.apply(lambda x: x.lower())

# %%
data_d.status = data_d.status.apply(lambda x: 'actv' if (x.find('activ')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cnstr' if (x.find('construction')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cntrct' if (x.find('contract')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'frcls' if (x.find('foreclosure')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'pnd' if (x.find('pending')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cntgs' if (x.find('contingen')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cmg_s' if (x.find('coming soon')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'frcls' if (x.find('foreclosure')>-1) else x)

# %%
data_d['status'].value_counts()
# Out:
# for_sale                 143519
# actv                      77419
# nan                       29408
# frcls                      8468
# pnd                        4624
# cnstr                      3385
# cntrct                     2593
# cntgs                       935
# p                           781
#  / auction                  556
# auction                     458
# new                         454
# price change                408
# for rent                    396
# foreclosed                  288
# back on market              101
# cmg_s                        78
# pi                           29
# due diligence period         26
# c continue show              18
# c                            18
# listing extended              8
# apartment for rent            7
# condo for rent                7
# accepted offer                4
# closed                        4
# pf                            3
# ct                            3
# ps                            2
# uc continue to show           2
# for sale                      1
# conting accpt backups         1
# lease/purchase                1
# backup                        1
# accepting backups             1
# Name: status, dtype: int64

# %% [markdown]
# Приведение к численному виду.

# %%
data_d['status'] = data_d['status'].astype('category')
data_d['status_cat'] = data_d['status'].cat.codes
data_d['status_cat'] = data_d['status_cat'].astype('category')

# %%
data_d['status_cat'].isna().sum()
# Out:
# 0

# %%
x = data_d['status_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Статус продажи', fontsize = 15)
plt.title('Зависимость цены от статуса продажи', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от статуса продажи')

# %% [markdown]
# # Индекс

# %%
data_d['zipcode'].value_counts()
# Out:
# 32137         1826
# 78245         1381
# 34759         1321
# 78253         1266
# 78254         1228
#               ...
# 27705-3530       1
# 27603-5569       1
# 50439            1
# 47901            1
# 44704            1
# Name: zipcode, Length: 4269, dtype: int64

# %%
data_d.zipcode = data_d.zipcode.apply(lambda x: (str(x))[0:2])

# %%
data_d.loc[data_d['zipcode']=='--']
# Out:
#        status private pool propertyType                   street  baths  \
# 235207    nan          NaN         twnh  1744 N Dixie Hwy # 1744    3.0
#
#                                                 homeFacts  fireplace  \
# 235207  [2010, None, Forced air, Central, No Data, No ...          0
#
#                    city                                            schools  \
# 235207  Fort Lauderdale  {'rating': ['3/10', '5/10', '7/10'], 'data': {...
#
#           sqft zipcode  beds state  stories mls-id PrivatePool  \
# 235207  2043.0      --     1    FL      1.0    NaN         NaN
#
#                              MlsId    target Year built Remodeled year  \
# 235207   1744, Fort Lauderdale, FL  425000.0
#
#        Heating Cooling Parking     lotsize price_sqft  \
# 235207                          0.87 acres       None
#
#                           rating                       Distance  \
# 235207  ['8/10', '9/10', '9/10']  ['5.0mi', '3.18mi', '2.94mi']
#
#                         Grades  \
# 235207  ['K-5', '6-8', '9-12']
#
#                                                      name  sqft_big  beds_big  \
# 235207  ['Northshore Elementary', 'Farragut Middle Sch...         0         0
#
#        propertyType_cat city_cat state_cat status_cat
# 235207                7       25         7         26

# %%
data_d['zipcode'].value_counts()
# Out:
# 33    51202
# 77    25825
# 32    24558
# 78    21004
# 34    13864
#       ...
# 0         2
# 35        1
# 58        1
# --        1
# 00        1
# Name: zipcode, Length: 78, dtype: int64

# %%
data_d = data_d.drop(data_d[data_d['zipcode']=='--'].index)
data_d = data_d.drop(data_d[data_d['zipcode']=='0'].index)
#data_d = data_d.drop(data_d[data_d['zipcode']=='--'].index)

# %%
data_d.zipcode = data_d.zipcode.apply(lambda x: int(x))

# %%
data_d['zipcode'].value_counts()
# Out:
# 33    51202
# 77    25825
# 32    24558
# 78    21004
# 34    13864
#       ...
# 59        8
# 42        7
# 35        1
# 58        1
# 0         1
# Name: zipcode, Length: 76, dtype: int64

# %%
data_d['zipcode'].isna().sum()
# Out:
# 0

# %%
data_d['zipcode'] = data_d['zipcode'].astype('category')

# %%
x = data_d['zipcode']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Цена', fontsize = 15)
plt.ylabel('Индекс', fontsize = 15)
plt.title('Зависимость цены от индекса', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от индекса')

# %% [markdown]
# # Разбор нового признака - рейтинг школы

# %% [markdown]
# Вспомогательная функция - возвращает численный список: численное значение рейтинга, если рейтинг выражен числом, первое значение дроби или ноль, если встречаются любые другие символы.

# %%
data_d['typeRating']=data_d['rating'].apply(lambda x: type(x))

# %%
data_d['typeRating'].value_counts()
# Out:
# <class 'str'>      199263
# <class 'float'>     74741
# Name: typeRating, dtype: int64

# %%
data_d.rating=data_d.rating.apply(lambda x: '[]' if type(x)==float else x)

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools    sqft zipcode  beds  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2301.0      28     1
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0      99     3
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  1947.0      32     1
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.0      19     2
#
#   state  stories mls-id PrivatePool       MlsId    target Year built  \
# 0    NC      1.0    NaN         NaN      611019  418000.0       2019
# 1    WA      2.0    NaN         NaN   201916904  310000.0       2019
# 4    FL      1.0    NaN         NaN      861745    5000.0       2006
# 5    PA      2.0    NaN         NaN  PAPH847006  209000.0       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                                       rating  \
# 0            $144  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1       $159/sqft                  ['4/10', 'None/10', '4/10']
# 4  $120 / Sq. Ft.                        ['3', '3', '1', 'NR']
# 5   $57 / Sq. Ft.                              ['4', '2', '2']
#
#                                             Distance  \
# 0  ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                     ['1.65mi', '1.32mi', '1.01mi']
# 4           ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
# 5                     ['0.7 mi', '0.4 mi', '2.2 mi']
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name  sqft_big  beds_big  \
# 0  ['Southern Pines Elementary School', 'Southern...         1         0
# 1  ['East Valley High School&Extension', 'Eastval...         0         0
# 4  ['Palmetto Elementary School', 'Haines City Se...         0         0
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...         0         0
#
#   propertyType_cat city_cat state_cat status_cat     typeRating
# 0                5      102        21          3  <class 'str'>
# 1                5      102        37         21  <class 'str'>
# 4                5       64         7         21  <class 'str'>
# 5                7       70        30         21  <class 'str'>

# %%
data_d.rating=data_d.rating.apply(lambda x: eval(x))

# %%
def school_rating1 (lst_r):
    lst_clean = []
    for p in lst_r:
        if p.find('/') == -1:
            if p.isdigit():
                lst_clean.append(int(p))
            else: lst_clean.append(0)
        else:
            num = p[:p.find('/')]
            if num.isdigit():
                lst_clean.append(int(num))
                
            else: lst_clean.append(0)

    return lst_clean

# %%
data_d.rating = data_d.rating.apply(lambda x: school_rating1(x))

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274004 entries, 0 to 377184
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   status            274004 non-null  category
#  1   private pool      2709 non-null    object
#  2   propertyType      274004 non-null  category
#  3   street            274003 non-null  object
#  4   baths             274004 non-null  float64
#  5   homeFacts         274004 non-null  object
#  6   fireplace         274004 non-null  int64
#  7   city              274004 non-null  category
#  8   schools           274004 non-null  object
#  9   sqft              274004 non-null  float64
#  10  zipcode           274004 non-null  category
#  11  beds              274004 non-null  int64
#  12  state             274004 non-null  category
#  13  stories           274004 non-null  float64
#  14  mls-id            19134 non-null   object
#  15  PrivatePool       22447 non-null   object
#  16  MlsId             224129 non-null  object
#  17  target            274004 non-null  float64
#  18  Year built        197216 non-null  object
#  19  Remodeled year    186327 non-null  object
#  20  Heating           197278 non-null  object
#  21  Cooling           197278 non-null  object
#  22  Parking           197278 non-null  object
#  23  lotsize           184322 non-null  object
#  24  price_sqft        167075 non-null  object
#  25  rating            274004 non-null  object
#  26  Distance          199263 non-null  object
#  27  Grades            199263 non-null  object
#  28  name              199263 non-null  object
#  29  sqft_big          274004 non-null  int64
#  30  beds_big          274004 non-null  int64
#  31  propertyType_cat  274004 non-null  category
#  32  city_cat          274004 non-null  category
#  33  state_cat         274004 non-null  category
#  34  status_cat        274004 non-null  category
#  35  typeRating        274004 non-null  object
# dtypes: category(9), float64(4), int64(4), object(19)
# memory usage: 60.9+ MB

# %% [markdown]
# # Создание новых признаков: маскимальный рейтинг, средний рейтинг.

# %%
data_d['max_rating'] = data_d['rating'].apply(lambda x: 0 if x == [] else max(x))

# %%
data_d['mean_rating'] = data_d['rating'].apply(lambda x: 0 if x == [] else round(sum(x)/len(x),2))

# %%
data_d.head(3)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
#
#                                           homeFacts  fireplace      city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0    others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0    others
# 4                     [, , , , , 10,019 sqft, None]          0  Palm Bay
#
#                                              schools    sqft zipcode  beds  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2301.0      28     1
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0      99     3
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  1947.0      32     1
#
#   state  stories mls-id PrivatePool      MlsId    target Year built  \
# 0    NC      1.0    NaN         NaN     611019  418000.0       2019
# 1    WA      2.0    NaN         NaN  201916904  310000.0       2019
# 4    FL      1.0    NaN         NaN     861745    5000.0       2006
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
#
#        price_sqft                    rating  \
# 0            $144  [4, 4, 7, 0, 4, 7, 0, 0]
# 1       $159/sqft                 [4, 0, 4]
# 4  $120 / Sq. Ft.              [3, 3, 1, 0]
#
#                                             Distance  \
# 0  ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                     ['1.65mi', '1.32mi', '1.01mi']
# 4           ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
#
#                                                 name  sqft_big  beds_big  \
# 0  ['Southern Pines Elementary School', 'Southern...         1         0
# 1  ['East Valley High School&Extension', 'Eastval...         0         0
# 4  ['Palmetto Elementary School', 'Haines City Se...         0         0
#
#   propertyType_cat city_cat state_cat status_cat     typeRating  max_rating  \
# 0                5      102        21          3  <class 'str'>           7
# 1                5      102        37         21  <class 'str'>           4
# 4                5       64         7         21  <class 'str'>           3
#
#    mean_rating
# 0         3.25
# 1         2.67
# 4         1.75

# %% [markdown]
# # Разбор нового признака расстояние

# %% [markdown]
# Вспомогательная функция возвращает список числовых значений расстояния

# %%
data_d.Distance=data_d.Distance.apply(lambda x: '[]' if type(x)==float else x)

# %%
data_d['type_Dist'] = data_d['Distance'].apply(lambda x: type(x))

# %%
data_d['type_Dist'].value_counts()
# Out:
# <class 'str'>    274004
# Name: type_Dist, dtype: int64

# %%
data_d.Distance = data_d.Distance.apply(lambda x: eval(x))

# %%
data_d['type_Dist'] = data_d['Distance'].apply(lambda x: type(x))

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools    sqft zipcode  beds  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2301.0      28     1
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0      99     3
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  1947.0      32     1
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.0      19     2
#
#   state  stories mls-id PrivatePool       MlsId    target Year built  \
# 0    NC      1.0    NaN         NaN      611019  418000.0       2019
# 1    WA      2.0    NaN         NaN   201916904  310000.0       2019
# 4    FL      1.0    NaN         NaN      861745    5000.0       2006
# 5    PA      2.0    NaN         NaN  PAPH847006  209000.0       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                    rating  \
# 0            $144  [4, 4, 7, 0, 4, 7, 0, 0]
# 1       $159/sqft                 [4, 0, 4]
# 4  $120 / Sq. Ft.              [3, 3, 1, 0]
# 5   $57 / Sq. Ft.                 [4, 2, 2]
#
#                                             Distance  \
# 0  [2.7 mi, 3.6 mi, 5.1 mi, 4.0 mi, 10.5 mi, 12.6...
# 1                           [1.65mi, 1.32mi, 1.01mi]
# 4                   [0.8 mi, 8.3 mi, 4.2 mi, 2.0 mi]
# 5                           [0.7 mi, 0.4 mi, 2.2 mi]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name  sqft_big  beds_big  \
# 0  ['Southern Pines Elementary School', 'Southern...         1         0
# 1  ['East Valley High School&Extension', 'Eastval...         0         0
# 4  ['Palmetto Elementary School', 'Haines City Se...         0         0
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...         0         0
#
#   propertyType_cat city_cat state_cat status_cat     typeRating  max_rating  \
# 0                5      102        21          3  <class 'str'>           7
# 1                5      102        37         21  <class 'str'>           4
# 4                5       64         7         21  <class 'str'>           3
# 5                7       70        30         21  <class 'str'>           4
#
#    mean_rating       type_Dist
# 0         3.25  <class 'list'>
# 1         2.67  <class 'list'>
# 4         1.75  <class 'list'>
# 5         2.67  <class 'list'>

# %%
data_d['typeRating'].value_counts()
# Out:
# <class 'str'>      199263
# <class 'float'>     74741
# Name: typeRating, dtype: int64

# %%
def distance_select(distance):
    lst_dist = []
    if distance == []: return []
    else:
        for i in distance:
            if i.find(' mi')>-1:
                lst_dist.append(float(i[:-3]))
            elif i.find('mi')>-1:
                lst_dist.append(float(i[:-2]))
            else: lst_dist.append(0)
    return lst_dist

# %%
data_d.Distance = data_d.Distance.apply(lambda x: distance_select(x))

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools    sqft zipcode  beds  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2301.0      28     1
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0      99     3
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  1947.0      32     1
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.0      19     2
#
#   state  stories mls-id PrivatePool       MlsId    target Year built  \
# 0    NC      1.0    NaN         NaN      611019  418000.0       2019
# 1    WA      2.0    NaN         NaN   201916904  310000.0       2019
# 4    FL      1.0    NaN         NaN      861745    5000.0       2006
# 5    PA      2.0    NaN         NaN  PAPH847006  209000.0       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                    rating  \
# 0            $144  [4, 4, 7, 0, 4, 7, 0, 0]
# 1       $159/sqft                 [4, 0, 4]
# 4  $120 / Sq. Ft.              [3, 3, 1, 0]
# 5   $57 / Sq. Ft.                 [4, 2, 2]
#
#                                      Distance  \
# 0  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                          [1.65, 1.32, 1.01]
# 4                        [0.8, 8.3, 4.2, 2.0]
# 5                             [0.7, 0.4, 2.2]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name  sqft_big  beds_big  \
# 0  ['Southern Pines Elementary School', 'Southern...         1         0
# 1  ['East Valley High School&Extension', 'Eastval...         0         0
# 4  ['Palmetto Elementary School', 'Haines City Se...         0         0
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...         0         0
#
#   propertyType_cat city_cat state_cat status_cat     typeRating  max_rating  \
# 0                5      102        21          3  <class 'str'>           7
# 1                5      102        37         21  <class 'str'>           4
# 4                5       64         7         21  <class 'str'>           3
# 5                7       70        30         21  <class 'str'>           4
#
#    mean_rating       type_Dist
# 0         3.25  <class 'list'>
# 1         2.67  <class 'list'>
# 4         1.75  <class 'list'>
# 5         2.67  <class 'list'>

# %% [markdown]
# # Добавление новых признаков: минимальное расстояние до школы, среднее расстояние до школы.

# %%
data_d['min_distance'] = data_d['Distance'].apply(lambda x: 0 if x == [] else min(x))
data_d['mean_distance'] = data_d['Distance'].apply(lambda x: 0 if x == [] else round(sum(x)/len(x),2))

# %% [markdown]
# # Выделение нового признака - цена за квадратный метр.

# %%
data_d['price_sqft'].isna().sum()
# Out:
# 106929

# %%
def price_clean(price):
    
    if price == None: return np.NaN
    
    elif type(price) == float: return price

    elif price.find('$')>-1: return price_clean(price[1:])
   
    elif price.find('/')>-1: return price_clean(price[0:price.find('/')])
    
    elif price.isnumeric(): return float(price)
    
    else: return np.NaN

# %%
data_d.price_sqft = data_d.price_sqft.apply(lambda x: price_clean(x))

# %%
data_d['price_sqft'].isna().sum()
# Out:
# 137606

# %% [markdown]
# # Для модели, построенной для цены за квадратный метр, заполнение убрать.

# %% [markdown]
# # Модель с целевой переменной цена за кв. метр.

# %%
#data_d[['price_sqft']] = data_d[['price_sqft']].fillna(data_d['price_sqft'].median())

# %%
data_d['price_sqft'].isna().sum()
# Out:
# 137606

# %%
data_d = data_d.dropna(axis=0,subset=['price_sqft'])

# %%
data_d['price_sqft'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Выбор предварительного датафрейма для модели

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136398 entries, 0 to 274464
# Data columns (total 41 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   status            136398 non-null  category
#  1   private pool      1322 non-null    object
#  2   propertyType      136398 non-null  category
#  3   street            136397 non-null  object
#  4   baths             136398 non-null  float64
#  5   homeFacts         136398 non-null  object
#  6   fireplace         136398 non-null  int64
#  7   city              136398 non-null  category
#  8   schools           136398 non-null  object
#  9   sqft              136398 non-null  float64
#  10  zipcode           136398 non-null  category
#  11  beds              136398 non-null  int64
#  12  state             136398 non-null  category
#  13  stories           136398 non-null  float64
#  14  mls-id            9473 non-null    object
#  15  PrivatePool       11220 non-null   object
#  16  MlsId             111622 non-null  object
#  17  target            136398 non-null  float64
#  18  Year built        136340 non-null  object
#  19  Remodeled year    126226 non-null  object
#  20  Heating           136398 non-null  object
#  21  Cooling           136398 non-null  object
#  22  Parking           136398 non-null  object
#  23  lotsize           124564 non-null  object
#  24  price_sqft        136398 non-null  float64
#  25  rating            136398 non-null  object
#  26  Distance          136398 non-null  object
#  27  Grades            136398 non-null  object
#  28  name              136398 non-null  object
#  29  sqft_big          136398 non-null  int64
#  30  beds_big          136398 non-null  int64
#  31  propertyType_cat  136398 non-null  category
#  32  city_cat          136398 non-null  category
#  33  state_cat         136398 non-null  category
#  34  status_cat        136398 non-null  category
#  35  typeRating        136398 non-null  object
#  36  max_rating        136398 non-null  int64
#  37  mean_rating       136398 non-null  float64
#  38  type_Dist         136398 non-null  object
#  39  min_distance      136398 non-null  float64
#  40  mean_distance     136398 non-null  float64
# dtypes: category(9), float64(8), int64(5), object(19)
# memory usage: 35.5+ MB

# %%
columns = data_d.columns

# %%
columns = columns.tolist()

# %%
columns
# Out:
# ['status',
#  'private pool',
#  'propertyType',
#  'street',
#  'baths',
#  'homeFacts',
#  'fireplace',
#  'city',
#  'schools',
#  'sqft',
#  'zipcode',
#  'beds',
#  'state',
#  'stories',
#  'mls-id',
#  'PrivatePool',
#  'MlsId',
#  'target',
#  'Year built',
#  'Remodeled year',
#  'Heating',
#  'Cooling',
#  'Parking',
#  'lotsize',
#  'price_sqft',
#  'rating',
#  'Distance',
#  'Grades',
#  'name',
#  'sqft_big',
#  'beds_big',
#  'propertyType_cat',
#  'city_cat',
#  'state_cat',
#  'status_cat',
#  'typeRating',
#  'max_rating',
#  'mean_rating',
#  'type_Dist',
#  'min_distance',
#  'mean_distance']

# %%
lst_remove = ['status','mls-id','private pool',
 'PrivatePool','Year built','state',
 'Remodeled year',
 'Heating',
 'Cooling',
 'Parking',
 'lotsize',
 'MlsId','propertyType','street','homeFacts','city','schools','rating',
 'Distance',
 'Grades',
 'name','typeRating',
 'type_Dist']

# %%
columns = columns
lst_remove = lst_remove
for i in lst_remove:
    columns.remove(i)

# %%
columns
# Out:
# ['baths',
#  'fireplace',
#  'sqft',
#  'zipcode',
#  'beds',
#  'stories',
#  'target',
#  'price_sqft',
#  'sqft_big',
#  'beds_big',
#  'propertyType_cat',
#  'city_cat',
#  'state_cat',
#  'status_cat',
#  'max_rating',
#  'mean_rating',
#  'min_distance',
#  'mean_distance']

# %%
data_d_preliminary=data_d[columns]

# %%
data_d_preliminary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136398 entries, 0 to 274464
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   baths             136398 non-null  float64
#  1   fireplace         136398 non-null  int64
#  2   sqft              136398 non-null  float64
#  3   zipcode           136398 non-null  category
#  4   beds              136398 non-null  int64
#  5   stories           136398 non-null  float64
#  6   target            136398 non-null  float64
#  7   price_sqft        136398 non-null  float64
#  8   sqft_big          136398 non-null  int64
#  9   beds_big          136398 non-null  int64
#  10  propertyType_cat  136398 non-null  category
#  11  city_cat          136398 non-null  category
#  12  state_cat         136398 non-null  category
#  13  status_cat        136398 non-null  category
#  14  max_rating        136398 non-null  int64
#  15  mean_rating       136398 non-null  float64
#  16  min_distance      136398 non-null  float64
#  17  mean_distance     136398 non-null  float64
# dtypes: category(5), float64(8), int64(5)
# memory usage: 15.2 MB

# %%
data_d_preliminary.isna().sum()
# Out:
# baths               0
# fireplace           0
# sqft                0
# zipcode             0
# beds                0
# stories             0
# target              0
# price_sqft          0
# sqft_big            0
# beds_big            0
# propertyType_cat    0
# city_cat            0
# state_cat           0
# status_cat          0
# max_rating          0
# mean_rating         0
# min_distance        0
# mean_distance       0
# dtype: int64

# %% [markdown]
# # Визуализация

# %%
plt.figure(figsize=(18, 10))
ax = sns.heatmap(data_d_preliminary.corr().abs(), vmin=0, vmax=1, annot = True)
i, k = ax.get_ylim()
ax.set_ylim(i+0.5, k-0.5)
# Out:
# (12.5, -0.5)

# %% [markdown]
# # Нормализация

# %%
# min_maz_Scaler=preprocessing.MinMaxScaler()

# %%
# col=data_d_preliminary.columns
# result=min_maz_Scaler.fit_transform(data_d_preliminary)
# data_d_preliminaty_n=pd.DataFrame(result,columns=col)

# %%
# data_d_preliminaty_n

# %%
#plt.figure(figsize=(18, 10))
#ax = sns.heatmap(data_d_preliminaty_n.corr().abs(), vmin=0, vmax=1, annot = True)
#i, k = ax.get_ylim()
#ax.set_ylim(i+0.5, k-0.5)

# %% [markdown]
# > # Подготовка данных для моделей.

# %%
columns = data_d_preliminary.columns
columns = columns.tolist()
columns.remove('price_sqft')

# %%
columns
# Out:
# ['baths',
#  'fireplace',
#  'sqft',
#  'zipcode',
#  'beds',
#  'stories',
#  'target',
#  'sqft_big',
#  'beds_big',
#  'propertyType_cat',
#  'city_cat',
#  'state_cat',
#  'status_cat',
#  'max_rating',
#  'mean_rating',
#  'min_distance',
#  'mean_distance']

# %%
X=data_d_preliminary[columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136398 entries, 0 to 274464
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   baths             136398 non-null  float64
#  1   fireplace         136398 non-null  int64
#  2   sqft              136398 non-null  float64
#  3   zipcode           136398 non-null  category
#  4   beds              136398 non-null  int64
#  5   stories           136398 non-null  float64
#  6   sqft_big          136398 non-null  int64
#  7   beds_big          136398 non-null  int64
#  8   propertyType_cat  136398 non-null  category
#  9   city_cat          136398 non-null  category
#  10  state_cat         136398 non-null  category
#  11  status_cat        136398 non-null  category
#  12  max_rating        136398 non-null  int64
#  13  mean_rating       136398 non-null  float64
#  14  min_distance      136398 non-null  float64
#  15  mean_distance     136398 non-null  float64
# dtypes: category(5), float64(6), int64(5)
# memory usage: 13.1 MB

# %%
X.isna().sum()
# Out:
# baths               0
# fireplace           0
# sqft                0
# zipcode             0
# beds                0
# stories             0
# sqft_big            0
# beds_big            0
# propertyType_cat    0
# city_cat            0
# state_cat           0
# status_cat          0
# max_rating          0
# mean_rating         0
# min_distance        0
# mean_distance       0
# dtype: int64

# %%
y = data_d_preliminary[['price_sqft']]

# %%
y.isna().sum()
# Out:
# price_sqft    0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.67, 
                                                    random_state=RANDOM_SEED)

# %% [markdown]
# # Подготовка признака площадь для перемножения.

# %%
X_test
# Out:
#         baths  fireplace    sqft zipcode  beds  stories    target  sqft_big  \
# 206307    3.0          0  2301.0      78     1      1.0  304900.0         1
# 174008    2.0          0  1431.0      77     3      1.0  164000.0         0
# 228514    4.0          0  2301.0      89     4      2.0  425000.0         1
# 75671     3.0          0  2301.0      32     4      1.0  355000.0         1
# 158857    2.0          0  2025.0      34     1      2.0  269000.0         0
# ...       ...        ...     ...     ...   ...      ...       ...       ...
# 12516     1.0          0  1019.0      32     2      1.0   71995.0         0
# 227878    3.0          0  1629.0      32     3      1.0  259900.0         0
# 12607     3.0          0  1800.0      33     3      1.0  349500.0         0
# 48874     1.0          0  1900.0      37     1      1.0   66900.0         0
# 130447    3.0          0  2301.0      77     1      2.0  389000.0         1
#
#         beds_big propertyType_cat city_cat state_cat status_cat  max_rating  \
# 206307         0                5       84        33         26           5
# 174008         0                5       33        33         21           3
# 228514         0                5       44        23         21           7
# 75671          0                5       28         7         21           4
# 158857         0                5      102         7          3          10
# ...          ...              ...      ...       ...        ...         ...
# 12516          0                5       68         7         21           8
# 227878         0                5       65         7         21           5
# 12607          0                7       96         7         21           9
# 48874          0                5       38        32         21           5
# 130447         0                5       33        33         26           3
#
#         mean_rating  min_distance  mean_distance
# 206307         4.00          0.80           1.17
# 174008         2.00          2.35           3.23
# 228514         6.33          0.90           1.47
# 75671          4.00          0.90           1.31
# 158857         5.62          1.20           2.99
# ...             ...           ...            ...
# 12516          7.67          0.70           1.93
# 227878         4.33          0.40           0.63
# 12607          7.00          2.30           3.11
# 48874          4.67          0.63           1.65
# 130447         1.62          0.30           1.45
#
# [45012 rows x 17 columns]

# %%
columns1 = ['sqft','target']

# %%
X_test_mult = X_test[columns1]
X_test_mult = X_test_mult.reset_index()
X_test_mult
# Out:
#         index    sqft    target
# 0      206307  2301.0  304900.0
# 1      174008  1431.0  164000.0
# 2      228514  2301.0  425000.0
# 3       75671  2301.0  355000.0
# 4      158857  2025.0  269000.0
# ...       ...     ...       ...
# 45007   12516  1019.0   71995.0
# 45008  227878  1629.0  259900.0
# 45009   12607  1800.0  349500.0
# 45010   48874  1900.0   66900.0
# 45011  130447  2301.0  389000.0
#
# [45012 rows x 3 columns]

# %% [markdown]
# baths	fireplace	sqft	zipcode	beds	stories	target	sqft_big	beds_big	propertyType_cat	city_cat	state_cat	status_cat	max_rating	mean_rating	min_distance	mean_distance

# %%
X_test = X_test[['baths','fireplace','sqft','zipcode','beds','stories','sqft_big','beds_big','propertyType_cat','city_cat','state_cat','status_cat','max_rating','mean_rating','min_distance','mean_distance']]

# %%
X_train = X_train[['baths','fireplace','sqft','zipcode','beds','stories','sqft_big','beds_big','propertyType_cat','city_cat','state_cat','status_cat','max_rating','mean_rating','min_distance','mean_distance']]

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45012 entries, 206307 to 130447
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   baths             45012 non-null  float64
#  1   fireplace         45012 non-null  int64
#  2   sqft              45012 non-null  float64
#  3   zipcode           45012 non-null  category
#  4   beds              45012 non-null  int64
#  5   stories           45012 non-null  float64
#  6   sqft_big          45012 non-null  int64
#  7   beds_big          45012 non-null  int64
#  8   propertyType_cat  45012 non-null  category
#  9   city_cat          45012 non-null  category
#  10  state_cat         45012 non-null  category
#  11  status_cat        45012 non-null  category
#  12  max_rating        45012 non-null  int64
#  13  mean_rating       45012 non-null  float64
#  14  min_distance      45012 non-null  float64
#  15  mean_distance     45012 non-null  float64
# dtypes: category(5), float64(6), int64(5)
# memory usage: 4.3 MB

# %% [markdown]
# # Тестирование моделей

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return 100 * (np.abs(y_true - y_pred) / y_true).mean()

# %%
def grafik(y_test,y_pred):
    x_ax = range(len(y_test))
    plt.plot(x_ax, y_test, linewidth=1, label="original")
    plt.plot(x_ax, y_pred, linewidth=1.1, label="predicted")
    plt.title("y-test and y-predicted data")
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.legend(loc='best',fancybox=True, shadow=True)
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Линейная регрессия

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))
# Out:
# MAE: 71.7224879604246
# RMSE: 104.15478702839735
# R2: 0.04

# %%
y_pred_df = pd.DataFrame(y_pred, columns = ['pr'])
y_pred_df
# Out:
#                pr
# 0      156.758370
# 1      140.863525
# 2      174.010161
# 3      147.650922
# 4      199.303323
# ...           ...
# 45007  182.250509
# 45008  154.265704
# 45009  187.236912
# 45010  157.957226
# 45011  143.473130
#
# [45012 rows x 1 columns]

# %%
df_multiply = X_test_mult.join(y_pred_df)

# %%
df_multiply['y_pred_mult'] = df_multiply['sqft']*df_multiply['pr']

# %%
df_multiply
# Out:
#         index    sqft    target          pr    y_pred_mult
# 0      206307  2301.0  304900.0  156.758370  360701.008858
# 1      174008  1431.0  164000.0  140.863525  201575.704560
# 2      228514  2301.0  425000.0  174.010161  400397.380611
# 3       75671  2301.0  355000.0  147.650922  339744.772419
# 4      158857  2025.0  269000.0  199.303323  403589.228892
# ...       ...     ...       ...         ...            ...
# 45007   12516  1019.0   71995.0  182.250509  185713.268383
# 45008  227878  1629.0  259900.0  154.265704  251298.832239
# 45009   12607  1800.0  349500.0  187.236912  337026.440705
# 45010   48874  1900.0   66900.0  157.957226  300118.729940
# 45011  130447  2301.0  389000.0  143.473130  330131.671199
#
# [45012 rows x 5 columns]

# %%
y_test = df_multiply['target'].tolist()
y_pred = df_multiply['pr'].tolist()

# %%
print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))
# Out:
# MAE: 251585.92520118906
# RMSE: 287680.19547623344
# R2: -3.25

# %%
grafik(y_test,y_pred)

# %% [markdown]
# # Случайный лес

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score

model =  RandomForestRegressor(n_estimators=10 ,
                               oob_score=True,
                               random_state=RANDOM_SEED)
model.fit(X_train, y_train) # обучение
a = model.predict(X_test) # предсказание
a

score = model.score(X_train, y_train)
print("R-squared:", score)

# %%
y_pred = model.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# # Регрессия с дополнительными деревьями

# %%
model = ExtraTreesRegressor(n_estimators = 400, 
                                 n_jobs=-1, random_state=RANDOM_SEED)
model.fit(X_train, y_train)
predict_extra_tree = model.predict(X_test)
predict_extra_tree

np.array(y_test.index.values)
print(np.array(y_test.index.values))
# оцениваем точность
#print(mape(np.array(y_test.index.values), predict_extra_tree))
#print((mape_log(y_test, predict_extra_tree)))
#pprint(f"MAPE: {(mape_log(y_test, predict_extra_tree))*100:0.2f}%")

# %%
y_pred = model.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# # Катбуст

# %%
cat_features = ['zipcode','propertyType_cat','state_cat','city_cat','status_cat']

# %%
catboost = CatBoostRegressor(iterations = 1000,
                          learning_rate = 0.5,
                          random_seed = RANDOM_SEED,
                          eval_metric='RMSE',
                          depth = 10,
                          l2_leaf_reg = 1)
catboost.fit(X_train, y_train,
         cat_features = cat_features,
         eval_set=(X_test, y_test),
         verbose_eval=100,
         use_best_model=True,
         plot=True
         )

# %%
y_pred = catboost.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# Ридж

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge

# %%
ridge_regression = Ridge(alpha=0.1)
ridge_regression.fit(X_train, y_train)
print(ridge_regression.predict(X_test))
print(ridge_regression.score(X_test, y_test))

# %%
y_pred = ridge_regression.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# Лассо

# %%
from sklearn.linear_model import Lasso

# %%
lasso_regression = Lasso(alpha=0.1)
lasso_regression.fit(X_train, y_train)
print(lasso_regression.predict(X_test))
print(lasso_regression.score(X_test, y_test))

# %%
y_pred = lasso_regression.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# Градиентный бустинг

# %%
from sklearn.ensemble import GradientBoostingRegressor
gradient_boosting = GradientBoostingRegressor()
gradient_boosting.fit(X_train, y_train)

# %%
y_pred = gradient_boosting.predict(X_test)

print('MAE:',metrics.mean_absolute_error(y_test, y_pred))
print('RMSE:',metrics.mean_squared_error(y_test, y_pred) ** 0.5)
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))

# %%
grafik(y_test,y_pred)

# %% [markdown]
# # Анализ feature importance

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %%
feature_importance=catboost.feature_importances_
sorted_idx=np.argsort(feature_importance)
fig=plt.figure(figsize=(12,6))
plt.barh(range(len(sorted_idx)),feature_importance[sorted_idx],align='center')
plt.yticks(range(len(sorted_idx)),np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance')
