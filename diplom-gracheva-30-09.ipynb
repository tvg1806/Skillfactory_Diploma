# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/diploma/data.csv

# %%
# импорт библиотек

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import sys
import zipfile
import PIL
from PIL import ImageOps, ImageFilter
import re
import ast
from datetime import time, date, datetime
import random

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-paper')


from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error, f1_score, accuracy_score, roc_curve, roc_auc_score
from sklearn import metrics
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import VotingRegressor
from tqdm.notebook import tqdm
from catboost import CatBoostRegressor, Pool, cv

# keras
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as L
from tensorflow.keras.models import Model, Sequential

from tensorflow.keras.losses import MeanAbsolutePercentageError

#from transformers import AutoTokenizer, TFAutoModelForSequenceClassification, DataCollatorWithPadding

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns', 550) # больше колонок

os.environ['PYTHONHASHSEED']=str(42)

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
ITERATIONS = 200

# %%
DIR_DATA  = '../input/diploma/'

# %%
data_d = pd.read_csv(DIR_DATA+'data.csv')

# %%
data_d_help = data_d

# %% [markdown]
# # Вспомогательные функции расчета метрик.

# %%
# Функция расчета ошибки
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred-y_true)/y_true))

# %%
# Функция расчета ошибки для логарифмированной целевой переменнной
def mape_log(y_true, y_pred):
    return np.mean(np.abs((np.exp(y_pred)-np.exp(y_true))/np.exp(y_true)))

# %%
def print_regression_metrics(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    print(f'MSE = {mse:.2f}, RMSE = {rmse:.2f}')

# %% [markdown]
# # Общие сведения, задачи, примерный план работы.

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377185 entries, 0 to 377184
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        337267 non-null  object
#  1   private pool  4181 non-null    object
#  2   propertyType  342452 non-null  object
#  3   street        377183 non-null  object
#  4   baths         270847 non-null  object
#  5   homeFacts     377185 non-null  object
#  6   fireplace     103115 non-null  object
#  7   city          377151 non-null  object
#  8   schools       377185 non-null  object
#  9   sqft          336608 non-null  object
#  10  zipcode       377185 non-null  object
#  11  beds          285903 non-null  object
#  12  state         377185 non-null  object
#  13  stories       226470 non-null  object
#  14  mls-id        24942 non-null   object
#  15  PrivatePool   40311 non-null   object
#  16  MlsId         310305 non-null  object
#  17  target        374704 non-null  object
# dtypes: object(18)
# memory usage: 51.8+ MB

# %% [markdown]
# Удалено, потому что громоздко.

# %% [markdown]
# # Анализ целевой переменной.

# %%
data_d.head(10)
# Out:
#      status private pool        propertyType                street    baths  \
# 0    Active          NaN  Single Family Home        240 Heather Ln      3.5
# 1  for sale          NaN  single-family home     12911 E Heroy Ave  3 Baths
# 2  for sale          NaN  single-family home     2005 Westridge Rd  2 Baths
# 3  for sale          NaN  single-family home   4311 Livingston Ave  8 Baths
# 4  for sale          NaN            lot/land        1524 Kiscoe St      NaN
# 5  for sale          NaN           townhouse     1624 S Newkirk St      NaN
# 6    Active          NaN             Florida      552 Casanova Ct       NaN
# 7    Active          NaN                 NaN       6094 Mingle Dr       NaN
# 8    Active          NaN  Single Family Home         11182 Owl Ave        2
# 9       NaN          NaN       Single Family  8612 Cedar Plains Ln        3
#
#                                            homeFacts fireplace  \
# 0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...  Gas Logs
# 1  {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
# 2  {'atAGlanceFacts': [{'factValue': '1961', 'fac...       yes
# 3  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 4  {'atAGlanceFacts': [{'factValue': '', 'factLab...       NaN
# 5  {'atAGlanceFacts': [{'factValue': '1920', 'fac...       NaN
# 6  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       NaN
# 7  {'atAGlanceFacts': [{'factValue': '1976', 'fac...       NaN
# 8  {'atAGlanceFacts': [{'factValue': '1970', 'fac...       NaN
# 9  {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
#
#              city                                            schools  \
# 0  Southern Pines  [{'rating': ['4', '4', '7', 'NR', '4', '7', 'N...
# 1  Spokane Valley  [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# 2     Los Angeles  [{'rating': ['8/10', '4/10', '8/10'], 'data': ...
# 3          Dallas  [{'rating': ['9/10', '9/10', '10/10', '9/10'],...
# 4        Palm Bay  [{'rating': ['4/10', '5/10', '5/10'], 'data': ...
# 5    Philadelphia  [{'rating': [], 'data': {'Distance': [], 'Grad...
# 6       POINCIANA  [{'rating': ['3', '3', '1', 'NR'], 'data': {'D...
# 7         Memphis  [{'rating': ['4', '2', '2'], 'data': {'Distanc...
# 8      Mason City  [{'rating': ['2', '2', '4', '7', '4', 'NR'], '...
# 9         Houston  [{'rating': ['4/10', '3/10', '2/10'], 'data': ...
#
#          sqft zipcode    beds state stories mls-id PrivatePool       MlsId  \
# 0        2900   28387       4    NC     NaN    NaN         NaN      611019
# 1  1,947 sqft   99216  3 Beds    WA     2.0    NaN         NaN   201916904
# 2  3,000 sqft   90049  3 Beds    CA     1.0    NaN         yes  FR19221027
# 3  6,457 sqft   75205  5 Beds    TX     3.0    NaN         NaN    14191809
# 4         NaN   32908     NaN    FL     NaN    NaN         NaN      861745
# 5    897 sqft   19145  2 Beds    PA     2.0    NaN         NaN  PAPH847006
# 6       1,507   34759     NaN    FL     One    NaN         NaN    S5026943
# 7         NaN   38115     NaN    TN     NaN    NaN         NaN    10063506
# 8        3588   50401       3    IA     NaN    NaN         NaN      190988
# 9       1,930   77080       3    TX     2.0    NaN         NaN    73968331
#
#        target
# 0    $418,000
# 1    $310,000
# 2  $2,895,000
# 3  $2,395,000
# 4      $5,000
# 5    $209,000
# 6     181,500
# 7      68,000
# 8    $244,900
# 9    $311,995

# %% [markdown]
# # Вспомогательная функция извлечения числа из записи доллара.

# %%
def dollar_clean(string):
    i=0
    string_interm=re.findall('[0-9]+', string)
    
    if string_interm==[]:

        return np.NaN
    else:
        dollar_res=''
        while i<=(len(string_interm)-1):
            dollar_res=dollar_res + string_interm[i]
            i=i+1
        return float(dollar_res)

# %%
data_d.target = data_d.target.apply(lambda x: dollar_clean(str(x)))

# %%
data_d['target'].isna().unique()
# Out:
# array([False,  True])

# %%
data_d['target'].value_counts()
# Out:
# 225000.0    1806
# 275000.0    1650
# 250000.0    1644
# 350000.0    1641
# 325000.0    1562
#             ...
# 236070.0       1
# 752911.0       1
# 73360.0        1
# 455740.0       1
# 171306.0       1
# Name: target, Length: 34232, dtype: int64

# %%
data_d['target'].fillna(value = data_d.target.median(), inplace = True)

# %%
data_d['target'].isna().unique()
# Out:
# array([False])

# %%
sns.distplot(data_d['target'])
# Out:
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %% [markdown]
# Предварительное грубое удаление выбросов.

# %%
data_d.loc[data_d['target'].median()]
# Out:
# status                                                     Active
# private pool                                                  NaN
# propertyType                        Condo/Townhome/Row Home/Co-Op
# street                              1080 Wisconsin Ave NW Apt 304
# baths                                                         1.5
# homeFacts       {'atAGlanceFacts': [{'factValue': '1981', 'fac...
# fireplace                                                     NaN
# city                                                   Washington
# schools         [{'rating': ['8', '8', '8', '8', '9', '9', 'NR...
# sqft                                                          946
# zipcode                                                     20007
# beds                                                            1
# state                                                          DC
# stories                                                        3+
# mls-id                                                        NaN
# PrivatePool                                                   NaN
# MlsId                                                  DCDC440008
# target                                                   549500.0
# Name: 320000, dtype: object

# %%
data_d['target'].mean()
# Out:
# 642621.3540146082

# %%
data_d.loc[data_d['target']>data_d['target'].mean()]
# Out:
#           status private pool        propertyType                    street  \
# 2       for sale          NaN  single-family home         2005 Westridge Rd
# 3       for sale          NaN  single-family home       4311 Livingston Ave
# 10      for sale          NaN                coop  14205 Roosevelt Ave #512
# 15           New          NaN             2 Story              930 52nd St
# 17        Active          NaN           Townhouse            24 W 126th St
# ...          ...          ...                 ...                       ...
# 377168  for sale          NaN  single-family home          24080 Tuscany Ct
# 377174  for sale          NaN  single-family home         1107 E Euclid Ave
# 377179  For sale          NaN               Condo     2238 11th St NW APT 2
# 377180       NaN          NaN       Single Family         20800 NE 23rd Ave
# 377181  for sale          NaN               condo  3530 N Lake Shore Dr #4B
#
#           baths                                          homeFacts fireplace  \
# 2       2 Baths  {'atAGlanceFacts': [{'factValue': '1961', 'fac...       yes
# 3       8 Baths  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 10      2 Baths  {'atAGlanceFacts': [{'factValue': '1965', 'fac...       NaN
# 15          NaN  {'atAGlanceFacts': [{'factValue': '1905', 'fac...       NaN
# 17          NaN  {'atAGlanceFacts': [{'factValue': '1899', 'fac...       NaN
# ...         ...                                                ...       ...
# 377168  5 Baths  {'atAGlanceFacts': [{'factValue': '2006', 'fac...       yes
# 377174      NaN  {'atAGlanceFacts': [{'factValue': '1938', 'fac...       NaN
# 377179        3  {'atAGlanceFacts': [{'factValue': '2010', 'fac...       NaN
# 377180      6.0  {'atAGlanceFacts': [{'factValue': '1990', 'fac...       NaN
# 377181  3 Baths  {'atAGlanceFacts': [{'factValue': '1924', 'fac...       NaN
#
#                   city                                            schools  \
# 2          Los Angeles  [{'rating': ['8/10', '4/10', '8/10'], 'data': ...
# 3               Dallas  [{'rating': ['9/10', '9/10', '10/10', '9/10'],...
# 10            Flushing  [{'rating': ['2/10', '8/10', '10/10'], 'data':...
# 15            Brooklyn  [{'rating': ['8', '8', '3'], 'data': {'Distanc...
# 17            New York  [{'rating': ['2', '5', '1', '2'], 'data': {'Di...
# ...                ...                                                ...
# 377168  Bonita Springs  [{'rating': ['3/10', '8/10', '4/10', '5/10', '...
# 377174     San Antonio  [{'rating': ['4/10', '5/10', '3/10'], 'data': ...
# 377179      Washington  [{'rating': ['3/10', '3/10'], 'data': {'Distan...
# 377180           Miami  [{'rating': ['10/10', '5/10'], 'data': {'Dista...
# 377181         Chicago  [{'rating': ['1/10', '5/10', '7/10'], 'data': ...
#
#               sqft zipcode    beds state stories mls-id PrivatePool  \
# 2       3,000 sqft   90049  3 Beds    CA     1.0    NaN         yes
# 3       6,457 sqft   75205  5 Beds    TX     3.0    NaN         NaN
# 10      1,300 sqft   11354  3 Beds    NY     NaN    NaN         NaN
# 15             NaN   11219     NaN    NY     NaN    NaN         NaN
# 17           3,325   10027     NaN    NY     NaN    NaN         NaN
# ...            ...     ...     ...   ...     ...    ...         ...
# 377168  5,992 sqft   34134  4 Beds    FL     NaN    NaN         yes
# 377174    950 sqft   78212  2 Beds    TX     1.0    NaN         yes
# 377179       1,417   20001       2    DC     3.0    NaN         NaN
# 377180       4,017   33180       5    FL     0.0    NaN         Yes
# 377181  2,000 sqft   60657  3 Beds    IL     9.0    NaN         NaN
#
#              MlsId     target
# 2       FR19221027  2895000.0
# 3         14191809  2395000.0
# 10         3087630   669000.0
# 15         3182740  1650000.0
# 17         4975368  2650000.0
# ...            ...        ...
# 377168   219077435  2495000.0
# 377174     1391618   799500.0
# 377179  DCDC444306   799000.0
# 377180   A10702700  1249000.0
# 377181    10374233   674999.0
#
# [82882 rows x 18 columns]

# %%
data_d = data_d[(data_d['target'] < 550000)]

# %%
sns.distplot(data_d['target'])
# Out:
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %%
plt.violinplot(data_d['target'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7f0d9a2ced10>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7f0d9a30bf90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7f0d9a2ceb10>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7f0d9a2c09d0>}

# %%
data_d['target'].isna().unique()
# Out:
# array([False])

# %%
data_d.loc[data_d['target']==0]
# Out:
# Empty DataFrame
# Columns: [status, private pool, propertyType, street, baths, homeFacts, fireplace, city, schools, sqft, zipcode, beds, state, stories, mls-id, PrivatePool, MlsId, target]
# Index: []

# %%
data_d.loc[data_d['target'].min()]
# Out:
# status                                                   for sale
# private pool                                                  NaN
# propertyType                                   single-family home
# street                                          12911 E Heroy Ave
# baths                                                     3 Baths
# homeFacts       {'atAGlanceFacts': [{'factValue': '2019', 'fac...
# fireplace                                                     NaN
# city                                               Spokane Valley
# schools         [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# sqft                                                   1,947 sqft
# zipcode                                                     99216
# beds                                                       3 Beds
# state                                                          WA
# stories                                                       2.0
# mls-id                                                        NaN
# PrivatePool                                                   NaN
# MlsId                                                   201916904
# target                                                   310000.0
# Name: 1, dtype: object

# %%
#data_d.target = np.log(data_d.target[data_d.target > 0])

# %%
#data_d['target'].isna().unique()

# %% [markdown]
# # Площадь

# %% [markdown]
# Вспомогательная функция для получения численного значения площади. Если значение некорректно, возвращает NaN.

# %%
def extract_num_recurr_sqft(stroka,first_digit,len_s,i):
    if i == len_s and stroka[i].isdigit():
        return (float(first_digit + str(stroka[i])))
    elif i < len_s and (stroka[i].isdigit() or stroka[i] == '.'):
        return extract_num_recurr_sqft(stroka, (first_digit + str(stroka[i])), len_s, i+1)
    elif i < len_s and stroka[i] == ',':
        return extract_num_recurr_sqft(stroka, first_digit, len_s, i+1)
    else: return(float(first_digit))
                        
def extract_num_sqft(stroka,len_s,i):
  
    if i == len_s and not stroka[i].isdigit():
        return np.NaN
    elif i == len_s and stroka[i].isdigit():
        return float(stroka[i])
    elif i < len_s and stroka[i].isdigit():
        return extract_num_recurr_sqft(stroka,str(stroka[i]),len_s,i+1)
    else: return extract_num_sqft(stroka,len_s,i+1)

def main_extract_num_sqft(stroka):   
    len_s=len(stroka)-1
    
    return extract_num_sqft(stroka,len_s,0)

# %%
data_d.sqft = data_d.sqft.apply(lambda x: main_extract_num_sqft(str(x)))

# %%
data_d['sqft'].value_counts()
# Out:
# 0.0        10652
# 1200.0      1232
# 1000.0       906
# 1100.0       798
# 1500.0       769
#            ...
# 8754.0         1
# 64.0           1
# 6223.0         1
# 46996.0        1
# 7644.0         1
# Name: sqft, Length: 5854, dtype: int64

# %% [markdown]
# Вместо нулевых значений подставляю нан для упрощения последующей замены.

# %%
data_d.sqft = data_d.sqft.apply(lambda x: np.NaN if x==0.0 else x)

# %%
data_d['sqft'].value_counts()
# Out:
# 1200.0     1232
# 1000.0      906
# 1100.0      798
# 1500.0      769
# 1400.0      749
#            ...
# 8754.0        1
# 64.0          1
# 6223.0        1
# 46996.0       1
# 7644.0        1
# Name: sqft, Length: 5853, dtype: int64

# %%
data_d['sqft'].unique()
# Out:
# array([2.90000000e+03, 1.94700000e+03,            nan, ...,
#        7.20000000e+01, 4.56602479e+08, 7.64400000e+03])

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276948 entries, 0 to 377184
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        246827 non-null  object
#  1   private pool  2742 non-null    object
#  2   propertyType  253129 non-null  object
#  3   street        276947 non-null  object
#  4   baths         194069 non-null  object
#  5   homeFacts     276948 non-null  object
#  6   fireplace     67586 non-null   object
#  7   city          276928 non-null  object
#  8   schools       276948 non-null  object
#  9   sqft          235646 non-null  float64
#  10  zipcode       276948 non-null  object
#  11  beds          207050 non-null  object
#  12  state         276948 non-null  object
#  13  stories       169302 non-null  object
#  14  mls-id        19149 non-null   object
#  15  PrivatePool   22749 non-null   object
#  16  MlsId         224599 non-null  object
#  17  target        276948 non-null  float64
# dtypes: float64(2), object(16)
# memory usage: 48.2+ MB

# %%
data_d.loc[data_d['sqft'].min()]
# Out:
# status                                                   for sale
# private pool                                                  NaN
# propertyType                                   single-family home
# street                                          12911 E Heroy Ave
# baths                                                     3 Baths
# homeFacts       {'atAGlanceFacts': [{'factValue': '2019', 'fac...
# fireplace                                                     NaN
# city                                               Spokane Valley
# schools         [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# sqft                                                       1947.0
# zipcode                                                     99216
# beds                                                       3 Beds
# state                                                          WA
# stories                                                       2.0
# mls-id                                                        NaN
# PrivatePool                                                   NaN
# MlsId                                                   201916904
# target                                                   310000.0
# Name: 1, dtype: object

# %% [markdown]
# # Спальни - приведение к численному виду.

# %%
data_d['beds'].value_counts()
# Out:
# 3 Beds        42890
# 4 Beds        24758
# 3             24356
# 2 Beds        20440
# 4             12920
#               ...
# 40 acres          1
# 6.53 acres        1
# 9,291 sqft        1
# 6,115 sqft        1
# 8,479 sqft        1
# Name: beds, Length: 959, dtype: int64

# %%
#data_d = data_d.drop(np.where(data_d['beds'] == '# Bedrooms 1st Floor')[0])

# %%
data_d.loc[data_d['beds'] == '# Bedrooms 1st Floor']
# Out:
#           status private pool propertyType               street baths  \
# 364340  A Active          NaN         Land  4500 Harris Hill Rd   NaN
#
#                                                 homeFacts fireplace      city  \
# 364340  {'atAGlanceFacts': [{'factValue': '1922', 'fac...       NaN  Falconer
#
#                                                   schools    sqft zipcode  \
# 364340  [{'rating': ['5', '5', 'NR', 'NR', 'NR'], 'dat...  1596.0   14733
#
#                         beds state stories mls-id PrivatePool     MlsId  \
# 364340  # Bedrooms 1st Floor    NY     NaN    NaN         NaN  R1171774
#
#          target
# 364340  79000.0

# %% [markdown]
# Вспомогательная функция stirng_part со вложенной string_part_extract для выделения символьной части.

# %%
def string_part_extract(string, len_s, i, res_str):
    if i<len_s:
      
        if string[i].isdigit(): return string_part_extract(string, len_s, i+1, res_str)
        else:
    
            return string_part_extract(string, len_s, i+1, res_str+string[i])
    elif i==len_s:
    
        if string[i].isdigit(): 
           
            return res_str
        
        else:
       
            return (res_str+string[i])
    
    
    
    
def stirng_part(string):
    len_s = len(str(string))-1
    pus = ""
    return string_part_extract(str(string), len_s, 0, pus)

# %% [markdown]
# Вспомогательная функция, проверяет определенные слова в описании признака.

# %%
def subsrting_beds(source_string):
    list_of_strings = ['Bd','Bedrooms','Beds','Bed','bd','beds','bed','bedrooms']
    for substring in list_of_strings:
        if substring in source_string:
            return False
    return True

# %% [markdown]
# Предварительная обработка признака для систематизации словесных комментариев. (Для того, чтобы значимые величины не попали в выбросы.)

# %%
#data_d = data_d.drop(np.where(data_d['beds'] == '# Bedrooms 1st Floor'))
data_d.beds = data_d.beds.apply(lambda x: 1 if subsrting_beds(stirng_part(x)) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if 'Bath' in str(x) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if x == '1-2 Beds' or x == '-- bd' else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if x == '1-2 Beds' or x == '-- bd' else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('sqft')>-1) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('acres')>-1) else x)
data_d.beds = data_d.beds.apply(lambda x: 1 if (str(x).find('# Bedrooms 1st Floor')>-1) else x)
data_d['beds'].unique()                        
data_d['beds'].value_counts()
# Out:
# 1                                                                         157719
# 3 Beds                                                                     42890
# 4 Beds                                                                     24758
# 2 Beds                                                                     20440
# 3 bd                                                                       11138
# 4 bd                                                                        6106
# 5 Beds                                                                      4814
# 2 bd                                                                        4650
# 5 bd                                                                        1317
# 6 Beds                                                                      1142
# 1 bd                                                                         982
# 6 bd                                                                         266
# 7 Beds                                                                       237
# 8 Beds                                                                       164
# 9 Beds                                                                        75
# 8 bd                                                                          47
# 64 Beds                                                                       44
# 7 bd                                                                          41
# 10 Beds                                                                       38
# 9 bd                                                                          15
# 11 Beds                                                                       14
# 12 Beds                                                                       13
# 10 bd                                                                          8
# 16 Beds                                                                        6
# 12 bd                                                                          5
# 14 Beds                                                                        3
# 11 bd                                                                          2
# 18 Beds                                                                        2
# 13 Beds                                                                        1
# 20 Beds                                                                        1
# 28 Beds                                                                        1
# 14 bd                                                                          1
# 3 or More Bedrooms                                                             1
# 24 bd                                                                          1
# 15 Beds                                                                        1
# 13 bd                                                                          1
# 3 or More Bedrooms, Dining Room, Living Room, Range/Oven, Refrigerator         1
# 17 Beds                                                                        1
# 44 Beds                                                                        1
# 24 Beds                                                                        1
# Name: beds, dtype: int64

# %%
data_d.loc[data_d['beds'] == '# Bedrooms 1st Floor']
# Out:
# Empty DataFrame
# Columns: [status, private pool, propertyType, street, baths, homeFacts, fireplace, city, schools, sqft, zipcode, beds, state, stories, mls-id, PrivatePool, MlsId, target]
# Index: []

# %% [markdown]
# Вспомогательная функция для выбора числового значения признака спальни.

# %%
def otbor(stroka,i):
    if i == len(stroka): return(int(stroka))
    elif stroka[i] == ' ':
            return (int(stroka[:i]))
    else: return otbor(stroka,i+1)

# %%
data_d.beds = data_d.beds.apply(lambda x: otbor(str(x),0))

# %%
data_d['beds'].unique()
# Out:
# array([ 1,  3,  2,  4,  5,  6,  8,  7, 10, 64, 24,  9, 11, 16, 18, 12, 44,
#        17, 14, 13, 15, 28, 20])

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276948 entries, 0 to 377184
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        246827 non-null  object
#  1   private pool  2742 non-null    object
#  2   propertyType  253129 non-null  object
#  3   street        276947 non-null  object
#  4   baths         194069 non-null  object
#  5   homeFacts     276948 non-null  object
#  6   fireplace     67586 non-null   object
#  7   city          276928 non-null  object
#  8   schools       276948 non-null  object
#  9   sqft          235646 non-null  float64
#  10  zipcode       276948 non-null  object
#  11  beds          276948 non-null  int64
#  12  state         276948 non-null  object
#  13  stories       169302 non-null  object
#  14  mls-id        19149 non-null   object
#  15  PrivatePool   22749 non-null   object
#  16  MlsId         224599 non-null  object
#  17  target        276948 non-null  float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 48.2+ MB

# %% [markdown]
# # Визуализация и обработка признака спальни (beds).

# %%
sns.distplot(data_d['beds'])
# Out:
# <AxesSubplot:xlabel='beds', ylabel='Density'>

# %%
t = data_d.loc[data_d['beds']>10]

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 6317 to 370966
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        99 non-null     object
#  1   private pool  0 non-null      object
#  2   propertyType  99 non-null     object
#  3   street        99 non-null     object
#  4   baths         43 non-null     object
#  5   homeFacts     99 non-null     object
#  6   fireplace     7 non-null      object
#  7   city          99 non-null     object
#  8   schools       99 non-null     object
#  9   sqft          47 non-null     float64
#  10  zipcode       99 non-null     object
#  11  beds          99 non-null     int64
#  12  state         99 non-null     object
#  13  stories       21 non-null     object
#  14  mls-id        9 non-null      object
#  15  PrivatePool   1 non-null      object
#  16  MlsId         86 non-null     object
#  17  target        99 non-null     float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 14.7+ KB

# %%
data_d = data_d[(data_d['beds'] < 10)]

# %%
sns.distplot(data_d['beds'])
# Out:
# <AxesSubplot:xlabel='beds', ylabel='Density'>

# %%
y = data_d['target']

# %%
x = data_d['beds']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Количество комнат', fontsize = 15)
plt.ylabel('Цена', fontsize = 15)
plt.title('Зависимость цены от количества комнат', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от количества комнат')

# %%
#data_d.plot(y='target',x='beds', kind='line',
#           color='blue',  title='Зависимость цены от города')

# %%
sns.boxplot(data_d['beds'])
# Out:
# <AxesSubplot:xlabel='beds'>

# %% [markdown]
# # Заполнение пропусков признака площадь по количеству комнат (примерное)

# %%
data_d['sqft'].fillna(data_d.groupby('beds')['sqft'].transform('mean'), inplace = True)

# %%
data_d.head(30)
# Out:
#               status private pool        propertyType  \
# 0             Active          NaN  Single Family Home
# 1           for sale          NaN  single-family home
# 4           for sale          NaN            lot/land
# 5           for sale          NaN           townhouse
# 6             Active          NaN             Florida
# 7             Active          NaN                 NaN
# 8             Active          NaN  Single Family Home
# 9                NaN          NaN       Single Family
# 11            Active          NaN             English
# 12          for sale          NaN  single-family home
# 13  New construction          NaN       Single Family
# 14               NaN          NaN       Single Family
# 16            Active          NaN                 NaN
# 18          for sale          NaN  single-family home
# 20          For sale          NaN       Single Family
# 23          for sale          NaN  single-family home
# 24          for sale          NaN  single-family home
# 27          for sale          NaN  single-family home
# 31          For sale          NaN       Single Family
# 32          for sale          NaN  single-family home
# 33               NaN          NaN               Condo
# 34          for sale          NaN  single-family home
# 35          for sale          NaN               condo
# 36          For sale          NaN       Single Family
# 37          For sale          NaN       Single Family
# 38          For sale          NaN       Single Family
# 39          for sale          NaN               condo
# 40            Active          NaN                 NaN
# 44          for sale          NaN               condo
# 45           Pending          NaN  Single Family Home
#
#                         street         baths  \
# 0               240 Heather Ln           3.5
# 1            12911 E Heroy Ave       3 Baths
# 4               1524 Kiscoe St           NaN
# 5            1624 S Newkirk St           NaN
# 6             552 Casanova Ct            NaN
# 7              6094 Mingle Dr            NaN
# 8                11182 Owl Ave             2
# 9         8612 Cedar Plains Ln             3
# 11      4222 False Cypress Ln            NaN
# 12            16373 NW 16th St       3 Baths
# 13              1538 Umpqua Dr  Bathrooms: 2
# 14          15351 Falmouth Ave             3
# 16            2402 NW 22nd Rd          1,750
# 18          22702 Alderdale Ln       4 Baths
# 20            5930 E Avenue T2          2 ba
# 23        4234 Orchard Pass Dr       4 Baths
# 24             703 W Gemini Ln       2 Baths
# 27        2104 Lou Ellen Ln #B       3 Baths
# 31             6712 N Glen Ave  Bathrooms: 2
# 32         2043 SE New York St       2 Baths
# 33    3750 NE 170th St APT 407           2.0
# 34           7314 Melvin Cir N       2 Baths
# 35       423 N Church St #13-A           NaN
# 36           2627 N Arthur Ave           3.0
# 37             3360 SW 29th St             2
# 38      5531 Eureka Springs Rd  Bathrooms: 1
# 39      316 N Henderson Ave #4       3 Baths
# 40           1104 Rotonda Cir            NaN
# 44  4504 W Lake Mead Blvd #201       2 Baths
# 45            11539 Kismet Ave             2
#
#                                             homeFacts fireplace  \
# 0   {'atAGlanceFacts': [{'factValue': '2019', 'fac...  Gas Logs
# 1   {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
# 4   {'atAGlanceFacts': [{'factValue': '', 'factLab...       NaN
# 5   {'atAGlanceFacts': [{'factValue': '1920', 'fac...       NaN
# 6   {'atAGlanceFacts': [{'factValue': '2006', 'fac...       NaN
# 7   {'atAGlanceFacts': [{'factValue': '1976', 'fac...       NaN
# 8   {'atAGlanceFacts': [{'factValue': '1970', 'fac...       NaN
# 9   {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
# 11  {'atAGlanceFacts': [{'factValue': '2015', 'fac...       NaN
# 12  {'atAGlanceFacts': [{'factValue': '1996', 'fac...       NaN
# 13  {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
# 14  {'atAGlanceFacts': [{'factValue': '1982', 'fac...       NaN
# 16  {'atAGlanceFacts': [{'factValue': '2008', 'fac...       NaN
# 18  {'atAGlanceFacts': [{'factValue': '2016', 'fac...       yes
# 20  {'atAGlanceFacts': [{'factValue': '1989', 'fac...       NaN
# 23  {'atAGlanceFacts': [{'factValue': '2019', 'fac...       yes
# 24  {'atAGlanceFacts': [{'factValue': '2014', 'fac...       yes
# 27  {'atAGlanceFacts': [{'factValue': '', 'factLab...       NaN
# 31  {'atAGlanceFacts': [{'factValue': '1960', 'fac...       NaN
# 32  {'atAGlanceFacts': [{'factValue': '1977', 'fac...       NaN
# 33  {'atAGlanceFacts': [{'factValue': '1972', 'fac...       NaN
# 34  {'atAGlanceFacts': [{'factValue': '1963', 'fac...       NaN
# 35  {'atAGlanceFacts': [{'factValue': '1981', 'fac...       NaN
# 36  {'atAGlanceFacts': [{'factValue': '1949', 'fac...       Yes
# 37  {'atAGlanceFacts': [{'factValue': '1954', 'fac...       NaN
# 38  {'atAGlanceFacts': [{'factValue': '1930', 'fac...       NaN
# 39  {'atAGlanceFacts': [{'factValue': '2019', 'fac...       NaN
# 40  {'atAGlanceFacts': [{'factValue': '', 'factLab...       NaN
# 44  {'atAGlanceFacts': [{'factValue': '1994', 'fac...       yes
# 45  {'atAGlanceFacts': [{'factValue': '1958', 'fac...       NaN
#
#                  city                                            schools  \
# 0      Southern Pines  [{'rating': ['4', '4', '7', 'NR', '4', '7', 'N...
# 1      Spokane Valley  [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# 4            Palm Bay  [{'rating': ['4/10', '5/10', '5/10'], 'data': ...
# 5        Philadelphia  [{'rating': [], 'data': {'Distance': [], 'Grad...
# 6           POINCIANA  [{'rating': ['3', '3', '1', 'NR'], 'data': {'D...
# 7             Memphis  [{'rating': ['4', '2', '2'], 'data': {'Distanc...
# 8          Mason City  [{'rating': ['2', '2', '4', '7', '4', 'NR'], '...
# 9             Houston  [{'rating': ['4/10', '3/10', '2/10'], 'data': ...
# 11            Houston  [{'rating': ['6', '3', '6', '1', '5'], 'data':...
# 12     Pembroke Pines  [{'rating': ['8/10', '7/10', '7/10'], 'data': ...
# 13             Eugene  [{'rating': ['7/10', '7/10', '8/10'], 'data': ...
# 14            Houston  [{'rating': ['4/10', '5/10', '7/10'], 'data': ...
# 16    Fort Lauderdale  [{'rating': ['4', 'NR', '3', 'NR'], 'data': {'...
# 18            Tomball  [{'rating': ['7/10', '7/10'], 'data': {'Distan...
# 20           Palmdale  [{'rating': ['3/10', '5/10'], 'data': {'Distan...
# 23             Spring  [{'rating': ['9/10', '8/10', '8/10'], 'data': ...
# 24            Killeen  [{'rating': ['3/10', '6/10', '6/10'], 'data': ...
# 27            Houston  [{'rating': ['6/10', '9/10', '3/10'], 'data': ...
# 31              Tampa  [{'rating': ['5/10', '2/10', '4/10'], 'data': ...
# 32     Pt Saint Lucie  [{'rating': ['7/10', '5/10', '5/10', '4/10', '...
# 33  North Miami Beach  [{'rating': ['10/10', '6/10'], 'data': {'Dista...
# 34       Jacksonville  [{'rating': ['2/10', '2/10', '4/10'], 'data': ...
# 35          Charlotte  [{'rating': ['7/10', '4/10', '8/10'], 'data': ...
# 36             Fresno  [{'rating': ['3/10', '4/10'], 'data': {'Distan...
# 37              Miami  [{'rating': ['10/10', '5/10'], 'data': {'Dista...
# 38              Tampa  [{'rating': ['1/10', '2/10', '3/10'], 'data': ...
# 39             Dallas  [{'rating': ['5/10', '6/10', '5/10'], 'data': ...
# 40       ROTONDA WEST  [{'rating': ['6', '6', '7'], 'data': {'Distanc...
# 44          Las Vegas  [{'rating': ['1/10', 'None/10', '2/10'], 'data...
# 45             Sylmar  [{'rating': ['4', '2', '1', 'NR', '6', '7', 'N...
#
#            sqft zipcode  beds state    stories      mls-id PrivatePool  \
# 0   2900.000000   28387     1    NC        NaN         NaN         NaN
# 1   1947.000000   99216     3    WA        2.0         NaN         NaN
# 4   6594.616652   32908     1    FL        NaN         NaN         NaN
# 5    897.000000   19145     2    PA        2.0         NaN         NaN
# 6   1507.000000   34759     1    FL        One         NaN         NaN
# 7   6594.616652   38115     1    TN        NaN         NaN         NaN
# 8   3588.000000   50401     1    IA        NaN         NaN         NaN
# 9   1930.000000   77080     1    TX        2.0         NaN         NaN
# 11  3130.000000   77068     1    TX          2         NaN         NaN
# 12  2839.000000   33028     4    FL        1.0         NaN         yes
# 13  1820.000000   97401     3    OR        1.0    19221142         NaN
# 14  2454.000000   77084     1    TX        2.0         NaN         NaN
# 16  2203.000000   33311     1    FL        NaN         NaN         NaN
# 18  3080.000000   77375     4    TX        2.0         NaN         NaN
# 20  1731.000000   93552     4    CA        NaN  SR19195113         NaN
# 23  3645.000000   77386     4    TX        2.0         NaN         NaN
# 24  1953.000000   76542     4    TX        1.0         NaN         NaN
# 27  2575.000000   77018     3    TX        NaN         NaN         NaN
# 31  1677.000000   33614     4    FL        0.0    T3159863         NaN
# 32  1176.000000   34952     3    FL        NaN         NaN         NaN
# 33  1085.000000   33160     1    FL        0.0         NaN         NaN
# 34   864.000000   32210     3    FL        NaN         NaN         NaN
# 35   900.000000   28202     2    NC        NaN         NaN         NaN
# 36  1448.000000   93705     1    CA          0         NaN         NaN
# 37  1396.000000   33133     1    FL        0.0         NaN         NaN
# 38  1232.000000   33610     2    FL        0.0    T3204536         NaN
# 39  1720.000000   75214     2    TX        2.0         NaN         NaN
# 40  6594.616652   33947     1    FL        NaN         NaN         NaN
# 44  1081.000000   89108     2    NV        2.0         NaN         NaN
# 45  1101.000000   91342     1    CA  One Level         NaN         NaN
#
#          MlsId    target
# 0       611019  418000.0
# 1    201916904  310000.0
# 4       861745    5000.0
# 5   PAPH847006  209000.0
# 6     S5026943  181500.0
# 7     10063506   68000.0
# 8       190988  244900.0
# 9     73968331  311995.0
# 11     5741322  260000.0
# 12   A10767242  525000.0
# 13         NaN  499900.0
# 14    65299510  168800.0
# 16   F10207914  335000.0
# 18    95301365  365000.0
# 20         NaN  375000.0
# 23    13624110  499007.0
# 24     6208631  182000.0
# 27    33856933  499900.0
# 31         NaN  262000.0
# 32   F10174710  204800.0
# 33   A10775650  179000.0
# 34     1027438  105000.0
# 35     3554602  260000.0
# 36      533746  284900.0
# 37   A10743020  495000.0
# 38         NaN  117900.0
# 39    14150656  385000.0
# 40    D6107075   54000.0
# 44     2160520  125000.0
# 45  SR19267193  499000.0

# %%
data_d['sqft'].unique()
# Out:
# array([2.90000000e+03, 1.94700000e+03, 6.59461665e+03, ...,
#        7.20000000e+01, 4.56602479e+08, 7.64400000e+03])

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 276803 entries, 0 to 377184
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        246682 non-null  object
#  1   private pool  2742 non-null    object
#  2   propertyType  252984 non-null  object
#  3   street        276802 non-null  object
#  4   baths         193984 non-null  object
#  5   homeFacts     276803 non-null  object
#  6   fireplace     67573 non-null   object
#  7   city          276783 non-null  object
#  8   schools       276803 non-null  object
#  9   sqft          276803 non-null  float64
#  10  zipcode       276803 non-null  object
#  11  beds          276803 non-null  int64
#  12  state         276803 non-null  object
#  13  stories       169266 non-null  object
#  14  mls-id        19133 non-null   object
#  15  PrivatePool   22747 non-null   object
#  16  MlsId         224478 non-null  object
#  17  target        276803 non-null  float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 40.1+ MB

# %% [markdown]
# # Визуализация признака площадь (sqft).

# %%
sns.distplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='Density'>

# %%
data_d = data_d[(data_d['sqft'] < 10000)]

# %%
sns.distplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft', ylabel='Density'>

# %%
x = data_d['sqft']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Цена', fontsize = 15)
plt.title('Зависимость цены от площади', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от площади')

# %%
sns.boxplot(data_d['sqft'])
# Out:
# <AxesSubplot:xlabel='sqft'>

# %% [markdown]
# # Ванны - приведение к численному виду.

# %%
data_d['baths'].unique()
# Out:
# array(['3.5', '3 Baths', nan, '2', '3', 'Bathrooms: 2', '1,750',
#        '4 Baths', '2 ba', '2 Baths', '2.0', '3.0', 'Bathrooms: 1',
#        '2.1 Baths', '2.5 Baths', '1', '4.5', 'Bathrooms: 4', '3 ba',
#        '4.0', '2,500', '5.5 Baths', '1.0', 'Bathrooms: 3', '1.5', '2.5',
#        '4,000', '3.5 Baths', '2,000', '1 ba', '3.5 ba', '0', '1,500',
#        '2,250', '1,000', '3,500', '4', '~', '3,000', '2,750', '750',
#        '5 Baths', '1.5 ba', '1,250', '1.5 Baths', '6 Baths', '0 / 0',
#        '5 ba', '4 ba', '2.5+', '6.0', '4.5 Baths', '-- baths', '7',
#        '1.5+', '6', '5,000', '5', '1.1 Baths', 'Bathrooms: 5', '5.5',
#        '19 Baths', '1.75 Baths', 'Bathrooms: 6', '13 Baths', '5.0',
#        'Sq. Ft. ', '2.5 ba', '3.5+', '7 Baths', 'Bathrooms: 241', '8.0',
#        '6.5', 'Bathrooms: 7', '7,500+', '4.5+', '6.5 Baths', '8 Baths',
#        '1.75 ba', '0.00', '2.25 Baths', '3.1 Baths', '4.5 ba',
#        '2.75 Baths', '0.0', '10', '16 Baths', '7.0', '20.0',
#        'Bathrooms: 8', '2 baths', '15 Baths', '11 Baths', '6.5+',
#        '3.25 Baths', '5.5+', '3.75 Baths', '7 ba', 'Bathrooms: 11',
#        '13.0', 'Bathrooms: SemiMod', '2.25 ba', '3.3 Baths', '9.0',
#        '1.25 Baths', '8', '9 Baths', '20', '2.2 Baths', '3 baths',
#        '14 Baths', '25 Baths', '0.5 Baths', '8 ba', '1.8 Baths',
#        'Bathrooms: 14', '8.5 Baths', '12 Baths', '6 ba', '2.8 Baths',
#        '13', '15.0', '30', '0.75 Baths', '10 Baths', 'Bathrooms: 12',
#        '5.5 ba', '11.0', '30 Baths', '4.1 Baths', '20 Baths',
#        'Bathrooms: 9'], dtype=object)

# %% [markdown]
# Вспомогательная функция извлекает численное значение из текста. Если значение некорректно, выдает 1. Применила здесь, а также для обработки этажей.)

# %%
def extract_num_recurr(stroka,first_digit,len_s,i):
    if i == len_s and stroka[i].isdigit():
        return (float(first_digit + str(stroka[i])))
    elif i < len_s and (stroka[i].isdigit() or stroka[i] == '.'):
        return extract_num_recurr(stroka, (first_digit + str(stroka[i])), len_s, i+1)
    
    else: return(float(first_digit))
                        
def extract_num(stroka,len_s,i):
  
    if i == len_s and not stroka[i].isdigit():
        return 1
    elif i == len_s and stroka[i].isdigit():
        return float(stroka[i])
    elif i < len_s and stroka[i].isdigit():
        return extract_num_recurr(stroka,str(stroka[i]),len_s,i+1)
    else: return extract_num(stroka,len_s,i+1)

def main_extract_num(stroka):   
    len_s=len(stroka)-1
    
    return extract_num(stroka,len_s,0)

# %%
data_d.baths = data_d.baths.apply(lambda x: main_extract_num(str(x)))

# %%
data_d['baths'].unique()
# Out:
# array([3.50e+00, 3.00e+00, 1.00e+00, 2.00e+00, 4.00e+00, 2.10e+00,
#        2.50e+00, 4.50e+00, 5.50e+00, 1.50e+00, 0.00e+00, 7.50e+02,
#        5.00e+00, 6.00e+00, 7.00e+00, 1.10e+00, 1.90e+01, 1.75e+00,
#        1.30e+01, 2.41e+02, 8.00e+00, 6.50e+00, 2.25e+00, 3.10e+00,
#        2.75e+00, 1.00e+01, 1.60e+01, 2.00e+01, 1.50e+01, 1.10e+01,
#        3.25e+00, 3.75e+00, 3.30e+00, 9.00e+00, 1.25e+00, 2.20e+00,
#        1.40e+01, 2.50e+01, 5.00e-01, 1.80e+00, 8.50e+00, 1.20e+01,
#        2.80e+00, 3.00e+01, 7.50e-01, 4.10e+00])

# %%
data_d['baths'].isna().unique()
# Out:
# array([False])

# %% [markdown]
# # Визуализация и обработка признака ванны (baths).

# %%
sns.distplot(data_d['baths'])
# Out:
# <AxesSubplot:xlabel='baths', ylabel='Density'>

# %%
t = data_d.loc[data_d['baths']>10]

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 1109 to 376147
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   status        170 non-null    object
#  1   private pool  0 non-null      object
#  2   propertyType  149 non-null    object
#  3   street        173 non-null    object
#  4   baths         173 non-null    float64
#  5   homeFacts     173 non-null    object
#  6   fireplace     46 non-null     object
#  7   city          173 non-null    object
#  8   schools       173 non-null    object
#  9   sqft          173 non-null    float64
#  10  zipcode       173 non-null    object
#  11  beds          173 non-null    int64
#  12  state         173 non-null    object
#  13  stories       59 non-null     object
#  14  mls-id        3 non-null      object
#  15  PrivatePool   1 non-null      object
#  16  MlsId         166 non-null    object
#  17  target        173 non-null    float64
# dtypes: float64(3), int64(1), object(14)
# memory usage: 25.7+ KB

# %%
data_d = data_d[data_d['baths']<10]

# %%
sns.distplot(data_d['baths'])
# Out:
# <AxesSubplot:xlabel='baths', ylabel='Density'>

# %%
x = data_d['baths']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Оборудование ванн', fontsize = 15)
plt.title('Зависимость цены от оборудования ванн', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от оборудования ванн')

# %% [markdown]
#  # Камин

# %% [markdown]
# Вспомогательная функция для приведения признака числа каминов к численному виду.

# %%
def fireplaces_def(stroka):
    if stroka == 'yes': return 1
    elif stroka == 'Yes': return 1
    elif stroka == '1': return 1
    elif stroka == '2': return 2
    else: return 0

# %%
data_d['fireplace'].value_counts()
# Out:
# yes                                                                32787
# Yes                                                                13334
# 1                                                                  10511
# Not Applicable                                                      1952
# 2                                                                    822
#                                                                    ...
# Gas Logs, In Den/Family Room, In Living Room, Wood Burning             1
# 7                                                                      1
# Great Room, Natural Gas, Wood Burning                                  1
# Air Filter, Ceiling Fan, Central Vacuum, SMTHR, Walk-In Closets        1
# Fireplace-Gas, Fireplace-Wood, Patio, Walk-in Closet                   1
# Name: fireplace, Length: 1028, dtype: int64

# %%
data_d.fireplace = data_d.fireplace.apply(lambda x: fireplaces_def(str(x)))

# %%
data_d['fireplace'].unique()
# Out:
# array([0, 1, 2])

# %%
data_d['fireplace'].isna().unique()
# Out:
# array([False])

# %%
x = data_d['fireplace']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Камин', fontsize = 15)
plt.title('Зависимость цены от наличия камина', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от наличия камина')

# %% [markdown]
# # Бассейн. Анализ.

# %%
data_d['private pool'].value_counts()
# Out:
# Yes    2729
# Name: private pool, dtype: int64

# %%
data_d.loc[data_d['private pool'] == 'Yes']
# Out:
#                            status private pool           propertyType  \
# 205                      For sale          Yes          Single Family
# 321                      For sale          Yes          Single Family
# 355                      For sale          Yes  Mobile / Manufactured
# 425     Pre-foreclosure / auction          Yes          Single Family
# 447                      For sale          Yes          Single Family
# ...                           ...          ...                    ...
# 376298            Pre-foreclosure          Yes          Single Family
# 376340                   For sale          Yes                  Condo
# 376582                   For sale          Yes          Single Family
# 376686                   For sale          Yes          Single Family
# 376694                   For sale          Yes                  Condo
#
#                              street  baths  \
# 205                  1403 Betton Rd    2.0
# 321              3296 Ledgewood Cir    3.0
# 355            2250 N Broadway # 42    2.0
# 425                7632 Hillside Dr    2.0
# 447       5370 Christie Ann Pl # 17    2.0
# ...                             ...    ...
# 376298            15369 Daybreak Ln    3.0
# 376340  200 River Vista Dr UNIT 436    2.0
# 376582           3235 Landover Blvd    2.0
# 376686          2609 S Marigold Ave    3.0
# 376694    5980 Shore Blvd S APT 312    3.0
#
#                                                 homeFacts  fireplace  \
# 205     {'atAGlanceFacts': [{'factValue': '1958', 'fac...          1
# 321     {'atAGlanceFacts': [{'factValue': '2017', 'fac...          0
# 355     {'atAGlanceFacts': [{'factValue': '1976', 'fac...          0
# 425     {'atAGlanceFacts': [{'factValue': '1964', 'fac...          1
# 447     {'atAGlanceFacts': [{'factValue': '1992', 'fac...          0
# ...                                                   ...        ...
# 376298  {'atAGlanceFacts': [{'factValue': '1990', 'fac...          1
# 376340  {'atAGlanceFacts': [{'factValue': '2010', 'fac...          0
# 376582  {'atAGlanceFacts': [{'factValue': '2005', 'fac...          0
# 376686  {'atAGlanceFacts': [{'factValue': '1979', 'fac...          0
# 376694  {'atAGlanceFacts': [{'factValue': '1972', 'fac...          0
#
#                 city                                            schools  \
# 205      Tallahassee  [{'rating': ['4/10', '5/10', '7/10'], 'data': ...
# 321        Riverside  [{'rating': ['4/10', '4/10', '6/10'], 'data': ...
# 355        Escondido  [{'rating': ['4/10', '4/10', '6/10'], 'data': ...
# 425     Jacksonville  [{'rating': ['5/10', '2/10', '4/10'], 'data': ...
# 447         Sarasota  [{'rating': ['10/10', '9/10', '6/10'], 'data':...
# ...              ...                                                ...
# 376298       Fontana  [{'rating': ['4/10', '3/10', '4/10'], 'data': ...
# 376340       Atlanta  [{'rating': ['9/10', '6/10', '6/10'], 'data': ...
# 376582   Spring Hill  [{'rating': ['4/10', '6/10'], 'data': {'Distan...
# 376686       Ontario  [{'rating': ['7/10', '6/10', '5/10'], 'data': ...
# 376694      Gulfport  [{'rating': ['2/10', '2/10', '4/10'], 'data': ...
#
#           sqft zipcode  beds state stories      mls-id PrivatePool MlsId  \
# 205     2361.0   32308     3    FL     NaN      302221         NaN   NaN
# 321     2135.0   92503     3    CA     2.0  IV19242188         NaN   NaN
# 355     1536.0   92026     2    CA     0.0   190034991         NaN   NaN
# 425     1245.0   32221     3    FL     1.0         NaN         NaN   NaN
# 447     1936.0   34233     3    FL     1.0    O5821850         NaN   NaN
# ...        ...     ...   ...   ...     ...         ...         ...   ...
# 376298  2225.0   92337     5    CA     2.0         NaN         NaN   NaN
# 376340  1299.0   30339     2    GA     1.0     8690633         NaN   NaN
# 376582  2256.0   34609     4    FL     1.0     2204520         NaN   NaN
# 376686  1726.0   91761     3    CA     2.0  IV19252050         NaN   NaN
# 376694  2210.0   33707     2    FL     9.0    U8064383         NaN   NaN
#
#           target
# 205     385000.0
# 321     525000.0
# 355     119000.0
# 425     128103.0
# 447     258000.0
# ...          ...
# 376298  399094.0
# 376340  295000.0
# 376582  225000.0
# 376686  479000.0
# 376694  435000.0
#
# [2729 rows x 18 columns]

# %% [markdown]
# Вывод: число домов с бассейнами незначительно (4181 из 377185), разброс цен для домов с бассейнами большой, явного влияния на цену нет. Можно не рассматривать.

# %% [markdown]
#  # propertyType

# %%
data_d['propertyType'].value_counts(normalize=True)
# Out:
# single-family home                                             0.275224
# Single Family                                                  0.183194
# Single Family Home                                             0.097924
# lot/land                                                       0.068953
# condo                                                          0.065922
#                                                                  ...
# 1 Story, Contemporary, Other (See Remarks)                     0.000004
# Traditional, Colonial                                          0.000004
# Condo/Townhome, Single Detached                                0.000004
# 1 Story, Spanish, Ranch, Traditional                           0.000004
# Bilevel, Converted Dwelling, Loft with Bedrooms, Condo/Unit    0.000004
# Name: propertyType, Length: 885, dtype: float64

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: str(x))

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: 'sfh' if x in ['single-family home','Single Family','Single Family Home'] else x)

# %%
data_d['propertyType'].value_counts(normalize=True)
# Out:
# sfh                                                            0.508385
# nan                                                            0.086200
# lot/land                                                       0.063010
# condo                                                          0.060240
# Condo                                                          0.041209
#                                                                  ...
# Penthouse, Low Rise                                            0.000004
# Traditional, Loft with Bedrooms                                0.000004
# Condo/Townhome, French, Split Level                            0.000004
# Traditional, Colonial, Federal                                 0.000004
# Bilevel, Converted Dwelling, Loft with Bedrooms, Condo/Unit    0.000004
# Name: propertyType, Length: 884, dtype: float64

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: x.lower())

# %%
data_d.propertyType = data_d.propertyType.apply(lambda x: 'mlf' if (x.find('multi')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'ctmp' if (x.find('contempor')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'loft' if (x.find('loft')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'twnh' if (x.find('townhouse')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'condo' if (x.find('condo')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'sn_dtch' if (x.find('single detached')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'eng' if (x.find('english')>-1) else x)
data_d.propertyType = data_d.propertyType.apply(lambda x: 'other' if x not in ['mlf','ctmp','loft','twnh','condo','sn_dtch','eng'] else x)

# %%
data_d['propertyType'].value_counts()
# Out:
# other      215075
# condo       34314
# twnh        14316
# mlf          5906
# ctmp         2837
# sn_dtch      2261
# loft           32
# eng            27
# Name: propertyType, dtype: int64

# %% [markdown]
# Преобразование к численному виду.

# %%
data_d['propertyType'] = data_d['propertyType'].astype('category')
data_d['propertyType_cat'] = data_d['propertyType'].cat.codes

# %%
data_d['propertyType_cat'].value_counts()
# Out:
# 5    215075
# 0     34314
# 7     14316
# 4      5906
# 1      2837
# 6      2261
# 3        32
# 2        27
# Name: propertyType_cat, dtype: int64

# %%
data_d['propertyType'].isna().unique()
# Out:
# array([False])

# %%
x = data_d['propertyType_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Тим собственности', fontsize = 15)
plt.title('Зависимость цены от типа собственности', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от типа собственности')

# %% [markdown]
# # Город

# %%
data_d.city.fillna('others',inplace=True)

# %%
data_d['city'].isna().sum()
# Out:
# 0

# %%
t = data_d['city'].value_counts()

# %%
t
# Out:
# Houston         19033
# San Antonio     14423
# Miami           10085
# Jacksonville     9191
# Dallas           5858
#                 ...
# EVERGREEN           1
# Downs               1
# Stanwood            1
# SUNRISE             1
# Blue Springs        1
# Name: city, Length: 1806, dtype: int64

# %%
t_df = pd.DataFrame(t)

# %%
t_df.loc[t_df['city']==np.NaN]
# Out:
# Empty DataFrame
# Columns: [city]
# Index: []

# %%
t_df['city'].isna().sum()
# Out:
# 0

# %%
dict_t = t_df.to_dict()

# %%
dict_city = dict_t.get('city')

# %%
data_d['city'].isna().sum()
# Out:
# 0

# %% [markdown]
# Вспомогательная функция присваивает значение others, если число вхождений данного города невелико. (Здесь меньше 500.)

# %%
def other_cities(x1,d):
    if x1==np.NaN:
        return ('others')
    elif d.get(x1)==np.NaN:
        return('others')
    elif d.get(x1)<500: return ('others')
    else: return(x1)

# %%
data_d.city = data_d.city.apply(lambda x: other_cities(x,dict_city))

# %%
data_d.head(30)
# Out:
#               status private pool propertyType                      street  \
# 0             Active          NaN        other              240 Heather Ln
# 1           for sale          NaN        other           12911 E Heroy Ave
# 4           for sale          NaN        other              1524 Kiscoe St
# 5           for sale          NaN         twnh           1624 S Newkirk St
# 6             Active          NaN        other            552 Casanova Ct
# 7             Active          NaN        other             6094 Mingle Dr
# 8             Active          NaN        other               11182 Owl Ave
# 9                NaN          NaN        other        8612 Cedar Plains Ln
# 11            Active          NaN          eng      4222 False Cypress Ln
# 12          for sale          NaN        other            16373 NW 16th St
# 13  New construction          NaN        other              1538 Umpqua Dr
# 14               NaN          NaN        other          15351 Falmouth Ave
# 16            Active          NaN        other            2402 NW 22nd Rd
# 18          for sale          NaN        other          22702 Alderdale Ln
# 20          For sale          NaN        other            5930 E Avenue T2
# 23          for sale          NaN        other        4234 Orchard Pass Dr
# 24          for sale          NaN        other             703 W Gemini Ln
# 27          for sale          NaN        other        2104 Lou Ellen Ln #B
# 31          For sale          NaN        other             6712 N Glen Ave
# 32          for sale          NaN        other         2043 SE New York St
# 33               NaN          NaN        condo    3750 NE 170th St APT 407
# 34          for sale          NaN        other           7314 Melvin Cir N
# 35          for sale          NaN        condo       423 N Church St #13-A
# 36          For sale          NaN        other           2627 N Arthur Ave
# 37          For sale          NaN        other             3360 SW 29th St
# 38          For sale          NaN        other      5531 Eureka Springs Rd
# 39          for sale          NaN        condo      316 N Henderson Ave #4
# 40            Active          NaN        other           1104 Rotonda Cir
# 44          for sale          NaN        condo  4504 W Lake Mead Blvd #201
# 45           Pending          NaN        other            11539 Kismet Ave
#
#     baths                                          homeFacts  fireplace  \
# 0     3.5  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 1     3.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 4     1.0  {'atAGlanceFacts': [{'factValue': '', 'factLab...          0
# 5     1.0  {'atAGlanceFacts': [{'factValue': '1920', 'fac...          0
# 6     1.0  {'atAGlanceFacts': [{'factValue': '2006', 'fac...          0
# 7     1.0  {'atAGlanceFacts': [{'factValue': '1976', 'fac...          0
# 8     2.0  {'atAGlanceFacts': [{'factValue': '1970', 'fac...          0
# 9     3.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 11    1.0  {'atAGlanceFacts': [{'factValue': '2015', 'fac...          0
# 12    3.0  {'atAGlanceFacts': [{'factValue': '1996', 'fac...          0
# 13    2.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 14    3.0  {'atAGlanceFacts': [{'factValue': '1982', 'fac...          0
# 16    1.0  {'atAGlanceFacts': [{'factValue': '2008', 'fac...          0
# 18    4.0  {'atAGlanceFacts': [{'factValue': '2016', 'fac...          1
# 20    2.0  {'atAGlanceFacts': [{'factValue': '1989', 'fac...          0
# 23    4.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          1
# 24    2.0  {'atAGlanceFacts': [{'factValue': '2014', 'fac...          1
# 27    3.0  {'atAGlanceFacts': [{'factValue': '', 'factLab...          0
# 31    2.0  {'atAGlanceFacts': [{'factValue': '1960', 'fac...          0
# 32    2.0  {'atAGlanceFacts': [{'factValue': '1977', 'fac...          0
# 33    2.0  {'atAGlanceFacts': [{'factValue': '1972', 'fac...          0
# 34    2.0  {'atAGlanceFacts': [{'factValue': '1963', 'fac...          0
# 35    1.0  {'atAGlanceFacts': [{'factValue': '1981', 'fac...          0
# 36    3.0  {'atAGlanceFacts': [{'factValue': '1949', 'fac...          1
# 37    2.0  {'atAGlanceFacts': [{'factValue': '1954', 'fac...          0
# 38    1.0  {'atAGlanceFacts': [{'factValue': '1930', 'fac...          0
# 39    3.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 40    1.0  {'atAGlanceFacts': [{'factValue': '', 'factLab...          0
# 44    2.0  {'atAGlanceFacts': [{'factValue': '1994', 'fac...          1
# 45    2.0  {'atAGlanceFacts': [{'factValue': '1958', 'fac...          0
#
#                city                                            schools  \
# 0            others  [{'rating': ['4', '4', '7', 'NR', '4', '7', 'N...
# 1            others  [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# 4          Palm Bay  [{'rating': ['4/10', '5/10', '5/10'], 'data': ...
# 5      Philadelphia  [{'rating': [], 'data': {'Distance': [], 'Grad...
# 6            others  [{'rating': ['3', '3', '1', 'NR'], 'data': {'D...
# 7           Memphis  [{'rating': ['4', '2', '2'], 'data': {'Distanc...
# 8            others  [{'rating': ['2', '2', '4', '7', '4', 'NR'], '...
# 9           Houston  [{'rating': ['4/10', '3/10', '2/10'], 'data': ...
# 11          Houston  [{'rating': ['6', '3', '6', '1', '5'], 'data':...
# 12   Pembroke Pines  [{'rating': ['8/10', '7/10', '7/10'], 'data': ...
# 13           others  [{'rating': ['7/10', '7/10', '8/10'], 'data': ...
# 14          Houston  [{'rating': ['4/10', '5/10', '7/10'], 'data': ...
# 16  Fort Lauderdale  [{'rating': ['4', 'NR', '3', 'NR'], 'data': {'...
# 18           others  [{'rating': ['7/10', '7/10'], 'data': {'Distan...
# 20           others  [{'rating': ['3/10', '5/10'], 'data': {'Distan...
# 23           Spring  [{'rating': ['9/10', '8/10', '8/10'], 'data': ...
# 24           others  [{'rating': ['3/10', '6/10', '6/10'], 'data': ...
# 27          Houston  [{'rating': ['6/10', '9/10', '3/10'], 'data': ...
# 31            Tampa  [{'rating': ['5/10', '2/10', '4/10'], 'data': ...
# 32           others  [{'rating': ['7/10', '5/10', '5/10', '4/10', '...
# 33           others  [{'rating': ['10/10', '6/10'], 'data': {'Dista...
# 34     Jacksonville  [{'rating': ['2/10', '2/10', '4/10'], 'data': ...
# 35        Charlotte  [{'rating': ['7/10', '4/10', '8/10'], 'data': ...
# 36           Fresno  [{'rating': ['3/10', '4/10'], 'data': {'Distan...
# 37            Miami  [{'rating': ['10/10', '5/10'], 'data': {'Dista...
# 38            Tampa  [{'rating': ['1/10', '2/10', '3/10'], 'data': ...
# 39           Dallas  [{'rating': ['5/10', '6/10', '5/10'], 'data': ...
# 40           others  [{'rating': ['6', '6', '7'], 'data': {'Distanc...
# 44        Las Vegas  [{'rating': ['1/10', 'None/10', '2/10'], 'data...
# 45           others  [{'rating': ['4', '2', '1', 'NR', '6', '7', 'N...
#
#            sqft zipcode  beds state    stories      mls-id PrivatePool  \
# 0   2900.000000   28387     1    NC        NaN         NaN         NaN
# 1   1947.000000   99216     3    WA        2.0         NaN         NaN
# 4   6594.616652   32908     1    FL        NaN         NaN         NaN
# 5    897.000000   19145     2    PA        2.0         NaN         NaN
# 6   1507.000000   34759     1    FL        One         NaN         NaN
# 7   6594.616652   38115     1    TN        NaN         NaN         NaN
# 8   3588.000000   50401     1    IA        NaN         NaN         NaN
# 9   1930.000000   77080     1    TX        2.0         NaN         NaN
# 11  3130.000000   77068     1    TX          2         NaN         NaN
# 12  2839.000000   33028     4    FL        1.0         NaN         yes
# 13  1820.000000   97401     3    OR        1.0    19221142         NaN
# 14  2454.000000   77084     1    TX        2.0         NaN         NaN
# 16  2203.000000   33311     1    FL        NaN         NaN         NaN
# 18  3080.000000   77375     4    TX        2.0         NaN         NaN
# 20  1731.000000   93552     4    CA        NaN  SR19195113         NaN
# 23  3645.000000   77386     4    TX        2.0         NaN         NaN
# 24  1953.000000   76542     4    TX        1.0         NaN         NaN
# 27  2575.000000   77018     3    TX        NaN         NaN         NaN
# 31  1677.000000   33614     4    FL        0.0    T3159863         NaN
# 32  1176.000000   34952     3    FL        NaN         NaN         NaN
# 33  1085.000000   33160     1    FL        0.0         NaN         NaN
# 34   864.000000   32210     3    FL        NaN         NaN         NaN
# 35   900.000000   28202     2    NC        NaN         NaN         NaN
# 36  1448.000000   93705     1    CA          0         NaN         NaN
# 37  1396.000000   33133     1    FL        0.0         NaN         NaN
# 38  1232.000000   33610     2    FL        0.0    T3204536         NaN
# 39  1720.000000   75214     2    TX        2.0         NaN         NaN
# 40  6594.616652   33947     1    FL        NaN         NaN         NaN
# 44  1081.000000   89108     2    NV        2.0         NaN         NaN
# 45  1101.000000   91342     1    CA  One Level         NaN         NaN
#
#          MlsId    target  propertyType_cat
# 0       611019  418000.0                 5
# 1    201916904  310000.0                 5
# 4       861745    5000.0                 5
# 5   PAPH847006  209000.0                 7
# 6     S5026943  181500.0                 5
# 7     10063506   68000.0                 5
# 8       190988  244900.0                 5
# 9     73968331  311995.0                 5
# 11     5741322  260000.0                 2
# 12   A10767242  525000.0                 5
# 13         NaN  499900.0                 5
# 14    65299510  168800.0                 5
# 16   F10207914  335000.0                 5
# 18    95301365  365000.0                 5
# 20         NaN  375000.0                 5
# 23    13624110  499007.0                 5
# 24     6208631  182000.0                 5
# 27    33856933  499900.0                 5
# 31         NaN  262000.0                 5
# 32   F10174710  204800.0                 5
# 33   A10775650  179000.0                 0
# 34     1027438  105000.0                 5
# 35     3554602  260000.0                 0
# 36      533746  284900.0                 5
# 37   A10743020  495000.0                 5
# 38         NaN  117900.0                 5
# 39    14150656  385000.0                 0
# 40    D6107075   54000.0                 5
# 44     2160520  125000.0                 0
# 45  SR19267193  499000.0                 5

# %%
data_d.loc[data_d['city']=='others']
# Out:
#                   status private pool propertyType                   street  \
# 0                 Active          NaN        other           240 Heather Ln
# 1               for sale          NaN        other        12911 E Heroy Ave
# 6                 Active          NaN        other         552 Casanova Ct
# 8                 Active          NaN        other            11182 Owl Ave
# 13      New construction          NaN        other           1538 Umpqua Dr
# ...                  ...          ...          ...                      ...
# 377140          for sale          NaN        other        6383 Cathedral Dr
# 377147            Active          NaN        other  1022 Lyndon Station Dr
# 377161            Active          NaN        other       Homestead Dr Lot 1
# 377173          for sale          NaN        other      19743 N Sagamore Rd
# 377182          for sale          NaN        other        15509 Linden Blvd
#
#         baths                                          homeFacts  fireplace  \
# 0         3.5  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 1         3.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# 6         1.0  {'atAGlanceFacts': [{'factValue': '2006', 'fac...          0
# 8         2.0  {'atAGlanceFacts': [{'factValue': '1970', 'fac...          0
# 13        2.0  {'atAGlanceFacts': [{'factValue': '2019', 'fac...          0
# ...       ...                                                ...        ...
# 377140    1.0  {'atAGlanceFacts': [{'factValue': '', 'factLab...          0
# 377147    1.0  {'atAGlanceFacts': [{'factValue': '2020', 'fac...          0
# 377161    1.0  {'atAGlanceFacts': [{'factValue': '', 'factLab...          0
# 377173    3.0  {'atAGlanceFacts': [{'factValue': '1950', 'fac...          1
# 377182    3.0  {'atAGlanceFacts': [{'factValue': '1950', 'fac...          0
#
#           city                                            schools  \
# 0       others  [{'rating': ['4', '4', '7', 'NR', '4', '7', 'N...
# 1       others  [{'rating': ['4/10', 'None/10', '4/10'], 'data...
# 6       others  [{'rating': ['3', '3', '1', 'NR'], 'data': {'D...
# 8       others  [{'rating': ['2', '2', '4', '7', '4', 'NR'], '...
# 13      others  [{'rating': ['7/10', '7/10', '8/10'], 'data': ...
# ...        ...                                                ...
# 377140  others  [{'rating': ['5/10', '5/10', '7/10'], 'data': ...
# 377147  others  [{'rating': ['8', '4', '7'], 'data': {'Distanc...
# 377161  others  [{'rating': ['8', '9', '8', 'NR'], 'data': {'D...
# 377173  others  [{'rating': ['6/10', '5/10', '6/10'], 'data': ...
# 377182  others  [{'rating': ['5/10', '4/10'], 'data': {'Distan...
#
#                sqft zipcode  beds state stories    mls-id PrivatePool  \
# 0       2900.000000   28387     1    NC     NaN       NaN         NaN
# 1       1947.000000   99216     3    WA     2.0       NaN         NaN
# 6       1507.000000   34759     1    FL     One       NaN         NaN
# 8       3588.000000   50401     1    IA     NaN       NaN         NaN
# 13      1820.000000   97401     3    OR     1.0  19221142         NaN
# ...             ...     ...   ...   ...     ...       ...         ...
# 377140  6594.616652   28601     1    NC     NaN       NaN         NaN
# 377147  2058.000000   28134     1    NC     NaN       NaN         NaN
# 377161  6594.616652   44408     1    OH     NaN       NaN         NaN
# 377173  2505.000000   44126     5    OH     2.0       NaN         NaN
# 377182  1152.000000   11434     3    NY       2       NaN         NaN
#
#             MlsId    target  propertyType_cat
# 0          611019  418000.0                 5
# 1       201916904  310000.0                 5
# 6        S5026943  181500.0                 5
# 8          190988  244900.0                 5
# 13            NaN  499900.0                 5
# ...           ...       ...               ...
# 377140    3525591   41000.0                 5
# 377147    3576461  342969.0                 5
# 377161    3382834   45000.0                 5
# 377173    4126112  384900.0                 5
# 377182        NaN  528000.0                 5
#
# [72560 rows x 19 columns]

# %%
data_d['city'] = data_d['city'].astype('category')
data_d['city_cat'] = data_d['city'].cat.codes

# %%
data_d['city_cat'].value_counts()
# Out:
# 103    72560
# 33     19033
# 85     14423
# 52     10085
# 36      9191
#        ...
# 91       512
# 34       510
# 7        506
# 49       501
# 68       500
# Name: city_cat, Length: 104, dtype: int64

# %%
sns.distplot(data_d['city_cat'])
# Out:
# <AxesSubplot:xlabel='city_cat', ylabel='Density'>

# %%
data_d['city_cat'].isna().unique()
# Out:
# array([False])

# %%
x = data_d['city_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Город', fontsize = 15)
plt.title('Зависимость цены от города', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от города')

# %% [markdown]
# # Штат

# %%
data_d['state'].value_counts()
# Out:
# FL    90167
# TX    68279
# NC    17910
# TN    15129
# OH    11603
# CA     8705
# WA     7823
# NY     7064
# IL     6970
# NV     6554
# GA     5084
# MI     4945
# PA     4734
# CO     4335
# AZ     3084
# IN     3058
# DC     1879
# OR     1739
# UT      903
# MO      807
# VT      770
# MD      763
# MA      552
# VA      508
# WI      388
# NJ      318
# ME      251
# IA      232
# KY       85
# OK       49
# MS       38
# SC       26
# MT        7
# DE        4
# Fl        1
# BA        1
# AL        1
# OT        1
# OS        1
# Name: state, dtype: int64

# %%
data_d['state'] = data_d['state'].astype('category')
data_d['state_cat'] = data_d['state'].cat.codes

# %%
data_d['state_cat'].value_counts()
# Out:
# 7     90167
# 33    68279
# 21    17910
# 32    15129
# 25    11603
# 3      8705
# 37     7823
# 24     7064
# 11     6970
# 23     6554
# 9      5084
# 17     4945
# 30     4734
# 4      4335
# 1      3084
# 12     3058
# 5      1879
# 27     1739
# 34      903
# 18      807
# 36      770
# 15      763
# 14      552
# 35      508
# 38      388
# 22      318
# 16      251
# 10      232
# 13       85
# 26       49
# 19       38
# 31       26
# 20        7
# 6         4
# 8         1
# 2         1
# 0         1
# 29        1
# 28        1
# Name: state_cat, dtype: int64

# %%
data_d['state_cat'].isna().unique()
# Out:
# array([False])

# %%
x = data_d['state_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Штат', fontsize = 15)
plt.title('Зависимость цены от штата', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от штата')

# %% [markdown]
# # Улица

# %%
data_d['street'].nunique()
# Out:
# 246360

# %% [markdown]
# Уникальных значений улиц слишком много. Признак удалила.

# %% [markdown]
#  # Stories (надеюсь, это этажи)

# %%
data_d['stories'].value_counts()
# Out:
# 1.0                         56657
# 2.0                         38931
# 1                           19805
# 2                           12436
# 3.0                          6145
#                             ...
# A Frame                         1
# One, Two                        1
# 42                              1
# 1-2 Stories, 3-4 Stories        1
# Patio Home                      1
# Name: stories, Length: 270, dtype: int64

# %%
data_d.stories = data_d.stories.apply(lambda x: main_extract_num(str(x)))

# %%
data_d['stories'].value_counts()
# Out:
# 1.00       194934
# 2.00        55903
# 3.00         9314
# 0.00         7763
# 9.00         2043
# 4.00         1617
# 1.50         1144
# 6.00          520
# 5.00          460
# 8.00          218
# 7.00          190
# 2.50          142
# 16.00          48
# 12.00          36
# 15.00          36
# 11.00          33
# 10.00          29
# 17.00          28
# 13.00          25
# 1.75           25
# 20.00          24
# 14.00          22
# 25.00          21
# 21.00          20
# 1.70           17
# 18.00          16
# 27.00          14
# 22.00          13
# 24.00          12
# 23.00          12
# 26.00           9
# 19.00           8
# 43.00           8
# 29.00           8
# 28.00           5
# 42.00           4
# 33.00           4
# 32.00           4
# 36.00           4
# 31.00           3
# 30.00           3
# 49.00           3
# 47.00           3
# 46.00           2
# 35.00           2
# 57.00           2
# 56.00           2
# 1.30            2
# 48.00           2
# 45.00           1
# 1.20            1
# 60.00           1
# 55.00           1
# 40.00           1
# 1120.00         1
# 41.00           1
# 2.20            1
# 3.50            1
# 1002.00         1
# 63.00           1
# Name: stories, dtype: int64

# %%
data_d['stories'].isna().unique()
# Out:
# array([False])

# %%
sns.distplot(data_d['stories'])
# Out:
# <AxesSubplot:xlabel='stories', ylabel='Density'>

# %%
data_d.loc[data_d['stories']>17].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216 entries, 612 to 375325
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status            168 non-null    object
#  1   private pool      2 non-null      object
#  2   propertyType      216 non-null    category
#  3   street            216 non-null    object
#  4   baths             216 non-null    float64
#  5   homeFacts         216 non-null    object
#  6   fireplace         216 non-null    int64
#  7   city              216 non-null    category
#  8   schools           216 non-null    object
#  9   sqft              216 non-null    float64
#  10  zipcode           216 non-null    object
#  11  beds              216 non-null    int64
#  12  state             216 non-null    category
#  13  stories           216 non-null    float64
#  14  mls-id            4 non-null      object
#  15  PrivatePool       90 non-null     object
#  16  MlsId             165 non-null    object
#  17  target            216 non-null    float64
#  18  propertyType_cat  216 non-null    int8
#  19  city_cat          216 non-null    int8
#  20  state_cat         216 non-null    int8
# dtypes: category(3), float64(4), int64(2), int8(3), object(9)
# memory usage: 34.9+ KB

# %%
data_d = data_d[data_d['stories']<17]

# %%
x = data_d['stories']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Этаж', fontsize = 15)
plt.title('Зависимость цены от этажа', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от этажа')

# %% [markdown]
#  # Status

# %%
data_d['status'].value_counts()
# Out:
# for sale                111749
# Active                   76480
# For sale                 30151
# foreclosure               5866
# Pending                   4058
#                          ...
# Pending Sale                 1
# Coming soon: Nov 30.         1
# Coming soon: Dec 16.         1
# Coming soon: Dec 18.         1
# Accepting backups            1
# Name: status, Length: 152, dtype: int64

# %%
data_d.status = data_d.status.apply(lambda x: 'for_sale' if x in ['for sale','For sale'] else x)

# %%
data_d.status = data_d.status.apply(lambda x: str(x))

# %%
data_d.status = data_d.status.apply(lambda x: x.lower())

# %%
data_d.status = data_d.status.apply(lambda x: 'actv' if (x.find('activ')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cnstr' if (x.find('construction')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cntrct' if (x.find('contract')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'frcls' if (x.find('foreclosure')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'pnd' if (x.find('pending')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cntgs' if (x.find('contingen')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'cmg_s' if (x.find('coming soon')>-1) else x)
data_d.status = data_d.status.apply(lambda x: 'frcls' if (x.find('foreclosure')>-1) else x)

# %%
data_d['status'].unique()
# Out:
# array(['actv', 'for_sale', 'nan', 'cnstr', 'pnd', 'frcls', ' / auction',
#        'cntrct', 'p', 'foreclosed', 'for rent', 'auction', 'cntgs',
#        'price change', 'back on market', 'new', 'recently sold', 'cmg_s',
#        'pf', 'apartment for rent', 'pi', 'due diligence period',
#        'c continue show', 'closed', 'for sale', 'c', 'condo for rent',
#        'ct', 'accepted offer', 'listing extended',
#        'conting accpt backups', 'lease/purchase', 'sold: $285,000',
#        'sold: $15,000', 'ps', 'uc continue to show', 'backup',
#        'accepting backups'], dtype=object)

# %%
data_d['status'].value_counts()
# Out:
# for_sale                 141900
# actv                      77306
# nan                       30053
# frcls                      9457
# pnd                        4626
# cnstr                      3399
# cntrct                     2593
# cntgs                       935
# p                           781
#  / auction                  691
# auction                     486
# new                         452
# foreclosed                  436
# price change                406
# for rent                    389
# recently sold               287
# back on market              101
# cmg_s                        78
# pi                           29
# due diligence period         26
# c                            18
# c continue show              18
# closed                       17
# listing extended              8
# condo for rent                6
# apartment for rent            5
# accepted offer                4
# ct                            3
# pf                            3
# ps                            2
# uc continue to show           2
# for sale                      1
# conting accpt backups         1
# lease/purchase                1
# sold: $285,000                1
# sold: $15,000                 1
# backup                        1
# accepting backups             1
# Name: status, dtype: int64

# %% [markdown]
# Приведение к численному виду.

# %%
data_d['status'] = data_d['status'].astype('category')
data_d['status_cat'] = data_d['status'].cat.codes

# %%
data_d['status'].isna().unique()
# Out:
# array([False])

# %%
x = data_d['status_cat']
y = data_d['target']

# %%
plt.figure(figsize = (10,6))
plt.scatter(x, y)


# добавим подписи
plt.xlabel('Площадь', fontsize = 15)
plt.ylabel('Статус продажи', fontsize = 15)
plt.title('Зависимость цены от статуса продажи', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Зависимость цены от статуса продажи')

# %% [markdown]
# # Индекс

# %%
data_d['zipcode'].value_counts()
# Out:
# 32137         1816
# 78245         1387
# 34759         1321
# 78253         1267
# 78254         1236
#               ...
# 78112            1
# 84044            1
# 27610-2861       1
# 27613-4042       1
# 64015            1
# Name: zipcode, Length: 4295, dtype: int64

# %%
data_d.zipcode = data_d.zipcode.apply(lambda x: 0 if (x.find('-')>-1) else x)

# %%
data_d.zipcode = data_d.zipcode.apply(lambda x: float(x))

# %%
data_d['zipcode'].value_counts()
# Out:
# 32137.0    1816
# 78245.0    1387
# 34759.0    1321
# 78253.0    1267
# 78254.0    1236
#            ...
# 92603.0       1
# 94086.0       1
# 41839.0       1
# 92008.0       1
# 64015.0       1
# Name: zipcode, Length: 4064, dtype: int64

# %%
data_d['zipcode'].isna().unique()
# Out:
# array([False])

# %%
data_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274524 entries, 0 to 377184
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   status            274524 non-null  category
#  1   private pool      2726 non-null    object
#  2   propertyType      274524 non-null  category
#  3   street            274523 non-null  object
#  4   baths             274524 non-null  float64
#  5   homeFacts         274524 non-null  object
#  6   fireplace         274524 non-null  int64
#  7   city              274524 non-null  category
#  8   schools           274524 non-null  object
#  9   sqft              274524 non-null  float64
#  10  zipcode           274524 non-null  float64
#  11  beds              274524 non-null  int64
#  12  state             274524 non-null  category
#  13  stories           274524 non-null  float64
#  14  mls-id            19020 non-null   object
#  15  PrivatePool       22527 non-null   object
#  16  MlsId             222772 non-null  object
#  17  target            274524 non-null  float64
#  18  propertyType_cat  274524 non-null  int8
#  19  city_cat          274524 non-null  int8
#  20  state_cat         274524 non-null  int8
#  21  status_cat        274524 non-null  int8
# dtypes: category(4), float64(5), int64(2), int8(4), object(7)
# memory usage: 33.5+ MB

# %% [markdown]
# # Обработка признака homeFacts.

# %% [markdown]
# Вспомогательная функция для извлечения списка значимых величин из признака. (Извлекает список словарей из исходной структуры, которая тоже является словарем. Затем по ключевым словам словаря формирует список значимых величин. Возвращает нан, если в списке отсутствует ключевое слово основного словаря.)

# %%
def facts_extraction(slovar):
    if slovar.find('atAGlanceFacts')>-1:
        slovar1 = eval(slovar)
       # print(type(slovar1))
        #print(slovar1)
        slovar2=slovar1.get('atAGlanceFacts')
       # print(type(slovar2))
       # print(slovar2)
        
        lst = ['']
        for i in slovar2:
            
            lst.append(i.get('factValue'))
        lst_res=lst[1:]
        return lst_res
            
    else: return np.NaN

# %%
data_d.homeFacts = data_d.homeFacts.apply(lambda x: facts_extraction(x))

# %%
t = data_d['homeFacts']
t
# Out:
# 0          [2019, , Central A/C, Heat Pump, , , None, $144]
# 1                      [2019, , , , , 5828 sqft, $159/sqft]
# 4                             [, , , , , 10,019 sqft, None]
# 5         [1920, , Forced Air, Central, , 680 sqft, $233...
# 6         [2006, 2006, Electric, Heat Pump, Central Air,...
#                                 ...
# 377177    [1921, , , Central A/C (Electric), Central Hea...
# 377178    [2019, None, No Data, No Data, 2 spaces, No Da...
# 377182      [1950, 1950, Other, , 2, 1,600 sqft, $458/sqft]
# 377183           [None, None, None, None, None, None, None]
# 377184    [2019, None, Electric, Central, No Data, 6,969...
# Name: homeFacts, Length: 274524, dtype: object

# %%
t_lst = t.tolist()

# %%
columns = ['Year built','Remodeled year','Heating','Cooling','Parking','lotsize','price_sqft']

# %%
t1 = pd.DataFrame(t_lst, columns = columns)

# %%
data_d = data_d.join(t1)

# %%
data_d.head(3)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
#
#                                           homeFacts  fireplace      city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0    others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0    others
# 4                     [, , , , , 10,019 sqft, None]          0  Palm Bay
#
#                                              schools         sqft  zipcode  \
# 0  [{'rating': ['4', '4', '7', 'NR', '4', '7', 'N...  2900.000000  28387.0
# 1  [{'rating': ['4/10', 'None/10', '4/10'], 'data...  1947.000000  99216.0
# 4  [{'rating': ['4/10', '5/10', '5/10'], 'data': ...  6594.616652  32908.0
#
#    beds state  stories mls-id PrivatePool      MlsId    target  \
# 0     1    NC      1.0    NaN         NaN     611019  418000.0
# 1     3    WA      2.0    NaN         NaN  201916904  310000.0
# 4     1    FL      1.0    NaN         NaN     861745    5000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
#
#        price_sqft
# 0            $144
# 1       $159/sqft
# 4  $120 / Sq. Ft.

# %% [markdown]
# # Обработка признака школы

# %%
data_d.schools = data_d.schools.apply(lambda x: eval(x[1:-1]))

# %%
t = data_d['schools']
t
# Out:
# 0         {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...
# 1         {'rating': ['4/10', 'None/10', '4/10'], 'data'...
# 4         {'rating': ['4/10', '5/10', '5/10'], 'data': {...
# 5         {'rating': [], 'data': {'Distance': [], 'Grade...
# 6         {'rating': ['3', '3', '1', 'NR'], 'data': {'Di...
#                                 ...
# 377177    {'rating': ['4', '6', '5'], 'data': {'Distance...
# 377178    {'rating': ['7/10', '6/10', '5/10'], 'data': {...
# 377182    {'rating': ['5/10', '4/10'], 'data': {'Distanc...
# 377183    {'rating': ['NA', 'NA', 'NA'], 'data': {'Dista...
# 377184    {'rating': ['5/10', '4/10', '3/10'], 'data': {...
# Name: schools, Length: 274524, dtype: object

# %%
t_lst = t.tolist()

# %%
t5_lst = []
for i in t_lst:
    i1 = dict([('rating', i.get('rating')), ('Distance', (i.get('data')).get('Distance')), ('Grades', (i.get('data')).get('Grades')),('name',i.get('name'))])
    t5_lst.append(i1)

# %%
df_lst = pd.DataFrame(t5_lst,dtype=str)

# %%
df_lst.head(10)
# Out:
#                                         rating  \
# 0  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1                  ['4/10', 'None/10', '4/10']
# 2                     ['4/10', '5/10', '5/10']
# 3                                           []
# 4                        ['3', '3', '1', 'NR']
# 5                              ['4', '2', '2']
# 6              ['2', '2', '4', '7', '4', 'NR']
# 7                     ['4/10', '3/10', '2/10']
# 8                    ['6', '3', '6', '1', '5']
# 9                     ['8/10', '7/10', '7/10']
#
#                                             Distance  \
# 0  ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                     ['1.65mi', '1.32mi', '1.01mi']
# 2                     ['5.96mi', '3.25mi', '3.03mi']
# 3                                                 []
# 4           ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
# 5                     ['0.7 mi', '0.4 mi', '2.2 mi']
# 6  ['5.6 mi', '5.6 mi', '6.8 mi', '6.5 mi', '6.8 ...
# 7                     ['0.7 mi', '0.6 mi', '1.9 mi']
# 8  ['0.4 mi', '0.4 mi', '3.0 mi', '3.2 mi', '7.4 ...
# 9                     ['2.66mi', '0.92mi', '2.54mi']
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 2                            ['7-8', '9-12', 'PK-6']
# 3                                                 []
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
# 6     ['PK–4', '5–6', '9–12', 'PK–4', '7–8', '9–12']
# 7                            ['PK-5', '5-8', '9-12']
# 8  ['Preschool to 5', '6 to 8', '6 to 8', '9 to 1...
# 9                            ['6-8', 'PK-5', '9-12']
#
#                                                 name
# 0  ['Southern Pines Elementary School', 'Southern...
# 1  ['East Valley High School&Extension', 'Eastval...
# 2  ['Southwest Middle School', 'Bayside High Scho...
# 3                                                 []
# 4  ['Palmetto Elementary School', 'Haines City Se...
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...
# 6  ['Roosevelt Elementary School', 'Lincoln Inter...
# 7  ['Edgewood Elementary School', 'Landrum Middle...
# 8  ['Pat Reynolds Elementary School', 'Edwin M We...
# 9  ['Walter C. Young Middle School', 'Silver Palm...

# %%
data_d = data_d.join(df_lst)

# %%
data_d.head(3)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
#
#                                           homeFacts  fireplace      city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0    others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0    others
# 4                     [, , , , , 10,019 sqft, None]          0  Palm Bay
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
#
#    beds state  stories mls-id PrivatePool      MlsId    target  \
# 0     1    NC      1.0    NaN         NaN     611019  418000.0
# 1     3    WA      2.0    NaN         NaN  201916904  310000.0
# 4     1    FL      1.0    NaN         NaN     861745    5000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
#
#        price_sqft                                       rating  \
# 0            $144  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1       $159/sqft                  ['4/10', 'None/10', '4/10']
# 4  $120 / Sq. Ft.                        ['3', '3', '1', 'NR']
#
#                                             Distance  \
# 0  ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                     ['1.65mi', '1.32mi', '1.01mi']
# 4           ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
#
#                                                 name
# 0  ['Southern Pines Elementary School', 'Southern...
# 1  ['East Valley High School&Extension', 'Eastval...
# 4  ['Palmetto Elementary School', 'Haines City Se...

# %% [markdown]
# # Разбор нового признака - рейтинг школы

# %% [markdown]
# Вспомогательная функция - возвращает численный список: численное значение рейтинга, если рейтинг выражен числом, первое значение дроби или ноль, если встречаются любые другие символы.

# %%
data_d['typeRating']=data_d['rating'].apply(lambda x: type(x))

# %%
data_d['typeRating'].value_counts()
# Out:
# <class 'str'>      199644
# <class 'float'>     74880
# Name: typeRating, dtype: int64

# %%
data_d.rating=data_d.rating.apply(lambda x: '[]' if type(x)==float else x)

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.000000  19145.0
#
#    beds state  stories mls-id PrivatePool       MlsId    target  \
# 0     1    NC      1.0    NaN         NaN      611019  418000.0
# 1     3    WA      2.0    NaN         NaN   201916904  310000.0
# 4     1    FL      1.0    NaN         NaN      861745    5000.0
# 5     2    PA      2.0    NaN         NaN  PAPH847006  209000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
# 5                 7        71         30          21       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                                       rating  \
# 0            $144  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1       $159/sqft                  ['4/10', 'None/10', '4/10']
# 4  $120 / Sq. Ft.                        ['3', '3', '1', 'NR']
# 5   $57 / Sq. Ft.                              ['4', '2', '2']
#
#                                      Distance  \
# 0  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                          [1.65, 1.32, 1.01]
# 4                        [0.8, 8.3, 4.2, 2.0]
# 5                             [0.7, 0.4, 2.2]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
# 4  ['Palmetto Elementary School', 'Haines City Se...  <class 'str'>
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...  <class 'str'>
#
#        type_Dist
# 0  <class 'str'>
# 1  <class 'str'>
# 4  <class 'str'>
# 5  <class 'str'>

# %%
data_d.rating=data_d.rating.apply(lambda x: eval(x))

# %%
data_d.head(4)

# %%
def school_rating1 (lst_r):
    lst_clean = []
    for p in lst_r:
        if p.find('/') == -1:
            if p.isdigit():
                lst_clean.append(int(p))
            else: lst_clean.append(0)
        else:
            num = p[:p.find('/')]
            if num.isdigit():
                lst_clean.append(int(num))
                
            else: lst_clean.append(0)

    return lst_clean

# %%
data_d.rating = data_d.rating.apply(lambda x: school_rating1(x))

# %%
data_d.head(2)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
#
#                                           homeFacts  fireplace    city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0  others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0  others
#
#                                              schools    sqft  zipcode  beds  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.0  28387.0     1
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.0  99216.0     3
#
#   state  stories mls-id PrivatePool      MlsId    target  propertyType_cat  \
# 0    NC      1.0    NaN         NaN     611019  418000.0                 5
# 1    WA      2.0    NaN         NaN  201916904  310000.0                 5
#
#    city_cat  state_cat  status_cat Year built Remodeled year  \
# 0       103         21           3       2019
# 1       103         37          21       2019
#
#                   Heating Cooling Parking    lotsize price_sqft  \
# 0  Central A/C, Heat Pump                       None       $144
# 1                                          5828 sqft  $159/sqft
#
#                      rating                                    Distance  \
# 0  [4, 4, 7, 0, 4, 7, 0, 0]  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                 [4, 0, 4]                          [1.65, 1.32, 1.01]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
#
#        type_Dist
# 0  <class 'str'>
# 1  <class 'str'>

# %% [markdown]
# # Создание новых признаков: маскимальный рейтинг, средний рейтинг.

# %%
data_d['max_rating'] = data_d['rating'].apply(lambda x: 0 if x == [] else max(x))

# %%
data_d['mean_rating'] = data_d['rating'].apply(lambda x: 0 if x == [] else round(sum(x)/len(x),2))

# %%
data_d.head(3)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
#
#                                           homeFacts  fireplace      city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0    others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0    others
# 4                     [, , , , , 10,019 sqft, None]          0  Palm Bay
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
#
#    beds state  stories mls-id PrivatePool      MlsId    target  \
# 0     1    NC      1.0    NaN         NaN     611019  418000.0
# 1     3    WA      2.0    NaN         NaN  201916904  310000.0
# 4     1    FL      1.0    NaN         NaN     861745    5000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
#
#        price_sqft                    rating  \
# 0            $144  [4, 4, 7, 0, 4, 7, 0, 0]
# 1       $159/sqft                 [4, 0, 4]
# 4  $120 / Sq. Ft.              [3, 3, 1, 0]
#
#                                      Distance  \
# 0  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                          [1.65, 1.32, 1.01]
# 4                        [0.8, 8.3, 4.2, 2.0]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
# 4  ['Palmetto Elementary School', 'Haines City Se...  <class 'str'>
#
#        type_Dist  max_rating  mean_rating
# 0  <class 'str'>           7         3.25
# 1  <class 'str'>           4         2.67
# 4  <class 'str'>           3         1.75

# %% [markdown]
# # Разбор нового признака расстояние

# %% [markdown]
# Вспомогательная функция возвращает список числовых значений расстояния

# %%
data_d.Distance=data_d.Distance.apply(lambda x: '[]' if type(x)==float else x)

# %%
data_d['type_Dist'] = data_d['Distance'].apply(lambda x: type(x))

# %%
data_d['type_Dist'].value_counts()
# Out:
# <class 'str'>    274524
# Name: type_Dist, dtype: int64

# %%
data_d.Distance = data_d.Distance.apply(lambda x: eval(x))

# %%
data_d['type_Dist'] = data_d['Distance'].apply(lambda x: type(x))

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.000000  19145.0
#
#    beds state  stories mls-id PrivatePool       MlsId    target  \
# 0     1    NC      1.0    NaN         NaN      611019  418000.0
# 1     3    WA      2.0    NaN         NaN   201916904  310000.0
# 4     1    FL      1.0    NaN         NaN      861745    5000.0
# 5     2    PA      2.0    NaN         NaN  PAPH847006  209000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
# 5                 7        71         30          21       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                                       rating  \
# 0            $144  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1       $159/sqft                  ['4/10', 'None/10', '4/10']
# 4  $120 / Sq. Ft.                        ['3', '3', '1', 'NR']
# 5   $57 / Sq. Ft.                              ['4', '2', '2']
#
#                                             Distance  \
# 0  ['2.7 mi', '3.6 mi', '5.1 mi', '4.0 mi', '10.5...
# 1                     ['1.65mi', '1.32mi', '1.01mi']
# 4           ['0.8 mi', '8.3 mi', '4.2 mi', '2.0 mi']
# 5                     ['0.7 mi', '0.4 mi', '2.2 mi']
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
# 4  ['Palmetto Elementary School', 'Haines City Se...  <class 'str'>
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...  <class 'str'>
#
#        type_Dist
# 0  <class 'str'>
# 1  <class 'str'>
# 4  <class 'str'>
# 5  <class 'str'>

# %%
data_d['typeRating'].value_counts()
# Out:
# <class 'str'>      199644
# <class 'float'>     74880
# Name: typeRating, dtype: int64

# %%
def distance_select(distance):
    lst_dist = []
    if distance == []: return []
    else:
        for i in distance:
            if i.find(' mi')>-1:
                lst_dist.append(float(i[:-3]))
            elif i.find('mi')>-1:
                lst_dist.append(float(i[:-2]))
            else: lst_dist.append(0)
    return lst_dist

# %%
data_d.Distance = data_d.Distance.apply(lambda x: distance_select(x))

# %%
data_d.head(4)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
# 5  for_sale          NaN         twnh  1624 S Newkirk St    1.0
#
#                                            homeFacts  fireplace          city  \
# 0   [2019, , Central A/C, Heat Pump, , , None, $144]          0        others
# 1               [2019, , , , , 5828 sqft, $159/sqft]          0        others
# 4                      [, , , , , 10,019 sqft, None]          0      Palm Bay
# 5  [1920, , Forced Air, Central, , 680 sqft, $233...          0  Philadelphia
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
# 5  {'rating': [], 'data': {'Distance': [], 'Grade...   897.000000  19145.0
#
#    beds state  stories mls-id PrivatePool       MlsId    target  \
# 0     1    NC      1.0    NaN         NaN      611019  418000.0
# 1     3    WA      2.0    NaN         NaN   201916904  310000.0
# 4     1    FL      1.0    NaN         NaN      861745    5000.0
# 5     2    PA      2.0    NaN         NaN  PAPH847006  209000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
# 5                 7        71         30          21       1976
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
# 5                                                              8,750 Sq. Ft.
#
#        price_sqft                                       rating  \
# 0            $144  ['4', '4', '7', 'NR', '4', '7', 'NR', 'NR']
# 1       $159/sqft                  ['4/10', 'None/10', '4/10']
# 4  $120 / Sq. Ft.                        ['3', '3', '1', 'NR']
# 5   $57 / Sq. Ft.                              ['4', '2', '2']
#
#                                      Distance  \
# 0  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                          [1.65, 1.32, 1.01]
# 4                        [0.8, 8.3, 4.2, 2.0]
# 5                             [0.7, 0.4, 2.2]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
# 5            ['Preschool to 5', '6 to 8', '9 to 12']
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
# 4  ['Palmetto Elementary School', 'Haines City Se...  <class 'str'>
# 5  ['Crump Elementary School', 'Hickory Ridge Mid...  <class 'str'>
#
#        type_Dist
# 0  <class 'str'>
# 1  <class 'str'>
# 4  <class 'str'>
# 5  <class 'str'>

# %% [markdown]
# # Добавление новых признаков: минимальное расстояние до школы, среднее расстояние до школы.

# %%
data_d['min_distance'] = data_d['Distance'].apply(lambda x: 0 if x == [] else min(x))

# %%
data_d['mean_distance'] = data_d['Distance'].apply(lambda x: 0 if x == [] else round(sum(x)/len(x),2))

# %%
data_d.head(3)
# Out:
#      status private pool propertyType             street  baths  \
# 0      actv          NaN        other     240 Heather Ln    3.5
# 1  for_sale          NaN        other  12911 E Heroy Ave    3.0
# 4  for_sale          NaN        other     1524 Kiscoe St    1.0
#
#                                           homeFacts  fireplace      city  \
# 0  [2019, , Central A/C, Heat Pump, , , None, $144]          0    others
# 1              [2019, , , , , 5828 sqft, $159/sqft]          0    others
# 4                     [, , , , , 10,019 sqft, None]          0  Palm Bay
#
#                                              schools         sqft  zipcode  \
# 0  {'rating': ['4', '4', '7', 'NR', '4', '7', 'NR...  2900.000000  28387.0
# 1  {'rating': ['4/10', 'None/10', '4/10'], 'data'...  1947.000000  99216.0
# 4  {'rating': ['4/10', '5/10', '5/10'], 'data': {...  6594.616652  32908.0
#
#    beds state  stories mls-id PrivatePool      MlsId    target  \
# 0     1    NC      1.0    NaN         NaN     611019  418000.0
# 1     3    WA      2.0    NaN         NaN  201916904  310000.0
# 4     1    FL      1.0    NaN         NaN     861745    5000.0
#
#    propertyType_cat  city_cat  state_cat  status_cat Year built  \
# 0                 5       103         21           3       2019
# 1                 5       103         37          21       2019
# 4                 5        64          7          21       2006
#
#   Remodeled year                 Heating      Cooling Parking        lotsize  \
# 0                 Central A/C, Heat Pump                                None
# 1                                                                  5828 sqft
# 4           2006     Electric, Heat Pump  Central Air          4,996 Sq. Ft.
#
#        price_sqft                    rating  \
# 0            $144  [4, 4, 7, 0, 4, 7, 0, 0]
# 1       $159/sqft                 [4, 0, 4]
# 4  $120 / Sq. Ft.              [3, 3, 1, 0]
#
#                                      Distance  \
# 0  [2.7, 3.6, 5.1, 4.0, 10.5, 12.6, 2.7, 3.1]
# 1                          [1.65, 1.32, 1.01]
# 4                        [0.8, 8.3, 4.2, 2.0]
#
#                                               Grades  \
# 0  ['3–5', '6–8', '9–12', 'PK–2', '6–8', '9–12', ...
# 1                            ['9-12', '3-8', 'PK-8']
# 4  ['Preschool to 4', 'Preschool to 12', '5 to 8'...
#
#                                                 name     typeRating  \
# 0  ['Southern Pines Elementary School', 'Southern...  <class 'str'>
# 1  ['East Valley High School&Extension', 'Eastval...  <class 'str'>
# 4  ['Palmetto Elementary School', 'Haines City Se...  <class 'str'>
#
#        type_Dist  max_rating  mean_rating  max_distance  mean_distance  \
# 0  <class 'str'>           7         3.25         12.60           5.54
# 1  <class 'str'>           4         2.67          1.65           1.33
# 4  <class 'str'>           3         1.75          8.30           3.83
#
#    min_distance
# 0          2.70
# 1          1.01
# 4          0.80

# %% [markdown]
# # Выбор предварительного датафрейма для модели

# %%
data_d_preliminary=data_d[['propertyType_cat','baths','fireplace','sqft','beds','stories','status_cat','city_cat','state_cat','max_rating','mean_rating','min_distance','mean_distance','target']]

# %%
data_d_preliminary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274524 entries, 0 to 377184
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   propertyType_cat  274524 non-null  int8
#  1   baths             274524 non-null  float64
#  2   fireplace         274524 non-null  int64
#  3   sqft              274524 non-null  float64
#  4   beds              274524 non-null  int64
#  5   stories           274524 non-null  float64
#  6   status_cat        274524 non-null  int8
#  7   city_cat          274524 non-null  int8
#  8   state_cat         274524 non-null  int8
#  9   max_rating        274524 non-null  int64
#  10  mean_rating       274524 non-null  float64
#  11  min_distance      274524 non-null  float64
#  12  mean_distance     274524 non-null  float64
#  13  target            274524 non-null  float64
# dtypes: float64(7), int64(3), int8(4)
# memory usage: 32.1 MB

# %%
#data_d_test=data_d[['sqft','target']]

# %%
data_d_preliminary

# %%
data_d_preliminary.isna().sum()
# Out:
# propertyType_cat    0
# baths               0
# fireplace           0
# sqft                0
# beds                0
# stories             0
# status_cat          0
# city_cat            0
# state_cat           0
# max_rating          0
# mean_rating         0
# min_distance        0
# mean_distance       0
# target              0
# dtype: int64

# %%
data_d_preliminary['propertyType_cat'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['baths'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['beds'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['stories'].fillna(method = 'ffill', inplace = True)

# %%
data_d_preliminary.isna().sum()

# %% [markdown]
# # Визуализация

# %%
plt.figure(figsize=(18, 10))
ax = sns.heatmap(data_d_preliminary.corr().abs(), vmin=0, vmax=1, annot = True)
i, k = ax.get_ylim()
ax.set_ylim(i+0.5, k-0.5)

# %%
#data_d_preliminary['state_cat'] = data_d_preliminary[(data_d_preliminary['state_cat'] < 500 ) | (data_d_preliminary['sity_state_cat'] > 1700)]['sity_state_cat']
#sns.boxplot(data_d_preliminary['sity_state_cat'])

# %% [markdown]
# 377185

# %%
#data_d_preliminary.isna().sum()

# %%
#values = {'propertyType_cat':1275}
#data_d_preliminary = data_d_preliminary.fillna(value=values)

# %%
#data_d_preliminary = data_d_preliminary.dropna()

# %%
#data_d_preliminary.isnull().sum()

# %% [markdown]
# # Нормализация

# %%
# min_maz_Scaler=preprocessing.MinMaxScaler()

# %%
# col=data_d_preliminary.columns
# result=min_maz_Scaler.fit_transform(data_d_preliminary)
# data_d_preliminaty_n=pd.DataFrame(result,columns=col)

# %%
# data_d_preliminaty_n

# %%
#plt.figure(figsize=(18, 10))
#ax = sns.heatmap(data_d_preliminaty_n.corr().abs(), vmin=0, vmax=1, annot = True)
#i, k = ax.get_ylim()
#ax.set_ylim(i+0.5, k-0.5)

# %% [markdown]
# > # Грубая модель

# %%
data_d_preliminary

# %%
data_d_preliminary.isna().sum()

# %%
data_d_preliminary['propertyType_cat'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['baths'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['beds'].fillna(method = 'ffill', inplace = True)
data_d_preliminary['stories'].fillna(method = 'ffill', inplace = True)

# %%
data_d_preliminary.isna().sum()

# %%
# data_d_preliminary=data_d_preliminary.dropna()

# %%
X=data_d_preliminary[['propertyType_cat','baths','fireplace','sqft','beds','stories','status_cat','city_cat','state_cat','max_rating','mean_rating','min_distance','mean_distance']]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274524 entries, 0 to 377184
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   propertyType_cat  274524 non-null  int8
#  1   baths             274524 non-null  float64
#  2   fireplace         274524 non-null  int64
#  3   sqft              274524 non-null  float64
#  4   beds              274524 non-null  int64
#  5   stories           274524 non-null  float64
#  6   status_cat        274524 non-null  int8
#  7   city_cat          274524 non-null  int8
#  8   state_cat         274524 non-null  int8
#  9   max_rating        274524 non-null  int64
#  10  mean_rating       274524 non-null  float64
#  11  min_distance      274524 non-null  float64
#  12  mean_distance     274524 non-null  float64
# dtypes: float64(6), int64(3), int8(4)
# memory usage: 30.1 MB

# %%
X
# Out:
#         propertyType_cat  baths  fireplace         sqft  beds  stories  \
# 0                      5    3.5          0  2900.000000     1      1.0
# 1                      5    3.0          0  1947.000000     3      2.0
# 4                      5    1.0          0  6594.616652     1      1.0
# 5                      7    1.0          0   897.000000     2      2.0
# 6                      5    1.0          0  1507.000000     1      1.0
# ...                  ...    ...        ...          ...   ...      ...
# 377177                 6    1.0          0  1895.000000     1      1.0
# 377178                 5    2.0          0  1841.000000     1      1.0
# 377182                 5    3.0          0  1152.000000     3      2.0
# 377183                 5    1.0          0  6594.616652     1      1.0
# 377184                 5    2.0          0  1462.000000     1      1.0
#
#         status_cat  city_cat  state_cat  max_rating  mean_rating  \
# 0                3       103         21           7         3.25
# 1               21       103         37           4         2.67
# 4               21        64          7           3         1.75
# 5               21        71         30           4         2.67
# 6                3       103          7           7         3.17
# ...            ...       ...        ...         ...          ...
# 377177           3        26         33           0         0.00
# 377178          26        33         33           0         0.00
# 377182          21       103         24           0         0.00
# 377183          26        33         33           0         0.00
# 377184          26        85         33           0         0.00
#
#         min_distance  mean_distance
# 0               2.70           5.54
# 1               1.01           1.33
# 4               0.80           3.83
# 5               0.40           1.10
# 6               5.60           6.35
# ...              ...            ...
# 377177          0.00           0.00
# 377178          0.00           0.00
# 377182          0.00           0.00
# 377183          0.00           0.00
# 377184          0.00           0.00
#
# [274524 rows x 13 columns]

# %%
data_d_preliminary.isna().sum()

# %%
#X_tes = data_d_test[['sqft']]
#y_tes = data_d_test[['target']]

# %%
#X_tes

# %%
y = data_d_preliminary[['target']]
y

#X1 = data_d_preliminary[['sity_state_cat','baths','beds']]
# Out:
#           target
# 0       418000.0
# 1       310000.0
# 4         5000.0
# 5       209000.0
# 6       181500.0
# ...          ...
# 377177  199900.0
# 377178  252990.0
# 377182  528000.0
# 377183   34500.0
# 377184  204900.0
#
# [274524 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.67, 
                                                    random_state=RANDOM_SEED)

# %% [markdown]
# # Тестирование моделей

# %% [markdown]
# # Линейная регрессия

# %%
from sklearn import metrics

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2:', np.round(metrics.r2_score(y_test, y_pred), 2))
# Out:
# Root Mean Squared Error (RMSE): 122354.79029545849
# R2: 0.22

# %% [markdown]
# # Случайный лес

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score

model =  RandomForestRegressor(n_estimators=10 ,
                               oob_score=True,
                               random_state=RANDOM_SEED)
model.fit(X_train, y_train) # обучение
a = model.predict(X_test) # предсказание
a

score = model.score(X_train, y_train)
print("R-squared:", score) 
#print ("AUC-ROC (oob) = ", roc_auc_score(y_train, model.oob_prediction_))
#print ("AUC-ROC (test) = ", roc_auc_score(y_test, a))
# Out:
# R-squared: 0.9022090498331894

# %% [markdown]
# # Регрессия с дополнительными деревьями

# %%
extra_tree = ExtraTreesRegressor(n_estimators = 400, 
                                 n_jobs=-1, random_state=RANDOM_SEED)
extra_tree.fit(X_train, y_train)
predict_extra_tree = extra_tree.predict(X_test)
predict_extra_tree

np.array(y_test.index.values)
print(np.array(y_test.index.values))
# оцениваем точность
print(mape(np.array(y_test.index.values), predict_extra_tree))
#print((mape_log(y_test, predict_extra_tree)))
#pprint(f"MAPE: {(mape_log(y_test, predict_extra_tree))*100:0.2f}%")
# Out:
# [ 82881 113914 324012 ... 153931 126373 273255]
# 7.404331684797752

# %%
print(np.array(y_test.index.values))
# Out:
# [ 82881 113914 324012 ... 153931 126373 273255]

# %%
print(mape(np.array(y_test.index.values), predict_extra_tree))
# Out:
# 7.404331684797752

# %% [markdown]
# # Катбуст

# %%
catboost = CatBoostRegressor(iterations = 1000,
                          learning_rate = 0.5,
                          random_seed = RANDOM_SEED,
                          eval_metric='RMSE',
                          depth = 10,
                          l2_leaf_reg = 1)
catboost.fit(X_train, y_train,
         
         eval_set=(X_test, y_test),
         verbose_eval=100,
         use_best_model=True,
         plot=True
         )
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 117907.8512877	test: 117581.5882583	best: 117581.5882583 (0)	total: 192ms	remaining: 3m 11s
# 100:	learn: 81999.0686064	test: 86841.1702245	best: 86801.3754166 (97)	total: 6.74s	remaining: 60s
# 200:	learn: 76980.1511594	test: 87353.9421143	best: 86778.6377121 (106)	total: 13.1s	remaining: 52.2s
# 300:	learn: 73019.5567883	test: 88056.6309726	best: 86778.6377121 (106)	total: 19.6s	remaining: 45.5s
# 400:	learn: 69977.5364431	test: 88574.8936009	best: 86778.6377121 (106)	total: 26s	remaining: 38.8s
# 500:	learn: 67345.2809083	test: 89170.2713688	best: 86778.6377121 (106)	total: 32.9s	remaining: 32.8s
# 600:	learn: 65046.9394662	test: 89648.9352742	best: 86778.6377121 (106)	total: 39.6s	remaining: 26.3s
# 700:	learn: 63093.3899206	test: 90100.9672866	best: 86778.6377121 (106)	total: 46.1s	remaining: 19.7s
# 800:	learn: 61245.1802709	test: 90525.3454930	best: 86778.6377121 (106)	total: 52.6s	remaining: 13.1s
# 900:	learn: 59618.7675487	test: 90889.6510969	best: 86778.6377121 (106)	total: 59.3s	remaining: 6.51s
# 999:	learn: 58143.3231971	test: 91211.8207689	best: 86778.6377121 (106)	total: 1m 6s	remaining: 0us
#
# bestTest = 86778.63771
# bestIteration = 106
#
# Shrink model to first 107 iterations.

# %%
predict_catboost = catboost.predict(X_test)
#predict_catboost_exp=np.exp(predict_catboost)

#predict_catboost_exp

# %%
print(f"MAPE: {(mape_log(y_test, predict_catboost))*100:0.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17/1747078164.py in <module>
# ----> 1 print(f"MAPE: {(mape_log(y_test, predict_catboost))*100:0.2f}%")
#
# /tmp/ipykernel_17/1056742179.py in mape_log(y_true, y_pred)
#       1 # Функция расчета ошибки для логарифмированной целевой переменнной
#       2 def mape_log(y_true, y_pred):
# ----> 3     return np.mean(np.abs((np.exp(y_pred)-np.exp(y_true))/np.exp(y_true)))
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2030         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031     ):
# -> 2032         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2033
#    2034     # ideally we would define this to avoid the getattr checks, but
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     251
#     252     # for binary ops, use our custom dunder methods
# --> 253     result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     254     if result is not NotImplemented:
#     255         return result
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/ops_dispatch.pyx in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/arraylike.py in __rsub__(self, other)
#     102     @unpack_zerodim_and_defer("__rsub__")
#     103     def __rsub__(self, other):
# --> 104         return self._arith_method(other, roperator.rsub)
#     105
#     106     @unpack_zerodim_and_defer("__mul__")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6862         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6863
# -> 6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
#    6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     245
#     246         if right.ndim == 1:
# --> 247             right = to_series(right)
#     248
#     249         elif right.ndim == 2:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/ops/__init__.py in to_series(right)
#     237             if len(left.columns) != len(right):
#     238                 raise ValueError(
# --> 239                     msg.format(req_len=len(left.columns), given_len=len(right))
#     240                 )
#     241             right = left._constructor_sliced(right, index=left.columns)
#
# ValueError: Unable to coerce to Series, length must be 1: given 90593

# %%
predict_catboost
# Out:
# array([245680.25308492, 204436.97301254,  95872.17558124, ...,
#        243484.93139244, 402657.17303708, 122073.55222769])

# %%
y_test1=y_test.index.values

# %%
y_test1
# Out:
# array([ 82881, 113914, 324012, ..., 153931, 126373, 273255])

# %%
print_regression_metrics(y_test1, predict_catboost)
# Out:
# MSE = 27808762866.86, RMSE = 166759.60

# %%
print(f"MAPE: {(mape_log(y_test1, predict_catboost))*100:0.2f}%")
# Out:
# MAPE: nan%

# %%
y_pred_exp=np.exp(y_pred)
y_pred_exp

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("MSE: ", mse)
print("RMSE: ", mse*(1/2.0))
# Out:
# MSE:  8489662216.345895
# RMSE:  4244831108.1729474

# %%
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, linewidth=1, label="original")
plt.plot(x_ax, y_pred, linewidth=1.1, label="predicted")
plt.title("y-test and y-predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# {'rating': ['5/10', '4/10', '3/10'],
#  'data': {'Distance': ['0.3 mi', '1.1 mi', '4.1 mi'],
#   'Grades': ['PK-5', '6-8', '9-12']},
#  'name': ['Mary Lou Hartman',
#   'Woodlake Hills Middle School',
#   'Judson High School']}

# %% [markdown]
# # Анализ feature importance

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: -4335.73268
# Feature: 1, Score: 65539.25057
# Feature: 2, Score: 23842.14849
# Feature: 3, Score: -9.21751
# Feature: 4, Score: -4338.44654
# Feature: 5, Score: 6439.06256
# Feature: 6, Score: -1781.60591
# Feature: 7, Score: 86.76083
# Feature: 8, Score: -390.19900
# Feature: 9, Score: -93.50474
# Feature: 10, Score: 150.40254
# Feature: 11, Score: -182.62168
# Feature: 12, Score: 230.89215

# %%
feature_importance=catboost.feature_importances_
sorted_idx=np.argsort(feature_importance)
fig=plt.figure(figsize=(12,6))
plt.barh(range(len(sorted_idx)),feature_importance[sorted_idx],align='center')
plt.yticks(range(len(sorted_idx)),np.array(X_test.columns)[sorted_idx])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')
